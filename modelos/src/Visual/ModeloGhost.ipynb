# %%
# !pip install lmdb

import argparse
import os
import numpy as np
import math
import itertools
import signal
import pandas as pd
import random
from sklearn.metrics import mean_absolute_error, r2_score
import lmdb
import pickle
from io import BytesIO
from sklearn.preprocessing import StandardScaler
import torchvision.transforms as transforms
from torchvision.utils import save_image
from transformers import AutoTokenizer, AutoModel
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torch.autograd import Variable
from torchvision import models

import gc

import zipfile
from io import BytesIO

import torch.nn as nn
import torch.nn.functional as F
import torch

import matplotlib.pyplot as plt
from PIL import Image

from torch.amp import GradScaler, autocast
from torch.utils.data import random_split

import glob
# Out:
# Collecting lmdb
#   Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 19.4 MB/s eta 0:00:00
# Installing collected packages: lmdb
# Successfully installed lmdb-1.6.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/data/datos_coches_procesados.csv')

# %%
import zipfile
import os

ruta_zip = "/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/data/imagenes_comprimidas.zip"
carpeta_destino = "dataset_extraido"

os.makedirs(carpeta_destino, exist_ok=True)

with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
    zip_ref.extractall(carpeta_destino)

print("Descompresión completada.")
# Out:
# Descompresión completada.

# %%
# Ruta a imágenes y CSV
root_dir = "dataset_extraido/imagenes_comprimidas"
csv_path = "/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/data/datos_coches_procesados.csv"
lmdb_path = "dataset.lmdb"

# Leer CSV
df = pd.read_csv(csv_path)
df = df.set_index('url')


# Crear base de datos LMDB
env = lmdb.open(lmdb_path, map_async=True, map_size=20*1024**3, meminit=False, writemap=True, lock=False)

with env.begin(write=True) as txn:
    for url in os.listdir(root_dir):
        folder_path = os.path.join(root_dir, url)
        if not os.path.isdir(folder_path) or url not in df.index:
            continue

        images = []
        df_row = df.loc[url]
        precio = df_row['precio']
         # Cargar todas las imágenes de la subcarpeta
        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            with open(img_path, 'rb') as f:
                img_bytes = f.read()
                images.append((img_name, img_bytes))  # Guardamos el nombre y el contenido

        if not images:
            continue

        key = url.encode('utf-8')  # Solo el nombre de la carpeta como clave
        metadata = df.loc[url].to_dict()
        value = pickle.dumps({
            "images": images,    # Lista de (nombre, bytes)
            "precio": precio
        })

        txn.put(key, value)

# %%
random.seed(42)
def split_keys(path, train, dev):
  env = lmdb.open(path, readonly=True, lock=False)
  keys = []

  with env.begin() as txn:
      cursor = txn.cursor()
      for key, _ in cursor:
          keys.append(key)

  random.shuffle(keys)

  train_split = train
  dev_split = dev

  n = len(keys)
  train_keys = keys[:int(train_split * n)]
  dev_keys = keys[int(train_split * n):int((train_split + dev_split) * n)]
  test_keys = keys[int((train_split + dev_split) * n):]
  return train_keys, dev_keys, test_keys

# %%
def set_scaler(y_train):
  y_train_int = []
  for y in y_train:
    y = y.split(",")[0]
    y = y.replace('.', '')
    y = int(y)
    y_train_int.append(y)
  targets = np.array(y_train_int).reshape(-1, 1)
  scaler = StandardScaler()
  scaler.fit(targets)
  return scaler

# %%
def get_labels_train(df, train_keys):
  keys_str = [key.decode('utf-8') for key in train_keys]
  filtered_df = df.loc[df.index.intersection(keys_str)]
  y_train = filtered_df['precio'].tolist()
  return y_train

# %%
class LMDBDataset(Dataset):
    def __init__(self, lmdb_path ,keys, scaler, transform=None):
        self.env = lmdb.open(lmdb_path, readonly=True, lock=False)
        self.keys = keys
        self.transform = transform or transforms.ToTensor()
        self.normalizar = False
        self.scaler = scaler
    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        with self.env.begin() as txn:
            data = pickle.loads(txn.get(key))

        images = data["images"]
        try:
          precio = data['precio'].split(",")[0]
          precio = precio.replace('.', '')
          precio = int(precio)
        except:
          precio = -1



        precio = self.normalizar_precio(precio)

        image_list = []
        for img_name, img_bytes in images:
            img = Image.open(BytesIO(img_bytes)).convert("RGB")
            img = self.transform(img)
            image_list.append(img)

        return image_list, len(images), precio
    def normalizar_precio(self, precio):
        y = self.scaler.transform([[precio]])[0][0]
        return y

# %%
def custom_collate_fn(batch):
    all_images = []
    all_metadata = []
    num_images_per_group = []
    precios = []
    for images, num_images, precio in batch:
        all_images.extend(images)  # añadir todas las imágenes
        num_images_per_group.append(num_images)
        precios.append(precio)

    all_images = torch.stack(all_images, dim=0)  # [total_imágenes, 3, 256, 256]

    return all_images, num_images_per_group, precios

# %%
train_keys, dev_keys, test_keys = split_keys(lmdb_path, 0.85, 0.05)

# %%
train_precios = get_labels_train(df, train_keys)
scaler = set_scaler(train_precios)

# %%
train_dataset = LMDBDataset(lmdb_path, train_keys, scaler)
dev_dataset = LMDBDataset(lmdb_path, dev_keys, scaler)
test_dataset = LMDBDataset(lmdb_path, test_keys, scaler)

# %%
class MultiImageFlexibleVGG(nn.Module):
    def __init__(self, model, feature_dim=4096):
        super().__init__()
        self.model = model

    def forward(self, images):
        device = next(self.parameters()).device
        all_imgs = images.to(device)

        with torch.no_grad():
            feats = self.model(all_imgs)
        return feats

# %%
class FeatLSTM(nn.Module):
  def __init__(self, input_size, hidden_size):
    super(FeatLSTM, self).__init__()
    self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, batch_first=True, bidirectional=True)
    self.hidden_size = hidden_size
    self.regression = nn.Linear(hidden_size * 2, 1)
  def forward(self, x, lengths):
    cut_indices = torch.cumsum(lengths, dim=0)[:-1]
    split = torch.tensor_split(x, cut_indices.tolist(), dim=0)
    out = torch.tensor([]).to(device)
    for seq in split:
      _, (h, c) = self.lstm(seq)
      h = h.flatten()
      out = torch.cat((out, torch.unsqueeze(h, 0)), dim=0)

    out = self.regression(out)
    return out

# %%
class MultiImageModel(nn.Module):
  def __init__(self, visual_model, input_size = 1280, hidden_size = 512):
    super(MultiImageModel, self).__init__()
    self.visual_model = MultiImageFlexibleVGG(visual_model)
    self.lstm = FeatLSTM(input_size, hidden_size)
  def forward(self, images, lengths):
    feats = self.visual_model(images)
    out = self.lstm(feats, lengths)
    return out

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0
        self.should_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True

# %%
class Trainer():
  def __init__(self, model, dataset, dataloader, devloader, testloader, num_epochs, learning_rate, device, save, earlystopping):
    self.model = model
    self.dataset = dataset
    self.dataloader = dataloader
    self.num_epochs = num_epochs
    self.learning_rate = learning_rate
    self.device = device
    self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)
    self.criterion = nn.MSELoss()
    self.save = save
    self.earlystopping = earlystopping
    self.devloader = devloader
    self.testloader = testloader
    self.save_path ='/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/modelos/visual/ghost_model.pth'

  def train(self):
    for epoch in range(self.num_epochs):
      self.model.train()
      for images, num_images, y in self.dataloader:
        y = torch.tensor(y, dtype=torch.float32).to(device)
        lengths = torch.tensor(num_images).to(self.device)
        images = images.to(self.device)

        self.optimizer.zero_grad()

        output = self.model(images, lengths)
        loss = self.criterion(output.flatten(), y.flatten())
        loss.backward()
        self.optimizer.step()
        print(f"Epoch {epoch+1}/{self.num_epochs}, Loss: {loss.item()}")

      eval_loss = self.eval()

      if self.save and self.earlystopping.best_loss > eval_loss:
        torch.save(self.model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/modelos/Visual/ghot_model.pth')

      print(f"Epoch {epoch+1}/{self.num_epochs}, Eval Loss: {eval_loss}")
      if epoch == 8:
        self.descongelar_capas()
      self.earlystopping(eval_loss)
      if self.earlystopping.should_stop:
        print("Early stopping triggered")
        break

  def eval(self):
    self.model.eval()
    losses = []
    with torch.no_grad():
      for images, num_images, y in self.devloader:
        lengths = torch.tensor(num_images).to(self.device)
        y = torch.tensor(y, dtype=torch.float32).to(device)
        images = images.to(self.device)
        output = self.model(images, lengths)
        loss = self.criterion(output.flatten(), y.flatten())
        losses.append(loss.item())
    return sum(losses)/len(losses)
  def test(self):
    self.model.eval()
    targets = []
    preds = []
    with torch.no_grad():
      for images, num_images, y in self.testloader:
        lengths = torch.tensor(num_images).to(self.device)
        y = torch.tensor(y, dtype=torch.float32).to(device)
        images = images.to(self.device)
        output = self.model(images, lengths)
        preds.append(output)
        targets.append(y)

    y_pred = torch.cat([torch.tensor(p) for p in preds]).to('cpu').numpy().flatten()
    y_true = torch.cat([torch.tensor(t) for t in targets]).to('cpu').numpy().flatten()

    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    print(f"MAE: {mae:.4f}")
    print(f"R²:  {r2:.4f}")

    return mae, r2

  def save(self, path=None):
    if path is None:
      torch.save(self.model.state_dict(), self.save_path)
    else:
      torch.save(self.model.state_dict(), path)
  def descongelar_capas(self):
    print("Descongelando capas...")
    for name, param in self.model.visual_model.named_parameters():
      if '8.3.ghost2' in name:
        param.requires_grad = True

# %%
import timm
v_model = timm.create_model('ghostnet_100', pretrained=True)
v_model.classifier = nn.Identity()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/20.9M [00:00<?, ?B/s]

# %%
for name, param in v_model.named_parameters():
    if 'conv_head' in name:
        param.requires_grad = True

# %%
for name, param in v_model.named_parameters():
    estado = "entrenable" if param.requires_grad else "congelada"
    print(f"{name:50} → {estado}")
# Out:
# conv_stem.weight                                   → entrenable
# bn1.weight                                         → entrenable
# bn1.bias                                           → entrenable
# blocks.0.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.0.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.0.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.0.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.0.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.0.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.0.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.0.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.0.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.0.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.0.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.0.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.1.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.1.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.1.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.1.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.1.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.1.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.1.0.conv_dw.weight                          → entrenable
# blocks.1.0.bn_dw.weight                            → entrenable
# blocks.1.0.bn_dw.bias                              → entrenable
# blocks.1.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.1.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.1.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.1.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.1.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.1.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.1.0.shortcut.0.weight                       → entrenable
# blocks.1.0.shortcut.1.weight                       → entrenable
# blocks.1.0.shortcut.1.bias                         → entrenable
# blocks.1.0.shortcut.2.weight                       → entrenable
# blocks.1.0.shortcut.3.weight                       → entrenable
# blocks.1.0.shortcut.3.bias                         → entrenable
# blocks.2.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.2.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.2.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.2.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.2.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.2.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.2.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.2.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.2.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.2.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.2.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.2.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.3.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.3.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.3.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.3.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.3.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.3.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.3.0.conv_dw.weight                          → entrenable
# blocks.3.0.bn_dw.weight                            → entrenable
# blocks.3.0.bn_dw.bias                              → entrenable
# blocks.3.0.se.conv_reduce.weight                   → entrenable
# blocks.3.0.se.conv_reduce.bias                     → entrenable
# blocks.3.0.se.conv_expand.weight                   → entrenable
# blocks.3.0.se.conv_expand.bias                     → entrenable
# blocks.3.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.3.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.3.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.3.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.3.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.3.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.3.0.shortcut.0.weight                       → entrenable
# blocks.3.0.shortcut.1.weight                       → entrenable
# blocks.3.0.shortcut.1.bias                         → entrenable
# blocks.3.0.shortcut.2.weight                       → entrenable
# blocks.3.0.shortcut.3.weight                       → entrenable
# blocks.3.0.shortcut.3.bias                         → entrenable
# blocks.4.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.4.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.4.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.4.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.4.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.4.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.4.0.se.conv_reduce.weight                   → entrenable
# blocks.4.0.se.conv_reduce.bias                     → entrenable
# blocks.4.0.se.conv_expand.weight                   → entrenable
# blocks.4.0.se.conv_expand.bias                     → entrenable
# blocks.4.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.4.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.4.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.4.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.4.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.4.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.5.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.5.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.5.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.5.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.5.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.5.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.5.0.conv_dw.weight                          → entrenable
# blocks.5.0.bn_dw.weight                            → entrenable
# blocks.5.0.bn_dw.bias                              → entrenable
# blocks.5.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.5.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.5.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.5.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.5.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.5.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.5.0.shortcut.0.weight                       → entrenable
# blocks.5.0.shortcut.1.weight                       → entrenable
# blocks.5.0.shortcut.1.bias                         → entrenable
# blocks.5.0.shortcut.2.weight                       → entrenable
# blocks.5.0.shortcut.3.weight                       → entrenable
# blocks.5.0.shortcut.3.bias                         → entrenable
# blocks.6.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.6.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.6.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.6.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.6.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.6.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.6.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.6.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.6.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.6.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.6.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.6.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.6.1.ghost1.primary_conv.0.weight            → entrenable
# blocks.6.1.ghost1.primary_conv.1.weight            → entrenable
# blocks.6.1.ghost1.primary_conv.1.bias              → entrenable
# blocks.6.1.ghost1.cheap_operation.0.weight         → entrenable
# blocks.6.1.ghost1.cheap_operation.1.weight         → entrenable
# blocks.6.1.ghost1.cheap_operation.1.bias           → entrenable
# blocks.6.1.ghost2.primary_conv.0.weight            → entrenable
# blocks.6.1.ghost2.primary_conv.1.weight            → entrenable
# blocks.6.1.ghost2.primary_conv.1.bias              → entrenable
# blocks.6.1.ghost2.cheap_operation.0.weight         → entrenable
# blocks.6.1.ghost2.cheap_operation.1.weight         → entrenable
# blocks.6.1.ghost2.cheap_operation.1.bias           → entrenable
# blocks.6.2.ghost1.primary_conv.0.weight            → entrenable
# blocks.6.2.ghost1.primary_conv.1.weight            → entrenable
# blocks.6.2.ghost1.primary_conv.1.bias              → entrenable
# blocks.6.2.ghost1.cheap_operation.0.weight         → entrenable
# blocks.6.2.ghost1.cheap_operation.1.weight         → entrenable
# blocks.6.2.ghost1.cheap_operation.1.bias           → entrenable
# blocks.6.2.ghost2.primary_conv.0.weight            → entrenable
# blocks.6.2.ghost2.primary_conv.1.weight            → entrenable
# blocks.6.2.ghost2.primary_conv.1.bias              → entrenable
# blocks.6.2.ghost2.cheap_operation.0.weight         → entrenable
# blocks.6.2.ghost2.cheap_operation.1.weight         → entrenable
# blocks.6.2.ghost2.cheap_operation.1.bias           → entrenable
# blocks.6.3.ghost1.primary_conv.0.weight            → entrenable
# blocks.6.3.ghost1.primary_conv.1.weight            → entrenable
# blocks.6.3.ghost1.primary_conv.1.bias              → entrenable
# blocks.6.3.ghost1.cheap_operation.0.weight         → entrenable
# blocks.6.3.ghost1.cheap_operation.1.weight         → entrenable
# blocks.6.3.ghost1.cheap_operation.1.bias           → entrenable
# blocks.6.3.se.conv_reduce.weight                   → entrenable
# blocks.6.3.se.conv_reduce.bias                     → entrenable
# blocks.6.3.se.conv_expand.weight                   → entrenable
# blocks.6.3.se.conv_expand.bias                     → entrenable
# blocks.6.3.ghost2.primary_conv.0.weight            → entrenable
# blocks.6.3.ghost2.primary_conv.1.weight            → entrenable
# blocks.6.3.ghost2.primary_conv.1.bias              → entrenable
# blocks.6.3.ghost2.cheap_operation.0.weight         → entrenable
# blocks.6.3.ghost2.cheap_operation.1.weight         → entrenable
# blocks.6.3.ghost2.cheap_operation.1.bias           → entrenable
# blocks.6.3.shortcut.0.weight                       → entrenable
# blocks.6.3.shortcut.1.weight                       → entrenable
# blocks.6.3.shortcut.1.bias                         → entrenable
# blocks.6.3.shortcut.2.weight                       → entrenable
# blocks.6.3.shortcut.3.weight                       → entrenable
# blocks.6.3.shortcut.3.bias                         → entrenable
# blocks.6.4.ghost1.primary_conv.0.weight            → entrenable
# blocks.6.4.ghost1.primary_conv.1.weight            → entrenable
# blocks.6.4.ghost1.primary_conv.1.bias              → entrenable
# blocks.6.4.ghost1.cheap_operation.0.weight         → entrenable
# blocks.6.4.ghost1.cheap_operation.1.weight         → entrenable
# blocks.6.4.ghost1.cheap_operation.1.bias           → entrenable
# blocks.6.4.se.conv_reduce.weight                   → entrenable
# blocks.6.4.se.conv_reduce.bias                     → entrenable
# blocks.6.4.se.conv_expand.weight                   → entrenable
# blocks.6.4.se.conv_expand.bias                     → entrenable
# blocks.6.4.ghost2.primary_conv.0.weight            → entrenable
# blocks.6.4.ghost2.primary_conv.1.weight            → entrenable
# blocks.6.4.ghost2.primary_conv.1.bias              → entrenable
# blocks.6.4.ghost2.cheap_operation.0.weight         → entrenable
# blocks.6.4.ghost2.cheap_operation.1.weight         → entrenable
# blocks.6.4.ghost2.cheap_operation.1.bias           → entrenable
# blocks.7.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.7.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.7.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.7.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.7.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.7.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.7.0.conv_dw.weight                          → entrenable
# blocks.7.0.bn_dw.weight                            → entrenable
# blocks.7.0.bn_dw.bias                              → entrenable
# blocks.7.0.se.conv_reduce.weight                   → entrenable
# blocks.7.0.se.conv_reduce.bias                     → entrenable
# blocks.7.0.se.conv_expand.weight                   → entrenable
# blocks.7.0.se.conv_expand.bias                     → entrenable
# blocks.7.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.7.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.7.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.7.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.7.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.7.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.7.0.shortcut.0.weight                       → entrenable
# blocks.7.0.shortcut.1.weight                       → entrenable
# blocks.7.0.shortcut.1.bias                         → entrenable
# blocks.7.0.shortcut.2.weight                       → entrenable
# blocks.7.0.shortcut.3.weight                       → entrenable
# blocks.7.0.shortcut.3.bias                         → entrenable
# blocks.8.0.ghost1.primary_conv.0.weight            → entrenable
# blocks.8.0.ghost1.primary_conv.1.weight            → entrenable
# blocks.8.0.ghost1.primary_conv.1.bias              → entrenable
# blocks.8.0.ghost1.cheap_operation.0.weight         → entrenable
# blocks.8.0.ghost1.cheap_operation.1.weight         → entrenable
# blocks.8.0.ghost1.cheap_operation.1.bias           → entrenable
# blocks.8.0.ghost2.primary_conv.0.weight            → entrenable
# blocks.8.0.ghost2.primary_conv.1.weight            → entrenable
# blocks.8.0.ghost2.primary_conv.1.bias              → entrenable
# blocks.8.0.ghost2.cheap_operation.0.weight         → entrenable
# blocks.8.0.ghost2.cheap_operation.1.weight         → entrenable
# blocks.8.0.ghost2.cheap_operation.1.bias           → entrenable
# blocks.8.1.ghost1.primary_conv.0.weight            → entrenable
# blocks.8.1.ghost1.primary_conv.1.weight            → entrenable
# blocks.8.1.ghost1.primary_conv.1.bias              → entrenable
# blocks.8.1.ghost1.cheap_operation.0.weight         → entrenable
# blocks.8.1.ghost1.cheap_operation.1.weight         → entrenable
# blocks.8.1.ghost1.cheap_operation.1.bias           → entrenable
# blocks.8.1.se.conv_reduce.weight                   → entrenable
# blocks.8.1.se.conv_reduce.bias                     → entrenable
# blocks.8.1.se.conv_expand.weight                   → entrenable
# blocks.8.1.se.conv_expand.bias                     → entrenable
# blocks.8.1.ghost2.primary_conv.0.weight            → entrenable
# blocks.8.1.ghost2.primary_conv.1.weight            → entrenable
# blocks.8.1.ghost2.primary_conv.1.bias              → entrenable
# blocks.8.1.ghost2.cheap_operation.0.weight         → entrenable
# blocks.8.1.ghost2.cheap_operation.1.weight         → entrenable
# blocks.8.1.ghost2.cheap_operation.1.bias           → entrenable
# blocks.8.2.ghost1.primary_conv.0.weight            → entrenable
# blocks.8.2.ghost1.primary_conv.1.weight            → entrenable
# blocks.8.2.ghost1.primary_conv.1.bias              → entrenable
# blocks.8.2.ghost1.cheap_operation.0.weight         → entrenable
# blocks.8.2.ghost1.cheap_operation.1.weight         → entrenable
# blocks.8.2.ghost1.cheap_operation.1.bias           → entrenable
# blocks.8.2.ghost2.primary_conv.0.weight            → entrenable
# blocks.8.2.ghost2.primary_conv.1.weight            → entrenable
# blocks.8.2.ghost2.primary_conv.1.bias              → entrenable
# blocks.8.2.ghost2.cheap_operation.0.weight         → entrenable
# blocks.8.2.ghost2.cheap_operation.1.weight         → entrenable
# blocks.8.2.ghost2.cheap_operation.1.bias           → entrenable
# blocks.8.3.ghost1.primary_conv.0.weight            → entrenable
# blocks.8.3.ghost1.primary_conv.1.weight            → entrenable
# blocks.8.3.ghost1.primary_conv.1.bias              → entrenable
# blocks.8.3.ghost1.cheap_operation.0.weight         → entrenable
# blocks.8.3.ghost1.cheap_operation.1.weight         → entrenable
# blocks.8.3.ghost1.cheap_operation.1.bias           → entrenable
# blocks.8.3.se.conv_reduce.weight                   → entrenable
# blocks.8.3.se.conv_reduce.bias                     → entrenable
# blocks.8.3.se.conv_expand.weight                   → entrenable
# blocks.8.3.se.conv_expand.bias                     → entrenable
# blocks.8.3.ghost2.primary_conv.0.weight            → entrenable
# blocks.8.3.ghost2.primary_conv.1.weight            → entrenable
# blocks.8.3.ghost2.primary_conv.1.bias              → entrenable
# blocks.8.3.ghost2.cheap_operation.0.weight         → entrenable
# blocks.8.3.ghost2.cheap_operation.1.weight         → entrenable
# blocks.8.3.ghost2.cheap_operation.1.bias           → entrenable
# blocks.9.0.conv.weight                             → entrenable
# blocks.9.0.bn1.weight                              → entrenable
# blocks.9.0.bn1.bias                                → entrenable
# conv_head.weight                                   → entrenable
# conv_head.bias                                     → entrenable

# %%
model = MultiImageModel(v_model)

# %%
trainloader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)
devloader = DataLoader(dev_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)
testloader = DataLoader(test_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)

# %%
earlystopping = EarlyStopping(patience = 12, min_delta=0.01)

# %%
trainer = Trainer(model.to(device), train_dataset, trainloader, devloader, testloader, 30, 0.001, device, True, earlystopping)

# %%
trainer.train()
# Out:
# Epoch 1/30, Loss: 0.30789875984191895
# Epoch 1/30, Loss: 3.5483791828155518
# Epoch 1/30, Loss: 0.20626704394817352
# Epoch 1/30, Loss: 0.39444392919540405
# Epoch 1/30, Loss: 0.961611270904541
# Epoch 1/30, Loss: 0.37757575511932373
# Epoch 1/30, Loss: 0.2291688621044159
# Epoch 1/30, Loss: 0.5848636031150818
# Epoch 1/30, Loss: 0.8835317492485046
# Epoch 1/30, Loss: 0.9277235865592957
# Epoch 1/30, Loss: 0.3567045032978058
# Epoch 1/30, Loss: 3.0706799030303955
# Epoch 1/30, Loss: 1.0471323728561401
# Epoch 1/30, Loss: 2.1496965885162354
# Epoch 1/30, Loss: 0.19746193289756775
# Epoch 1/30, Loss: 0.20541024208068848
# Epoch 1/30, Loss: 0.250527024269104
# Epoch 1/30, Loss: 0.3263586163520813
# Epoch 1/30, Loss: 0.20233452320098877
# Epoch 1/30, Loss: 0.25767743587493896
# Epoch 1/30, Loss: 0.18159610033035278
# Epoch 1/30, Loss: 7.5466837882995605
# Epoch 1/30, Loss: 0.207736074924469
# Epoch 1/30, Loss: 0.11529865115880966
# Epoch 1/30, Loss: 0.18435397744178772
# Epoch 1/30, Loss: 0.1301831305027008
# Epoch 1/30, Loss: 0.13756510615348816
# Epoch 1/30, Loss: 0.28462162613868713
# Epoch 1/30, Loss: 0.2580168545246124
# Epoch 1/30, Loss: 0.27658265829086304
# Epoch 1/30, Loss: 0.270086407661438
# Epoch 1/30, Loss: 0.2059127688407898
# Epoch 1/30, Loss: 0.11170646548271179
# Epoch 1/30, Loss: 0.40037649869918823
# Epoch 1/30, Loss: 0.22535662353038788
# Epoch 1/30, Loss: 0.10772189497947693
# Epoch 1/30, Loss: 0.14718922972679138
# Epoch 1/30, Loss: 0.2648295760154724
# Epoch 1/30, Loss: 0.11602912843227386
# Epoch 1/30, Loss: 0.25957709550857544
# Epoch 1/30, Loss: 0.1324584186077118
# Epoch 1/30, Loss: 0.17960433661937714
# Epoch 1/30, Loss: 0.08768147230148315
# Epoch 1/30, Loss: 0.7078017592430115
# Epoch 1/30, Loss: 0.2759614586830139
# Epoch 1/30, Loss: 0.1169305145740509
# Epoch 1/30, Loss: 0.16810670495033264
# Epoch 1/30, Loss: 2.410526752471924
# Epoch 1/30, Loss: 1.4473838806152344
# Epoch 1/30, Loss: 0.3242129385471344
# Epoch 1/30, Loss: 0.1520724594593048
# Epoch 1/30, Loss: 0.2653959393501282
# Epoch 1/30, Loss: 1.810613751411438
# Epoch 1/30, Loss: 0.28211498260498047
# Epoch 1/30, Loss: 0.1823008954524994
# Epoch 1/30, Loss: 0.11699783802032471
# Epoch 1/30, Loss: 0.20725181698799133
# Epoch 1/30, Loss: 0.049828894436359406
# Epoch 1/30, Loss: 0.13632065057754517
# Epoch 1/30, Loss: 0.6981751322746277
# Epoch 1/30, Loss: 0.43842068314552307
# Epoch 1/30, Loss: 0.16534078121185303
# Epoch 1/30, Loss: 0.43588992953300476
# Epoch 1/30, Loss: 0.12419302761554718
# Epoch 1/30, Loss: 0.16635292768478394
# Epoch 1/30, Loss: 0.22441497445106506
# Epoch 1/30, Loss: 2.8073501586914062
# Epoch 1/30, Loss: 0.09343612939119339
# Epoch 1/30, Loss: 0.2486172914505005
# Epoch 1/30, Loss: 0.0944804847240448
# Epoch 1/30, Loss: 0.18781116604804993
# Epoch 1/30, Loss: 0.0875292718410492
# Epoch 1/30, Loss: 0.09714333713054657
# Epoch 1/30, Loss: 0.8815262317657471
# Epoch 1/30, Loss: 0.5978604555130005
# Epoch 1/30, Loss: 0.2906583249568939
# Epoch 1/30, Loss: 0.2433844953775406
# Epoch 1/30, Loss: 7.453756332397461
# Epoch 1/30, Loss: 0.19597521424293518
# Epoch 1/30, Loss: 0.1294468492269516
# Epoch 1/30, Loss: 0.12167999893426895
# Epoch 1/30, Loss: 0.23506207764148712
# Epoch 1/30, Loss: 0.15506473183631897
# Epoch 1/30, Loss: 0.18105320632457733
# Epoch 1/30, Loss: 14.386354446411133
# Epoch 1/30, Loss: 0.20142707228660583
# Epoch 1/30, Loss: 0.6712915301322937
# Epoch 1/30, Loss: 0.7565733194351196
# Epoch 1/30, Loss: 0.34093713760375977
# Epoch 1/30, Loss: 0.5298562049865723
# Epoch 1/30, Loss: 2.591552495956421
# Epoch 1/30, Loss: 4.807126522064209
# Epoch 1/30, Loss: 0.17510688304901123
# Epoch 1/30, Loss: 1.3567787408828735
# Epoch 1/30, Loss: 0.10646018385887146
# Epoch 1/30, Loss: 0.18168920278549194
# Epoch 1/30, Loss: 0.21823343634605408
# Epoch 1/30, Loss: 0.11607816070318222
# Epoch 1/30, Loss: 0.37482380867004395
# Epoch 1/30, Loss: 0.3214978277683258
# Epoch 1/30, Loss: 0.11814625561237335
# Epoch 1/30, Loss: 0.2054460644721985
# Epoch 1/30, Loss: 18.564912796020508
# Epoch 1/30, Loss: 0.40786612033843994
# Epoch 1/30, Loss: 0.3160286545753479
# Epoch 1/30, Loss: 7.400000095367432
# Epoch 1/30, Loss: 0.4287734925746918
# Epoch 1/30, Loss: 0.4593002498149872
# Epoch 1/30, Loss: 0.4317212700843811
# Epoch 1/30, Loss: 0.7280624508857727
# Epoch 1/30, Loss: 0.5935665369033813
# Epoch 1/30, Loss: 0.25954169034957886
# Epoch 1/30, Loss: 0.2039683759212494
# Epoch 1/30, Loss: 0.19973143935203552
# Epoch 1/30, Loss: 0.28060197830200195
# Epoch 1/30, Loss: 0.16734054684638977
# Epoch 1/30, Loss: 0.07532387971878052
# Epoch 1/30, Loss: 0.11079497635364532
# Epoch 1/30, Loss: 0.3885679543018341
# Epoch 1/30, Loss: 0.30549365282058716
# Epoch 1/30, Loss: 0.29931700229644775
# Epoch 1/30, Loss: 0.13039365410804749
# Epoch 1/30, Loss: 0.111992247402668
# Epoch 1/30, Loss: 0.31321626901626587
# Epoch 1/30, Loss: 0.25343990325927734
# Epoch 1/30, Loss: 0.4284217357635498
# Epoch 1/30, Loss: 0.16804690659046173
# Epoch 1/30, Loss: 0.09542996436357498
# Epoch 1/30, Loss: 0.14323949813842773
# Epoch 1/30, Loss: 0.17705628275871277
# Epoch 1/30, Loss: 0.24035748839378357
# Epoch 1/30, Loss: 0.2593023180961609
# Epoch 1/30, Loss: 0.08829779177904129
# Epoch 1/30, Loss: 5.5269646644592285
# Epoch 1/30, Loss: 0.11881669610738754
# Epoch 1/30, Loss: 0.09420209378004074
# Epoch 1/30, Loss: 0.15931436419487
# Epoch 1/30, Loss: 0.11801254749298096
# Epoch 1/30, Loss: 0.18070416152477264
# Epoch 1/30, Loss: 5.220390319824219
# Epoch 1/30, Loss: 0.1821787804365158
# Epoch 1/30, Loss: 0.15208464860916138
# Epoch 1/30, Loss: 1.313652753829956
# Epoch 1/30, Loss: 0.16207972168922424
# Epoch 1/30, Loss: 0.16442696750164032
# Epoch 1/30, Loss: 2.190526008605957
# Epoch 1/30, Loss: 0.1935144066810608
# Epoch 1/30, Loss: 0.15727201104164124
# Epoch 1/30, Loss: 0.45660755038261414
# Epoch 1/30, Loss: 0.3754591941833496
# Epoch 1/30, Loss: 0.14980949461460114
# Epoch 1/30, Loss: 0.14559254050254822
# Epoch 1/30, Loss: 0.20499104261398315
# Epoch 1/30, Loss: 0.29043644666671753
# Epoch 1/30, Loss: 0.17181570827960968
# Epoch 1/30, Loss: 0.12750916182994843
# Epoch 1/30, Loss: 0.24530351161956787
# Epoch 1/30, Loss: 0.0901356190443039
# Epoch 1/30, Loss: 0.6165623068809509
# Epoch 1/30, Loss: 0.1730833351612091
# Epoch 1/30, Loss: 0.0816827341914177
# Epoch 1/30, Loss: 0.12621957063674927
# Epoch 1/30, Loss: 0.12017276138067245
# Epoch 1/30, Loss: 0.3316730260848999
# Epoch 1/30, Loss: 0.3685374855995178
# Epoch 1/30, Loss: 0.19787736237049103
# Epoch 1/30, Loss: 0.09853660315275192
# Epoch 1/30, Loss: 0.6745059490203857
# Epoch 1/30, Loss: 0.20998415350914001
# Epoch 1/30, Loss: 0.19442318379878998
# Epoch 1/30, Loss: 1.5189709663391113
# Epoch 1/30, Loss: 0.1665775328874588
# Epoch 1/30, Loss: 2.9963905811309814
# Epoch 1/30, Loss: 0.15035949647426605
# Epoch 1/30, Loss: 0.12304816395044327
# Epoch 1/30, Loss: 3.607637643814087
# Epoch 1/30, Loss: 0.27433279156684875
# Epoch 1/30, Loss: 0.46321341395378113
# Epoch 1/30, Loss: 0.6043649315834045
# Epoch 1/30, Loss: 0.07616052776575089
# Epoch 1/30, Loss: 0.6132128238677979
# Epoch 1/30, Loss: 0.4693126976490021
# Epoch 1/30, Loss: 0.23568780720233917
# Epoch 1/30, Loss: 0.2739499807357788
# Epoch 1/30, Loss: 0.2231612503528595
# Epoch 1/30, Loss: 0.2408919781446457
# Epoch 1/30, Loss: 0.8308241367340088
# Epoch 1/30, Loss: 0.3954577147960663
# Epoch 1/30, Loss: 0.24319201707839966
# Epoch 1/30, Loss: 0.09899124503135681
# Epoch 1/30, Loss: 0.44585758447647095
# Epoch 1/30, Loss: 0.22679048776626587
# Epoch 1/30, Loss: 0.20937538146972656
# Epoch 1/30, Loss: 0.39238440990448
# Epoch 1/30, Loss: 0.18953758478164673
# Epoch 1/30, Loss: 0.14103296399116516
# Epoch 1/30, Loss: 0.11003907024860382
# Epoch 1/30, Loss: 0.23836985230445862
# Epoch 1/30, Loss: 0.09423099458217621
# Epoch 1/30, Loss: 0.04057988524436951
# Epoch 1/30, Loss: 0.10025152564048767
# Epoch 1/30, Loss: 1.2938458919525146
# Epoch 1/30, Loss: 0.1770993024110794
# Epoch 1/30, Loss: 0.28956156969070435
# Epoch 1/30, Loss: 0.4538217782974243
# Epoch 1/30, Loss: 0.11096227169036865
# Epoch 1/30, Loss: 0.19720886647701263
# Epoch 1/30, Loss: 0.7398379445075989
# Epoch 1/30, Loss: 31.1318416595459
# Epoch 1/30, Loss: 0.2883262634277344
# Epoch 1/30, Loss: 0.5985748767852783
# Epoch 1/30, Loss: 0.547698438167572
# Epoch 1/30, Loss: 1.150447130203247
# Epoch 1/30, Loss: 0.26326197385787964
# Epoch 1/30, Loss: 0.2523377239704132
# Epoch 1/30, Loss: 0.5941798090934753
# Epoch 1/30, Eval Loss: 3.394498709302682
# Epoch 2/30, Loss: 28.3870849609375
# Epoch 2/30, Loss: 0.21214769780635834
# Epoch 2/30, Loss: 0.3798982501029968
# Epoch 2/30, Loss: 1.3593820333480835
# Epoch 2/30, Loss: 0.6661170721054077
# Epoch 2/30, Loss: 0.22544001042842865
# Epoch 2/30, Loss: 0.22174911201000214
# Epoch 2/30, Loss: 0.05270294100046158
# Epoch 2/30, Loss: 0.11572857201099396
# Epoch 2/30, Loss: 6.3406267166137695
# Epoch 2/30, Loss: 0.1898089200258255
# Epoch 2/30, Loss: 0.0829966589808464
# Epoch 2/30, Loss: 0.12638509273529053
# Epoch 2/30, Loss: 0.2843928337097168
# Epoch 2/30, Loss: 0.22656315565109253
# Epoch 2/30, Loss: 1.148139238357544
# Epoch 2/30, Loss: 0.16270631551742554
# Epoch 2/30, Loss: 0.26615843176841736
# Epoch 2/30, Loss: 0.3566637635231018
# Epoch 2/30, Loss: 0.16162583231925964
# Epoch 2/30, Loss: 0.15467844903469086
# Epoch 2/30, Loss: 0.11314306408166885
# Epoch 2/30, Loss: 0.1463651806116104
# Epoch 2/30, Loss: 0.09122582525014877
# Epoch 2/30, Loss: 0.25358712673187256
# Epoch 2/30, Loss: 0.10737190395593643
# Epoch 2/30, Loss: 0.5019546747207642
# Epoch 2/30, Loss: 0.2511887550354004
# Epoch 2/30, Loss: 0.30437418818473816
# Epoch 2/30, Loss: 0.08870165795087814
# Epoch 2/30, Loss: 0.15188997983932495
# Epoch 2/30, Loss: 1.3445210456848145
# Epoch 2/30, Loss: 0.14868372678756714
# Epoch 2/30, Loss: 0.7986998558044434
# Epoch 2/30, Loss: 0.2292172610759735
# Epoch 2/30, Loss: 0.23630928993225098
# Epoch 2/30, Loss: 0.16033649444580078
# Epoch 2/30, Loss: 0.21680930256843567
# Epoch 2/30, Loss: 0.047416314482688904
# Epoch 2/30, Loss: 0.2927137017250061
# Epoch 2/30, Loss: 0.3928150534629822
# Epoch 2/30, Loss: 0.08059301972389221
# Epoch 2/30, Loss: 0.11232100427150726
# Epoch 2/30, Loss: 0.2571002244949341
# Epoch 2/30, Loss: 0.2990914285182953
# Epoch 2/30, Loss: 0.48768532276153564
# Epoch 2/30, Loss: 0.23955923318862915
# Epoch 2/30, Loss: 0.08610992133617401
# Epoch 2/30, Loss: 0.2871433198451996
# Epoch 2/30, Loss: 0.12061757594347
# Epoch 2/30, Loss: 1.9332447052001953
# Epoch 2/30, Loss: 0.3099583387374878
# Epoch 2/30, Loss: 0.2557387351989746
# Epoch 2/30, Loss: 0.083588145673275
# Epoch 2/30, Loss: 0.13410982489585876
# Epoch 2/30, Loss: 0.21879777312278748
# Epoch 2/30, Loss: 0.19840428233146667
# Epoch 2/30, Loss: 0.15652547776699066
# Epoch 2/30, Loss: 0.18445181846618652
# Epoch 2/30, Loss: 0.11197271198034286
# Epoch 2/30, Loss: 0.14518606662750244
# Epoch 2/30, Loss: 0.07499592751264572
# Epoch 2/30, Loss: 0.06737987697124481
# Epoch 2/30, Loss: 16.703275680541992
# Epoch 2/30, Loss: 0.5716237425804138
# Epoch 2/30, Loss: 0.1655142605304718
# Epoch 2/30, Loss: 0.23717445135116577
# Epoch 2/30, Loss: 0.5775390267372131
# Epoch 2/30, Loss: 0.19578012824058533
# Epoch 2/30, Loss: 0.27142852544784546
# Epoch 2/30, Loss: 0.23288747668266296
# Epoch 2/30, Loss: 0.14603286981582642
# Epoch 2/30, Loss: 0.1099037230014801
# Epoch 2/30, Loss: 0.08010121434926987
# Epoch 2/30, Loss: 0.471329927444458
# Epoch 2/30, Loss: 0.07070828974246979
# Epoch 2/30, Loss: 0.5591784119606018
# Epoch 2/30, Loss: 0.6425247192382812
# Epoch 2/30, Loss: 0.29396557807922363
# Epoch 2/30, Loss: 8.7657470703125
# Epoch 2/30, Loss: 0.1743534505367279
# Epoch 2/30, Loss: 0.19228234887123108
# Epoch 2/30, Loss: 0.3413776159286499
# Epoch 2/30, Loss: 0.3007872700691223
# Epoch 2/30, Loss: 0.16781747341156006
# Epoch 2/30, Loss: 0.15545031428337097
# Epoch 2/30, Loss: 0.1722358912229538
# Epoch 2/30, Loss: 0.0974227711558342
# Epoch 2/30, Loss: 0.05883677303791046
# Epoch 2/30, Loss: 0.16166815161705017
# Epoch 2/30, Loss: 0.18576011061668396
# Epoch 2/30, Loss: 0.22006361186504364
# Epoch 2/30, Loss: 0.9278470873832703
# Epoch 2/30, Loss: 1.5877732038497925
# Epoch 2/30, Loss: 0.09527686983346939
# Epoch 2/30, Loss: 0.19937193393707275
# Epoch 2/30, Loss: 0.2590930461883545
# Epoch 2/30, Loss: 0.13852165639400482
# Epoch 2/30, Loss: 0.2937811613082886
# Epoch 2/30, Loss: 0.1980871707201004
# Epoch 2/30, Loss: 0.0807553380727768
# Epoch 2/30, Loss: 0.21564652025699615
# Epoch 2/30, Loss: 0.21931402385234833
# Epoch 2/30, Loss: 0.11339935660362244
# Epoch 2/30, Loss: 0.3641605079174042
# Epoch 2/30, Loss: 10.63879108428955
# Epoch 2/30, Loss: 0.49646589159965515
# Epoch 2/30, Loss: 0.1580030620098114
# Epoch 2/30, Loss: 0.24816957116127014
# Epoch 2/30, Loss: 0.26949542760849
# Epoch 2/30, Loss: 0.12574425339698792
# Epoch 2/30, Loss: 0.10359187424182892
# Epoch 2/30, Loss: 0.3054375946521759
# Epoch 2/30, Loss: 0.43457940220832825
# Epoch 2/30, Loss: 0.41916292905807495
# Epoch 2/30, Loss: 0.4245397746562958
# Epoch 2/30, Loss: 0.17634637653827667
# Epoch 2/30, Loss: 0.17131564021110535
# Epoch 2/30, Loss: 0.08207380771636963
# Epoch 2/30, Loss: 0.5216552019119263
# Epoch 2/30, Loss: 0.15402460098266602
# Epoch 2/30, Loss: 1.33652663230896
# Epoch 2/30, Loss: 0.430842787027359
# Epoch 2/30, Loss: 0.12822291254997253
# Epoch 2/30, Loss: 1.859473466873169
# Epoch 2/30, Loss: 0.1608867645263672
# Epoch 2/30, Loss: 0.5639727115631104
# Epoch 2/30, Loss: 0.1570051610469818
# Epoch 2/30, Loss: 0.2958812117576599
# Epoch 2/30, Loss: 0.18714691698551178
# Epoch 2/30, Loss: 0.8668598532676697
# Epoch 2/30, Loss: 0.12964510917663574
# Epoch 2/30, Loss: 0.14926117658615112
# Epoch 2/30, Loss: 0.10508465766906738
# Epoch 2/30, Loss: 0.1775386929512024
# Epoch 2/30, Loss: 0.2891114056110382
# Epoch 2/30, Loss: 0.09880048036575317
# Epoch 2/30, Loss: 0.15652842819690704
# Epoch 2/30, Loss: 0.20795096457004547
# Epoch 2/30, Loss: 0.16342195868492126
# Epoch 2/30, Loss: 2.284111738204956
# Epoch 2/30, Loss: 0.07899025827646255
# Epoch 2/30, Loss: 0.20017558336257935
# Epoch 2/30, Loss: 0.13603530824184418
# Epoch 2/30, Loss: 0.08531324565410614
# Epoch 2/30, Loss: 0.192909836769104
# Epoch 2/30, Loss: 0.9308986067771912
# Epoch 2/30, Loss: 0.11114643514156342
# Epoch 2/30, Loss: 0.5121653079986572
# Epoch 2/30, Loss: 0.11054620146751404
# Epoch 2/30, Loss: 0.13771048188209534
# Epoch 2/30, Loss: 0.18739323318004608
# Epoch 2/30, Loss: 0.050808489322662354
# Epoch 2/30, Loss: 0.0800093337893486
# Epoch 2/30, Loss: 2.4014267921447754
# Epoch 2/30, Loss: 0.06460794806480408
# Epoch 2/30, Loss: 0.6725218296051025
# Epoch 2/30, Loss: 0.18185457587242126
# Epoch 2/30, Loss: 0.12616994976997375
# Epoch 2/30, Loss: 6.178548812866211
# Epoch 2/30, Loss: 0.13946303725242615
# Epoch 2/30, Loss: 0.11333557963371277
# Epoch 2/30, Loss: 0.23796731233596802
# Epoch 2/30, Loss: 0.28292539715766907
# Epoch 2/30, Loss: 0.10648849606513977
# Epoch 2/30, Loss: 0.255220502614975
# Epoch 2/30, Loss: 0.12112417072057724
# Epoch 2/30, Loss: 0.2520846128463745
# Epoch 2/30, Loss: 6.129316806793213
# Epoch 2/30, Loss: 4.584966659545898
# Epoch 2/30, Loss: 0.2555654048919678
# Epoch 2/30, Loss: 0.4771604537963867
# Epoch 2/30, Loss: 1.4465467929840088
# Epoch 2/30, Loss: 1.0363609790802002
# Epoch 2/30, Loss: 3.8324692249298096
# Epoch 2/30, Loss: 0.3108435869216919
# Epoch 2/30, Loss: 0.45755505561828613
# Epoch 2/30, Loss: 0.24677090346813202
# Epoch 2/30, Loss: 0.12514162063598633
# Epoch 2/30, Loss: 0.16033720970153809
# Epoch 2/30, Loss: 0.3447577953338623
# Epoch 2/30, Loss: 0.07808402925729752
# Epoch 2/30, Loss: 0.0851144939661026
# Epoch 2/30, Loss: 2.209587574005127
# Epoch 2/30, Loss: 0.19443246722221375
# Epoch 2/30, Loss: 0.14062456786632538
# Epoch 2/30, Loss: 0.21637949347496033
# Epoch 2/30, Loss: 0.21433620154857635
# Epoch 2/30, Loss: 0.26129838824272156
# Epoch 2/30, Loss: 0.15768373012542725
# Epoch 2/30, Loss: 0.29859602451324463
# Epoch 2/30, Loss: 2.720864772796631
# Epoch 2/30, Loss: 0.18038128316402435
# Epoch 2/30, Loss: 0.17676013708114624
# Epoch 2/30, Loss: 0.3072999119758606
# Epoch 2/30, Loss: 0.17473773658275604
# Epoch 2/30, Loss: 0.2522687315940857
# Epoch 2/30, Loss: 0.30939438939094543
# Epoch 2/30, Loss: 0.312425434589386
# Epoch 2/30, Loss: 0.32995593547821045
# Epoch 2/30, Loss: 0.36886513233184814
# Epoch 2/30, Loss: 0.07192912697792053
# Epoch 2/30, Loss: 0.08423076570034027
# Epoch 2/30, Loss: 0.5465571880340576
# Epoch 2/30, Loss: 0.5179056525230408
# Epoch 2/30, Loss: 0.3276664614677429
# Epoch 2/30, Loss: 0.08697430789470673
# Epoch 2/30, Loss: 0.042647603899240494
# Epoch 2/30, Loss: 0.16281309723854065
# Epoch 2/30, Loss: 0.07988406717777252
# Epoch 2/30, Loss: 0.26624464988708496
# Epoch 2/30, Loss: 2.2185611724853516
# Epoch 2/30, Loss: 2.078688383102417
# Epoch 2/30, Loss: 0.25696247816085815
# Epoch 2/30, Loss: 0.153432697057724
# Epoch 2/30, Loss: 0.2086600512266159
# Epoch 2/30, Eval Loss: 3.1215866213807693
# Epoch 3/30, Loss: 0.3977167010307312
# Epoch 3/30, Loss: 0.1377028375864029
# Epoch 3/30, Loss: 0.1483805626630783
# Epoch 3/30, Loss: 3.0013818740844727
# Epoch 3/30, Loss: 1.2264264822006226
# Epoch 3/30, Loss: 0.5877190232276917
# Epoch 3/30, Loss: 0.1503618359565735
# Epoch 3/30, Loss: 0.151749849319458
# Epoch 3/30, Loss: 0.2991856336593628
# Epoch 3/30, Loss: 0.18657159805297852
# Epoch 3/30, Loss: 0.0889788493514061
# Epoch 3/30, Loss: 0.3280608057975769
# Epoch 3/30, Loss: 0.14450915157794952
# Epoch 3/30, Loss: 0.14079220592975616
# Epoch 3/30, Loss: 0.08984832465648651
# Epoch 3/30, Loss: 0.24884197115898132
# Epoch 3/30, Loss: 0.05752137303352356
# Epoch 3/30, Loss: 0.06294494867324829
# Epoch 3/30, Loss: 0.854786217212677
# Epoch 3/30, Loss: 0.1078002005815506
# Epoch 3/30, Loss: 0.45756852626800537
# Epoch 3/30, Loss: 0.11799924075603485
# Epoch 3/30, Loss: 0.30968382954597473
# Epoch 3/30, Loss: 0.1313353180885315
# Epoch 3/30, Loss: 0.260922908782959
# Epoch 3/30, Loss: 0.16978007555007935
# Epoch 3/30, Loss: 0.1644909679889679
# Epoch 3/30, Loss: 1.0036616325378418
# Epoch 3/30, Loss: 0.09269201010465622
# Epoch 3/30, Loss: 0.08641598373651505
# Epoch 3/30, Loss: 0.12147513031959534
# Epoch 3/30, Loss: 0.24014435708522797
# Epoch 3/30, Loss: 0.1412033885717392
# Epoch 3/30, Loss: 0.15833860635757446
# Epoch 3/30, Loss: 0.10159249603748322
# Epoch 3/30, Loss: 0.1450887769460678
# Epoch 3/30, Loss: 0.06963090598583221
# Epoch 3/30, Loss: 0.07446443289518356
# Epoch 3/30, Loss: 1.4696751832962036
# Epoch 3/30, Loss: 0.3235684037208557
# Epoch 3/30, Loss: 0.11557002365589142
# Epoch 3/30, Loss: 0.14366482198238373
# Epoch 3/30, Loss: 0.25360995531082153
# Epoch 3/30, Loss: 0.13671010732650757
# Epoch 3/30, Loss: 0.12708531320095062
# Epoch 3/30, Loss: 2.008969783782959
# Epoch 3/30, Loss: 0.18164058029651642
# Epoch 3/30, Loss: 0.18128357827663422
# Epoch 3/30, Loss: 0.1392602026462555
# Epoch 3/30, Loss: 0.16725371778011322
# Epoch 3/30, Loss: 0.05683489516377449
# Epoch 3/30, Loss: 0.4180016815662384
# Epoch 3/30, Loss: 0.5722100138664246
# Epoch 3/30, Loss: 0.11300784349441528
# Epoch 3/30, Loss: 0.5196871757507324
# Epoch 3/30, Loss: 1.4475466012954712
# Epoch 3/30, Loss: 0.11874494701623917
# Epoch 3/30, Loss: 0.22127322852611542
# Epoch 3/30, Loss: 0.1663590967655182
# Epoch 3/30, Loss: 0.07789815217256546
# Epoch 3/30, Loss: 0.17413076758384705
# Epoch 3/30, Loss: 0.24160616099834442
# Epoch 3/30, Loss: 0.07885445654392242
# Epoch 3/30, Loss: 0.11008848249912262
# Epoch 3/30, Loss: 0.1497076153755188
# Epoch 3/30, Loss: 0.32811838388442993
# Epoch 3/30, Loss: 0.3490719199180603
# Epoch 3/30, Loss: 2.4512946605682373
# Epoch 3/30, Loss: 0.09217178821563721
# Epoch 3/30, Loss: 1.123647689819336
# Epoch 3/30, Loss: 0.1568400263786316
# Epoch 3/30, Loss: 0.3687702417373657
# Epoch 3/30, Loss: 0.5089291334152222
# Epoch 3/30, Loss: 0.2851247191429138
# Epoch 3/30, Loss: 0.2950592637062073
# Epoch 3/30, Loss: 2.8403210639953613
# Epoch 3/30, Loss: 0.18756935000419617
# Epoch 3/30, Loss: 1.5239211320877075
# Epoch 3/30, Loss: 0.0829148143529892
# Epoch 3/30, Loss: 0.22084727883338928
# Epoch 3/30, Loss: 0.3210296630859375
# Epoch 3/30, Loss: 0.12683145701885223
# Epoch 3/30, Loss: 0.12825722992420197
# Epoch 3/30, Loss: 0.7621669769287109
# Epoch 3/30, Loss: 0.2710384130477905
# Epoch 3/30, Loss: 0.2992721199989319
# Epoch 3/30, Loss: 0.2859058976173401
# Epoch 3/30, Loss: 0.20568659901618958
# Epoch 3/30, Loss: 0.29407232999801636
# Epoch 3/30, Loss: 0.2801041901111603
# Epoch 3/30, Loss: 0.08513196557760239
# Epoch 3/30, Loss: 0.22207984328269958
# Epoch 3/30, Loss: 0.21931225061416626
# Epoch 3/30, Loss: 0.2128133773803711
# Epoch 3/30, Loss: 0.15153828263282776
# Epoch 3/30, Loss: 0.4237348735332489
# Epoch 3/30, Loss: 0.07411770522594452
# Epoch 3/30, Loss: 0.13125039637088776
# Epoch 3/30, Loss: 0.1625925749540329
# Epoch 3/30, Loss: 4.420578956604004
# Epoch 3/30, Loss: 0.7774679660797119
# Epoch 3/30, Loss: 0.31178680062294006
# Epoch 3/30, Loss: 0.294481486082077
# Epoch 3/30, Loss: 0.40583693981170654
# Epoch 3/30, Loss: 0.3105592727661133
# Epoch 3/30, Loss: 0.30464157462120056
# Epoch 3/30, Loss: 0.11048170924186707
# Epoch 3/30, Loss: 0.15861785411834717
# Epoch 3/30, Loss: 0.7381196618080139
# Epoch 3/30, Loss: 0.1658061295747757
# Epoch 3/30, Loss: 0.1811068058013916
# Epoch 3/30, Loss: 0.8350966572761536
# Epoch 3/30, Loss: 0.09249848872423172
# Epoch 3/30, Loss: 0.4374040961265564
# Epoch 3/30, Loss: 0.29791560769081116
# Epoch 3/30, Loss: 0.051280949264764786
# Epoch 3/30, Loss: 0.1453099250793457
# Epoch 3/30, Loss: 0.12811416387557983
# Epoch 3/30, Loss: 0.12001416087150574
# Epoch 3/30, Loss: 0.22581520676612854
# Epoch 3/30, Loss: 0.10691628605127335
# Epoch 3/30, Loss: 0.08317141234874725
# Epoch 3/30, Loss: 0.14680983126163483
# Epoch 3/30, Loss: 1.884922742843628
# Epoch 3/30, Loss: 0.07462868094444275
# Epoch 3/30, Loss: 0.20472964644432068
# Epoch 3/30, Loss: 0.31198832392692566
# Epoch 3/30, Loss: 0.11858923733234406
# Epoch 3/30, Loss: 0.1607801914215088
# Epoch 3/30, Loss: 0.18332397937774658
# Epoch 3/30, Loss: 2.371202230453491
# Epoch 3/30, Loss: 0.5757356882095337
# Epoch 3/30, Loss: 1.0405915975570679
# Epoch 3/30, Loss: 1.3797852993011475
# Epoch 3/30, Loss: 0.10845111310482025
# Epoch 3/30, Loss: 0.09875350445508957
# Epoch 3/30, Loss: 0.09018348157405853
# Epoch 3/30, Loss: 0.18847933411598206
# Epoch 3/30, Loss: 0.13144788146018982
# Epoch 3/30, Loss: 2.736386775970459
# Epoch 3/30, Loss: 0.13474853336811066
# Epoch 3/30, Loss: 0.35193097591400146
# Epoch 3/30, Loss: 10.207890510559082
# Epoch 3/30, Loss: 2.250337839126587
# Epoch 3/30, Loss: 0.31794410943984985
# Epoch 3/30, Loss: 1.9493868350982666
# Epoch 3/30, Loss: 0.6285452842712402
# Epoch 3/30, Loss: 0.1321084201335907
# Epoch 3/30, Loss: 0.24707871675491333
# Epoch 3/30, Loss: 0.17215070128440857
# Epoch 3/30, Loss: 0.3425857424736023
# Epoch 3/30, Loss: 0.17044346034526825
# Epoch 3/30, Loss: 0.4065764248371124
# Epoch 3/30, Loss: 0.07842686772346497
# Epoch 3/30, Loss: 0.1475965976715088
# Epoch 3/30, Loss: 0.34818094968795776
# Epoch 3/30, Loss: 0.5119318962097168
# Epoch 3/30, Loss: 0.3674774765968323
# Epoch 3/30, Loss: 0.18466615676879883
# Epoch 3/30, Loss: 0.1392151415348053
# Epoch 3/30, Loss: 0.3398945927619934
# Epoch 3/30, Loss: 0.1706504225730896
# Epoch 3/30, Loss: 0.20922337472438812
# Epoch 3/30, Loss: 0.16588130593299866
# Epoch 3/30, Loss: 0.11587578058242798
# Epoch 3/30, Loss: 0.209406778216362
# Epoch 3/30, Loss: 0.12141504883766174
# Epoch 3/30, Loss: 0.07037938386201859
# Epoch 3/30, Loss: 0.21740755438804626
# Epoch 3/30, Loss: 0.19962355494499207
# Epoch 3/30, Loss: 0.1886884868144989
# Epoch 3/30, Loss: 0.16744214296340942
# Epoch 3/30, Loss: 0.08811009675264359
# Epoch 3/30, Loss: 0.1853761076927185
# Epoch 3/30, Loss: 1.2970447540283203
# Epoch 3/30, Loss: 0.26871028542518616
# Epoch 3/30, Loss: 0.13961553573608398
# Epoch 3/30, Loss: 12.424259185791016
# Epoch 3/30, Loss: 0.2837463915348053
# Epoch 3/30, Loss: 0.25280994176864624
# Epoch 3/30, Loss: 0.2959757447242737
# Epoch 3/30, Loss: 0.2751203179359436
# Epoch 3/30, Loss: 0.3314715623855591
# Epoch 3/30, Loss: 0.09531295299530029
# Epoch 3/30, Loss: 0.19390767812728882
# Epoch 3/30, Loss: 0.32872942090034485
# Epoch 3/30, Loss: 0.06583312153816223
# Epoch 3/30, Loss: 0.07569079101085663
# Epoch 3/30, Loss: 0.23591257631778717
# Epoch 3/30, Loss: 0.20481309294700623
# Epoch 3/30, Loss: 0.16464978456497192
# Epoch 3/30, Loss: 0.18839989602565765
# Epoch 3/30, Loss: 0.14041468501091003
# Epoch 3/30, Loss: 0.8097671866416931
# Epoch 3/30, Loss: 0.1922193467617035
# Epoch 3/30, Loss: 0.20236676931381226
# Epoch 3/30, Loss: 0.16481541097164154
# Epoch 3/30, Loss: 0.19610849022865295
# Epoch 3/30, Loss: 0.13344189524650574
# Epoch 3/30, Loss: 0.19903643429279327
# Epoch 3/30, Loss: 0.1942497193813324
# Epoch 3/30, Loss: 0.25639110803604126
# Epoch 3/30, Loss: 0.4802442491054535
# Epoch 3/30, Loss: 0.09193065762519836
# Epoch 3/30, Loss: 0.1360236406326294
# Epoch 3/30, Loss: 0.12318439781665802
# Epoch 3/30, Loss: 0.09720064699649811
# Epoch 3/30, Loss: 0.17739109694957733
# Epoch 3/30, Loss: 0.24706849455833435
# Epoch 3/30, Loss: 0.23799248039722443
# Epoch 3/30, Loss: 0.5657907724380493
# Epoch 3/30, Loss: 0.5273872017860413
# Epoch 3/30, Loss: 0.18233415484428406
# Epoch 3/30, Loss: 0.16233094036579132
# Epoch 3/30, Loss: 0.1134539470076561
# Epoch 3/30, Loss: 0.07379747182130814
# Epoch 3/30, Eval Loss: 3.1690366119146347
# Epoch 4/30, Loss: 0.26276472210884094
# Epoch 4/30, Loss: 0.1659054011106491
# Epoch 4/30, Loss: 0.22650404274463654
# Epoch 4/30, Loss: 0.5732358694076538
# Epoch 4/30, Loss: 0.7068372368812561
# Epoch 4/30, Loss: 0.08597975969314575
# Epoch 4/30, Loss: 0.2476007044315338
# Epoch 4/30, Loss: 0.16917094588279724
# Epoch 4/30, Loss: 0.21730393171310425
# Epoch 4/30, Loss: 0.25035908818244934
# Epoch 4/30, Loss: 0.15770801901817322
# Epoch 4/30, Loss: 0.12528246641159058
# Epoch 4/30, Loss: 0.3143533170223236
# Epoch 4/30, Loss: 0.163890540599823
# Epoch 4/30, Loss: 0.13045182824134827
# Epoch 4/30, Loss: 0.10476288944482803
# Epoch 4/30, Loss: 0.12315802276134491
# Epoch 4/30, Loss: 0.16139404475688934
# Epoch 4/30, Loss: 0.20537221431732178
# Epoch 4/30, Loss: 0.0319511704146862
# Epoch 4/30, Loss: 0.2911805808544159
# Epoch 4/30, Loss: 0.10598315298557281
# Epoch 4/30, Loss: 0.131852924823761
# Epoch 4/30, Loss: 0.20710943639278412
# Epoch 4/30, Loss: 0.12773165106773376
# Epoch 4/30, Loss: 0.0886264443397522
# Epoch 4/30, Loss: 2.1075687408447266
# Epoch 4/30, Loss: 0.1203782707452774
# Epoch 4/30, Loss: 0.7992965579032898
# Epoch 4/30, Loss: 0.15758004784584045
# Epoch 4/30, Loss: 0.12904304265975952
# Epoch 4/30, Loss: 0.31572985649108887
# Epoch 4/30, Loss: 0.13860689103603363
# Epoch 4/30, Loss: 0.10952483862638474
# Epoch 4/30, Loss: 0.08373574167490005
# Epoch 4/30, Loss: 0.15915976464748383
# Epoch 4/30, Loss: 1.1366628408432007
# Epoch 4/30, Loss: 0.14715754985809326
# Epoch 4/30, Loss: 0.36830031871795654
# Epoch 4/30, Loss: 0.11628300696611404
# Epoch 4/30, Loss: 0.11761146783828735
# Epoch 4/30, Loss: 0.11326642334461212
# Epoch 4/30, Loss: 0.1587122082710266
# Epoch 4/30, Loss: 0.2750128507614136
# Epoch 4/30, Loss: 0.21154052019119263
# Epoch 4/30, Loss: 0.22076182067394257
# Epoch 4/30, Loss: 0.08440844714641571
# Epoch 4/30, Loss: 0.19881968200206757
# Epoch 4/30, Loss: 0.285938024520874
# Epoch 4/30, Loss: 0.37220704555511475
# Epoch 4/30, Loss: 0.07796356081962585
# Epoch 4/30, Loss: 0.14889127016067505
# Epoch 4/30, Loss: 0.15690504014492035
# Epoch 4/30, Loss: 0.2765636444091797
# Epoch 4/30, Loss: 0.11492224037647247
# Epoch 4/30, Loss: 0.17455650866031647
# Epoch 4/30, Loss: 0.23861967027187347
# Epoch 4/30, Loss: 0.24968570470809937
# Epoch 4/30, Loss: 0.15242168307304382
# Epoch 4/30, Loss: 1.0426504611968994
# Epoch 4/30, Loss: 0.08296577632427216
# Epoch 4/30, Loss: 0.06532741338014603
# Epoch 4/30, Loss: 0.19741272926330566
# Epoch 4/30, Loss: 0.4405803084373474
# Epoch 4/30, Loss: 1.0983132123947144
# Epoch 4/30, Loss: 0.24687400460243225
# Epoch 4/30, Loss: 0.16854560375213623
# Epoch 4/30, Loss: 0.10783158242702484
# Epoch 4/30, Loss: 0.16923558712005615
# Epoch 4/30, Loss: 0.08482466638088226
# Epoch 4/30, Loss: 0.34260812401771545
# Epoch 4/30, Loss: 0.106935515999794
# Epoch 4/30, Loss: 0.27868643403053284
# Epoch 4/30, Loss: 0.13740569353103638
# Epoch 4/30, Loss: 0.13604268431663513
# Epoch 4/30, Loss: 0.3252354562282562
# Epoch 4/30, Loss: 0.2973036766052246
# Epoch 4/30, Loss: 0.059594422578811646
# Epoch 4/30, Loss: 0.14783123135566711
# Epoch 4/30, Loss: 0.09858295321464539
# Epoch 4/30, Loss: 0.0921909436583519
# Epoch 4/30, Loss: 0.11243585497140884
# Epoch 4/30, Loss: 0.2640053927898407
# Epoch 4/30, Loss: 0.08242309093475342
# Epoch 4/30, Loss: 0.13162484765052795
# Epoch 4/30, Loss: 0.08650460094213486
# Epoch 4/30, Loss: 1.363476276397705
# Epoch 4/30, Loss: 0.09636738896369934
# Epoch 4/30, Loss: 1.5321950912475586
# Epoch 4/30, Loss: 0.21016396582126617
# Epoch 4/30, Loss: 0.09164570271968842
# Epoch 4/30, Loss: 0.12605679035186768
# Epoch 4/30, Loss: 0.3509071171283722
# Epoch 4/30, Loss: 0.17345380783081055
# Epoch 4/30, Loss: 0.17381609976291656
# Epoch 4/30, Loss: 0.1236720159649849
# Epoch 4/30, Loss: 0.18040406703948975
# Epoch 4/30, Loss: 0.4182025194168091
# Epoch 4/30, Loss: 0.4507070779800415
# Epoch 4/30, Loss: 0.19692528247833252
# Epoch 4/30, Loss: 0.1196906790137291
# Epoch 4/30, Loss: 0.2064962536096573
# Epoch 4/30, Loss: 0.07905280590057373
# Epoch 4/30, Loss: 0.14712443947792053
# Epoch 4/30, Loss: 0.46958795189857483
# Epoch 4/30, Loss: 0.33337515592575073
# Epoch 4/30, Loss: 0.10681246221065521
# Epoch 4/30, Loss: 0.12058153748512268
# Epoch 4/30, Loss: 0.6104350686073303
# Epoch 4/30, Loss: 0.8930094838142395
# Epoch 4/30, Loss: 0.213669091463089
# Epoch 4/30, Loss: 0.19832949340343475
# Epoch 4/30, Loss: 0.1993541419506073
# Epoch 4/30, Loss: 0.1413341462612152
# Epoch 4/30, Loss: 1.4633564949035645
# Epoch 4/30, Loss: 0.14415785670280457
# Epoch 4/30, Loss: 0.40637898445129395
# Epoch 4/30, Loss: 0.25181329250335693
# Epoch 4/30, Loss: 0.23250322043895721
# Epoch 4/30, Loss: 0.16519951820373535
# Epoch 4/30, Loss: 0.174803227186203
# Epoch 4/30, Loss: 0.11759014427661896
# Epoch 4/30, Loss: 0.11342711746692657
# Epoch 4/30, Loss: 0.1236581951379776
# Epoch 4/30, Loss: 0.21236272156238556
# Epoch 4/30, Loss: 0.08067461103200912
# Epoch 4/30, Loss: 0.18388772010803223
# Epoch 4/30, Loss: 2.156952142715454
# Epoch 4/30, Loss: 0.4036678075790405
# Epoch 4/30, Loss: 0.1569448858499527
# Epoch 4/30, Loss: 0.39893847703933716
# Epoch 4/30, Loss: 0.2855920195579529
# Epoch 4/30, Loss: 0.19284221529960632
# Epoch 4/30, Loss: 0.1711883842945099
# Epoch 4/30, Loss: 0.2057393193244934
# Epoch 4/30, Loss: 0.22486193478107452
# Epoch 4/30, Loss: 0.18445831537246704
# Epoch 4/30, Loss: 0.24096176028251648
# Epoch 4/30, Loss: 0.09826619923114777
# Epoch 4/30, Loss: 0.1601700335741043
# Epoch 4/30, Loss: 0.154452845454216
# Epoch 4/30, Loss: 0.17049871385097504
# Epoch 4/30, Loss: 0.08062753081321716
# Epoch 4/30, Loss: 0.32640641927719116
# Epoch 4/30, Loss: 0.16250789165496826
# Epoch 4/30, Loss: 0.16685372591018677
# Epoch 4/30, Loss: 0.20457282662391663
# Epoch 4/30, Loss: 0.20246967673301697
# Epoch 4/30, Loss: 0.4030628204345703
# Epoch 4/30, Loss: 0.14912694692611694
# Epoch 4/30, Loss: 0.4625847041606903
# Epoch 4/30, Loss: 0.17624276876449585
# Epoch 4/30, Loss: 0.19509929418563843
# Epoch 4/30, Loss: 4.857193470001221
# Epoch 4/30, Loss: 0.11551088094711304
# Epoch 4/30, Loss: 0.2421562671661377
# Epoch 4/30, Loss: 0.12003058195114136
# Epoch 4/30, Loss: 0.10840865224599838
# Epoch 4/30, Loss: 0.341821551322937
# Epoch 4/30, Loss: 0.10721494257450104
# Epoch 4/30, Loss: 1.97445809841156
# Epoch 4/30, Loss: 0.19722434878349304
# Epoch 4/30, Loss: 0.2371058315038681
# Epoch 4/30, Loss: 0.19369737803936005
# Epoch 4/30, Loss: 0.0878039225935936
# Epoch 4/30, Loss: 0.13079634308815002
# Epoch 4/30, Loss: 0.12094859778881073
# Epoch 4/30, Loss: 0.32689446210861206
# Epoch 4/30, Loss: 0.6891307234764099
# Epoch 4/30, Loss: 0.1267727017402649
# Epoch 4/30, Loss: 0.09553490579128265
# Epoch 4/30, Loss: 0.06932978332042694
# Epoch 4/30, Loss: 0.1370120495557785
# Epoch 4/30, Loss: 0.21782535314559937
# Epoch 4/30, Loss: 0.15061558783054352
# Epoch 4/30, Loss: 0.14823612570762634
# Epoch 4/30, Loss: 0.1340211033821106
# Epoch 4/30, Loss: 0.6579784154891968
# Epoch 4/30, Loss: 0.07142937183380127
# Epoch 4/30, Loss: 0.26462218165397644
# Epoch 4/30, Loss: 0.05625644326210022
# Epoch 4/30, Loss: 0.10951109975576401
# Epoch 4/30, Loss: 0.8540225625038147
# Epoch 4/30, Loss: 0.4791739881038666
# Epoch 4/30, Loss: 0.19460529088974
# Epoch 4/30, Loss: 3.754342794418335
# Epoch 4/30, Loss: 0.14456523954868317
# Epoch 4/30, Loss: 0.1873675137758255
# Epoch 4/30, Loss: 0.15902721881866455
# Epoch 4/30, Loss: 0.19000449776649475
# Epoch 4/30, Loss: 0.22510066628456116
# Epoch 4/30, Loss: 0.18530474603176117
# Epoch 4/30, Loss: 0.21916532516479492
# Epoch 4/30, Loss: 0.1618892103433609
# Epoch 4/30, Loss: 0.4048194885253906
# Epoch 4/30, Loss: 0.15511995553970337
# Epoch 4/30, Loss: 0.11659057438373566
# Epoch 4/30, Loss: 0.1825486719608307
# Epoch 4/30, Loss: 0.10184603184461594
# Epoch 4/30, Loss: 0.24029934406280518
# Epoch 4/30, Loss: 0.1979137659072876
# Epoch 4/30, Loss: 0.14476865530014038
# Epoch 4/30, Loss: 0.09684312343597412
# Epoch 4/30, Loss: 0.19707731902599335
# Epoch 4/30, Loss: 0.3825886845588684
# Epoch 4/30, Loss: 0.18843013048171997
# Epoch 4/30, Loss: 0.18965230882167816
# Epoch 4/30, Loss: 0.4265756607055664
# Epoch 4/30, Loss: 0.07496099919080734
# Epoch 4/30, Loss: 0.11317715048789978
# Epoch 4/30, Loss: 0.1748683750629425
# Epoch 4/30, Loss: 0.2598213851451874
# Epoch 4/30, Loss: 0.17507606744766235
# Epoch 4/30, Loss: 0.15922757983207703
# Epoch 4/30, Loss: 0.10524548590183258
# Epoch 4/30, Loss: 0.0807901918888092
# Epoch 4/30, Eval Loss: 3.2526042255071492
# Epoch 5/30, Loss: 0.14407652616500854
# Epoch 5/30, Loss: 0.13134954869747162
# Epoch 5/30, Loss: 0.07376808673143387
# Epoch 5/30, Loss: 0.2241511195898056
# Epoch 5/30, Loss: 0.15032082796096802
# Epoch 5/30, Loss: 0.12766200304031372
# Epoch 5/30, Loss: 0.06638003140687943
# Epoch 5/30, Loss: 0.4337941110134125
# Epoch 5/30, Loss: 0.12338410317897797
# Epoch 5/30, Loss: 0.056613098829984665
# Epoch 5/30, Loss: 0.19027605652809143
# Epoch 5/30, Loss: 0.13081760704517365
# Epoch 5/30, Loss: 0.13611404597759247
# Epoch 5/30, Loss: 0.14389953017234802
# Epoch 5/30, Loss: 0.10159662365913391
# Epoch 5/30, Loss: 0.10445095598697662
# Epoch 5/30, Loss: 0.26758190989494324
# Epoch 5/30, Loss: 0.1007552295923233
# Epoch 5/30, Loss: 0.038798294961452484
# Epoch 5/30, Loss: 0.1377491056919098
# Epoch 5/30, Loss: 0.13515019416809082
# Epoch 5/30, Loss: 0.14666056632995605
# Epoch 5/30, Loss: 0.3027309775352478
# Epoch 5/30, Loss: 0.22551831603050232
# Epoch 5/30, Loss: 0.065060093998909
# Epoch 5/30, Loss: 0.09905650466680527
# Epoch 5/30, Loss: 0.28948062658309937
# Epoch 5/30, Loss: 0.1394970715045929
# Epoch 5/30, Loss: 0.11770390719175339
# Epoch 5/30, Loss: 0.13963332772254944
# Epoch 5/30, Loss: 0.10122334957122803
# Epoch 5/30, Loss: 0.10211794823408127
# Epoch 5/30, Loss: 0.20967106521129608
# Epoch 5/30, Loss: 0.15944011509418488
# Epoch 5/30, Loss: 0.16846077144145966
# Epoch 5/30, Loss: 0.33199024200439453
# Epoch 5/30, Loss: 0.12418602406978607
# Epoch 5/30, Loss: 0.2827310860157013
# Epoch 5/30, Loss: 0.1129499226808548
# Epoch 5/30, Loss: 0.24707306921482086
# Epoch 5/30, Loss: 0.12794914841651917
# Epoch 5/30, Loss: 0.20018626749515533
# Epoch 5/30, Loss: 0.0793408453464508
# Epoch 5/30, Loss: 0.10072176903486252
# Epoch 5/30, Loss: 0.09243081510066986
# Epoch 5/30, Loss: 0.49656885862350464
# Epoch 5/30, Loss: 0.10533340275287628
# Epoch 5/30, Loss: 0.1251274049282074
# Epoch 5/30, Loss: 0.07543309032917023
# Epoch 5/30, Loss: 0.15529261529445648
# Epoch 5/30, Loss: 0.28967177867889404
# Epoch 5/30, Loss: 0.08950014412403107
# Epoch 5/30, Loss: 0.12684135138988495
# Epoch 5/30, Loss: 0.36766961216926575
# Epoch 5/30, Loss: 0.10682578384876251
# Epoch 5/30, Loss: 0.1252211183309555
# Epoch 5/30, Loss: 0.5034416317939758
# Epoch 5/30, Loss: 0.3338084816932678
# Epoch 5/30, Loss: 0.14109034836292267
# Epoch 5/30, Loss: 0.2456715852022171
# Epoch 5/30, Loss: 0.1387035846710205
# Epoch 5/30, Loss: 0.24824213981628418
# Epoch 5/30, Loss: 0.1555362343788147
# Epoch 5/30, Loss: 0.10006079077720642
# Epoch 5/30, Loss: 0.1347166895866394
# Epoch 5/30, Loss: 0.35686272382736206
# Epoch 5/30, Loss: 0.09794557094573975
# Epoch 5/30, Loss: 0.30166736245155334
# Epoch 5/30, Loss: 0.2048960030078888
# Epoch 5/30, Loss: 0.12119430303573608
# Epoch 5/30, Loss: 0.07767203450202942
# Epoch 5/30, Loss: 0.22540634870529175
# Epoch 5/30, Loss: 0.7444733381271362
# Epoch 5/30, Loss: 0.13954773545265198
# Epoch 5/30, Loss: 0.1733904927968979
# Epoch 5/30, Loss: 0.19742102921009064
# Epoch 5/30, Loss: 0.1573670357465744
# Epoch 5/30, Loss: 0.38051652908325195
# Epoch 5/30, Loss: 0.2064151018857956
# Epoch 5/30, Loss: 0.06106200069189072
# Epoch 5/30, Loss: 0.1466360241174698
# Epoch 5/30, Loss: 0.15251463651657104
# Epoch 5/30, Loss: 0.07159356772899628
# Epoch 5/30, Loss: 0.09653546661138535
# Epoch 5/30, Loss: 0.07074860483407974
# Epoch 5/30, Loss: 0.0776819959282875
# Epoch 5/30, Loss: 0.40092727541923523
# Epoch 5/30, Loss: 0.6478461027145386
# Epoch 5/30, Loss: 0.08985599875450134
# Epoch 5/30, Loss: 0.08121968060731888
# Epoch 5/30, Loss: 0.0638756975531578
# Epoch 5/30, Loss: 0.16859880089759827
# Epoch 5/30, Loss: 0.08581504225730896
# Epoch 5/30, Loss: 0.13235682249069214
# Epoch 5/30, Loss: 0.09822595119476318
# Epoch 5/30, Loss: 0.5500595569610596
# Epoch 5/30, Loss: 0.10419842600822449
# Epoch 5/30, Loss: 0.05557771772146225
# Epoch 5/30, Loss: 3.112313985824585
# Epoch 5/30, Loss: 0.06003634259104729
# Epoch 5/30, Loss: 0.07743649184703827
# Epoch 5/30, Loss: 0.2523406744003296
# Epoch 5/30, Loss: 0.11223749816417694
# Epoch 5/30, Loss: 0.10424386709928513
# Epoch 5/30, Loss: 4.452329635620117
# Epoch 5/30, Loss: 0.18589451909065247
# Epoch 5/30, Loss: 0.17113183438777924
# Epoch 5/30, Loss: 0.1266644448041916
# Epoch 5/30, Loss: 0.09764362871646881
# Epoch 5/30, Loss: 0.0949903205037117
# Epoch 5/30, Loss: 0.19977664947509766
# Epoch 5/30, Loss: 0.1738041639328003
# Epoch 5/30, Loss: 0.17694386839866638
# Epoch 5/30, Loss: 0.2854445278644562
# Epoch 5/30, Loss: 0.07192417979240417
# Epoch 5/30, Loss: 0.15578627586364746
# Epoch 5/30, Loss: 0.09609904140233994
# Epoch 5/30, Loss: 0.06940390914678574
# Epoch 5/30, Loss: 0.14340314269065857
# Epoch 5/30, Loss: 0.11565577983856201
# Epoch 5/30, Loss: 0.14301186800003052
# Epoch 5/30, Loss: 0.06893205642700195
# Epoch 5/30, Loss: 0.07408566772937775
# Epoch 5/30, Loss: 0.07011091709136963
# Epoch 5/30, Loss: 0.13203029334545135
# Epoch 5/30, Loss: 0.15901607275009155
# Epoch 5/30, Loss: 0.09236551821231842
# Epoch 5/30, Loss: 0.11319850385189056
# Epoch 5/30, Loss: 0.09409797936677933
# Epoch 5/30, Loss: 0.11352725327014923
# Epoch 5/30, Loss: 0.16390597820281982
# Epoch 5/30, Loss: 0.05907945707440376
# Epoch 5/30, Loss: 0.18007001280784607
# Epoch 5/30, Loss: 0.083917535841465
# Epoch 5/30, Loss: 0.32128337025642395
# Epoch 5/30, Loss: 3.179650068283081
# Epoch 5/30, Loss: 0.17942583560943604
# Epoch 5/30, Loss: 0.3004939556121826
# Epoch 5/30, Loss: 0.08911292999982834
# Epoch 5/30, Loss: 0.07501822710037231
# Epoch 5/30, Loss: 0.08399491012096405
# Epoch 5/30, Loss: 0.1667788177728653
# Epoch 5/30, Loss: 0.057187650352716446
# Epoch 5/30, Loss: 0.1116771399974823
# Epoch 5/30, Loss: 0.1617165505886078
# Epoch 5/30, Loss: 0.15451210737228394
# Epoch 5/30, Loss: 0.1320669800043106
# Epoch 5/30, Loss: 0.12366783618927002
# Epoch 5/30, Loss: 0.34920287132263184
# Epoch 5/30, Loss: 0.4449276924133301
# Epoch 5/30, Loss: 0.1713508516550064
# Epoch 5/30, Loss: 0.1232069581747055
# Epoch 5/30, Loss: 0.08899420499801636
# Epoch 5/30, Loss: 0.11040264368057251
# Epoch 5/30, Loss: 0.1658671498298645
# Epoch 5/30, Loss: 0.14402799308300018
# Epoch 5/30, Loss: 0.2347548007965088
# Epoch 5/30, Loss: 0.12550580501556396
# Epoch 5/30, Loss: 0.11359257996082306
# Epoch 5/30, Loss: 0.2917519211769104
# Epoch 5/30, Loss: 0.2533876895904541
# Epoch 5/30, Loss: 0.06766185164451599
# Epoch 5/30, Loss: 0.19713526964187622
# Epoch 5/30, Loss: 0.08297520875930786
# Epoch 5/30, Loss: 0.10214835405349731
# Epoch 5/30, Loss: 0.3641579747200012
# Epoch 5/30, Loss: 0.05194687098264694
# Epoch 5/30, Loss: 0.06200196593999863
# Epoch 5/30, Loss: 0.08322641253471375
# Epoch 5/30, Loss: 0.088591068983078
# Epoch 5/30, Loss: 1.8193460702896118
# Epoch 5/30, Loss: 0.25181978940963745
# Epoch 5/30, Loss: 0.2202731817960739
# Epoch 5/30, Loss: 0.08720839023590088
# Epoch 5/30, Loss: 0.08889417350292206
# Epoch 5/30, Loss: 0.07692155241966248
# Epoch 5/30, Loss: 0.23531584441661835
# Epoch 5/30, Loss: 0.20671473443508148
# Epoch 5/30, Loss: 0.10733582824468613
# Epoch 5/30, Loss: 0.5154882073402405
# Epoch 5/30, Loss: 0.06456243991851807
# Epoch 5/30, Loss: 0.05780280381441116
# Epoch 5/30, Loss: 0.08238720893859863
# Epoch 5/30, Loss: 0.11012536287307739
# Epoch 5/30, Loss: 0.19125288724899292
# Epoch 5/30, Loss: 0.3434559106826782
# Epoch 5/30, Loss: 0.0987188071012497
# Epoch 5/30, Loss: 0.10293929278850555
# Epoch 5/30, Loss: 0.11302541196346283
# Epoch 5/30, Loss: 0.08782388269901276
# Epoch 5/30, Loss: 0.09129102528095245
# Epoch 5/30, Loss: 0.1839822232723236
# Epoch 5/30, Loss: 0.3257673382759094
# Epoch 5/30, Loss: 0.08381906151771545
# Epoch 5/30, Loss: 0.09382326155900955
# Epoch 5/30, Loss: 0.15186607837677002
# Epoch 5/30, Loss: 0.07123416662216187
# Epoch 5/30, Loss: 0.08835640549659729
# Epoch 5/30, Loss: 0.1195463091135025
# Epoch 5/30, Loss: 0.5307114124298096
# Epoch 5/30, Loss: 0.17840567231178284
# Epoch 5/30, Loss: 0.13424518704414368
# Epoch 5/30, Loss: 0.11999164521694183
# Epoch 5/30, Loss: 0.09499596804380417
# Epoch 5/30, Loss: 0.08249804377555847
# Epoch 5/30, Loss: 0.0996275395154953
# Epoch 5/30, Loss: 0.10898378491401672
# Epoch 5/30, Loss: 0.12078732252120972
# Epoch 5/30, Loss: 0.0863485187292099
# Epoch 5/30, Loss: 0.10257260501384735
# Epoch 5/30, Loss: 0.17132796347141266
# Epoch 5/30, Loss: 0.11366699635982513
# Epoch 5/30, Loss: 0.17000706493854523
# Epoch 5/30, Loss: 0.14342647790908813
# Epoch 5/30, Loss: 0.1333409994840622
# Epoch 5/30, Loss: 0.1607162058353424
# Epoch 5/30, Eval Loss: 3.1507917258601923
# Epoch 6/30, Loss: 0.15406236052513123
# Epoch 6/30, Loss: 0.38756245374679565
# Epoch 6/30, Loss: 0.05585631728172302
# Epoch 6/30, Loss: 0.1445716768503189
# Epoch 6/30, Loss: 0.047153957188129425
# Epoch 6/30, Loss: 0.10872414708137512
# Epoch 6/30, Loss: 0.22724765539169312
# Epoch 6/30, Loss: 0.06987424194812775
# Epoch 6/30, Loss: 0.11432167887687683
# Epoch 6/30, Loss: 0.08634361624717712
# Epoch 6/30, Loss: 0.10171426832675934
# Epoch 6/30, Loss: 0.12363099306821823
# Epoch 6/30, Loss: 0.19568602740764618
# Epoch 6/30, Loss: 0.14408725500106812
# Epoch 6/30, Loss: 0.0758957490324974
# Epoch 6/30, Loss: 0.26372724771499634
# Epoch 6/30, Loss: 0.08035247772932053
# Epoch 6/30, Loss: 0.07510928064584732
# Epoch 6/30, Loss: 0.05416746437549591
# Epoch 6/30, Loss: 0.051021479070186615
# Epoch 6/30, Loss: 0.16915558278560638
# Epoch 6/30, Loss: 0.055377282202243805
# Epoch 6/30, Loss: 0.07681183516979218
# Epoch 6/30, Loss: 0.07262437045574188
# Epoch 6/30, Loss: 0.10591770708560944
# Epoch 6/30, Loss: 0.11352689564228058
# Epoch 6/30, Loss: 0.1263449639081955
# Epoch 6/30, Loss: 0.055387839674949646
# Epoch 6/30, Loss: 0.10404658317565918
# Epoch 6/30, Loss: 0.20336277782917023
# Epoch 6/30, Loss: 0.32787758111953735
# Epoch 6/30, Loss: 0.14066025614738464
# Epoch 6/30, Loss: 0.27839910984039307
# Epoch 6/30, Loss: 0.08826389908790588
# Epoch 6/30, Loss: 0.169538676738739
# Epoch 6/30, Loss: 0.13979528844356537
# Epoch 6/30, Loss: 0.05822836607694626
# Epoch 6/30, Loss: 0.14994260668754578
# Epoch 6/30, Loss: 0.2508637309074402
# Epoch 6/30, Loss: 0.14610238373279572
# Epoch 6/30, Loss: 0.11394944787025452
# Epoch 6/30, Loss: 0.14737167954444885
# Epoch 6/30, Loss: 0.056145939975976944
# Epoch 6/30, Loss: 0.3935038149356842
# Epoch 6/30, Loss: 0.17011669278144836
# Epoch 6/30, Loss: 0.1139141321182251
# Epoch 6/30, Loss: 0.11805208027362823
# Epoch 6/30, Loss: 0.12738637626171112
# Epoch 6/30, Loss: 0.1891387701034546
# Epoch 6/30, Loss: 0.1000508964061737
# Epoch 6/30, Loss: 0.034781403839588165
# Epoch 6/30, Loss: 0.09520315378904343
# Epoch 6/30, Loss: 0.09347429871559143
# Epoch 6/30, Loss: 0.07575821876525879
# Epoch 6/30, Loss: 0.07834050059318542
# Epoch 6/30, Loss: 0.1267527937889099
# Epoch 6/30, Loss: 0.06075113266706467
# Epoch 6/30, Loss: 0.19003529846668243
# Epoch 6/30, Loss: 0.20602628588676453
# Epoch 6/30, Loss: 0.10419661551713943
# Epoch 6/30, Loss: 0.19162173569202423
# Epoch 6/30, Loss: 0.05324549227952957
# Epoch 6/30, Loss: 0.08102810382843018
# Epoch 6/30, Loss: 0.10515832901000977
# Epoch 6/30, Loss: 0.061881013214588165
# Epoch 6/30, Loss: 0.10724835842847824
# Epoch 6/30, Loss: 0.04206382855772972
# Epoch 6/30, Loss: 0.11981160938739777
# Epoch 6/30, Loss: 0.1218075230717659
# Epoch 6/30, Loss: 0.07018212974071503
# Epoch 6/30, Loss: 0.08080809563398361
# Epoch 6/30, Loss: 0.06977717578411102
# Epoch 6/30, Loss: 0.15526935458183289
# Epoch 6/30, Loss: 0.05916040390729904
# Epoch 6/30, Loss: 0.11174745857715607
# Epoch 6/30, Loss: 0.07115692645311356
# Epoch 6/30, Loss: 0.10463210195302963
# Epoch 6/30, Loss: 0.06537144631147385
# Epoch 6/30, Loss: 0.10986064374446869
# Epoch 6/30, Loss: 0.09812676161527634
# Epoch 6/30, Loss: 0.08321422338485718
# Epoch 6/30, Loss: 0.06277196854352951
# Epoch 6/30, Loss: 0.04323654994368553
# Epoch 6/30, Loss: 0.07370088249444962
# Epoch 6/30, Loss: 0.10353535413742065
# Epoch 6/30, Loss: 0.03461315855383873
# Epoch 6/30, Loss: 0.06356631219387054
# Epoch 6/30, Loss: 0.08534802496433258
# Epoch 6/30, Loss: 0.08657972514629364
# Epoch 6/30, Loss: 0.0695023238658905
# Epoch 6/30, Loss: 0.10077278316020966
# Epoch 6/30, Loss: 0.0879250168800354
# Epoch 6/30, Loss: 0.10690762102603912
# Epoch 6/30, Loss: 0.10733944922685623
# Epoch 6/30, Loss: 0.0857354998588562
# Epoch 6/30, Loss: 0.05288732796907425
# Epoch 6/30, Loss: 0.29728084802627563
# Epoch 6/30, Loss: 0.12102402746677399
# Epoch 6/30, Loss: 0.11904206871986389
# Epoch 6/30, Loss: 0.15574729442596436
# Epoch 6/30, Loss: 0.08234919607639313
# Epoch 6/30, Loss: 0.15756791830062866
# Epoch 6/30, Loss: 0.07398900389671326
# Epoch 6/30, Loss: 0.3935999870300293
# Epoch 6/30, Loss: 0.08463090658187866
# Epoch 6/30, Loss: 0.1029604971408844
# Epoch 6/30, Loss: 0.0521584078669548
# Epoch 6/30, Loss: 0.10979372262954712
# Epoch 6/30, Loss: 0.19559459388256073
# Epoch 6/30, Loss: 0.10689574480056763
# Epoch 6/30, Loss: 0.06930112838745117
# Epoch 6/30, Loss: 0.05658680945634842
# Epoch 6/30, Loss: 0.06779134273529053
# Epoch 6/30, Loss: 0.06646306812763214
# Epoch 6/30, Loss: 0.6527196764945984
# Epoch 6/30, Loss: 0.07778827100992203
# Epoch 6/30, Loss: 0.3811396062374115
# Epoch 6/30, Loss: 0.09983551502227783
# Epoch 6/30, Loss: 0.08660399168729782
# Epoch 6/30, Loss: 0.06356332451105118
# Epoch 6/30, Loss: 0.052602555602788925
# Epoch 6/30, Loss: 0.07180668413639069
# Epoch 6/30, Loss: 0.11331086605787277
# Epoch 6/30, Loss: 0.07087602466344833
# Epoch 6/30, Loss: 0.9721307158470154
# Epoch 6/30, Loss: 0.0864914208650589
# Epoch 6/30, Loss: 0.21016725897789001
# Epoch 6/30, Loss: 0.08721692860126495
# Epoch 6/30, Loss: 0.13062936067581177
# Epoch 6/30, Loss: 1.038167119026184
# Epoch 6/30, Loss: 0.3522273600101471
# Epoch 6/30, Loss: 0.124533511698246
# Epoch 6/30, Loss: 0.040413737297058105
# Epoch 6/30, Loss: 0.06121596321463585
# Epoch 6/30, Loss: 0.06773418188095093
# Epoch 6/30, Loss: 0.07770172506570816
# Epoch 6/30, Loss: 0.08342020958662033
# Epoch 6/30, Loss: 0.07920375466346741
# Epoch 6/30, Loss: 0.07756276428699493
# Epoch 6/30, Loss: 0.07158943265676498
# Epoch 6/30, Loss: 0.4603145718574524
# Epoch 6/30, Loss: 0.07129500806331635
# Epoch 6/30, Loss: 0.19517406821250916
# Epoch 6/30, Loss: 0.1080549955368042
# Epoch 6/30, Loss: 0.12535369396209717
# Epoch 6/30, Loss: 0.12149558216333389
# Epoch 6/30, Loss: 0.1454291045665741
# Epoch 6/30, Loss: 0.0834512710571289
# Epoch 6/30, Loss: 0.10717909038066864
# Epoch 6/30, Loss: 0.05577201768755913
# Epoch 6/30, Loss: 0.11010725796222687
# Epoch 6/30, Loss: 0.052357904613018036
# Epoch 6/30, Loss: 0.2116258293390274
# Epoch 6/30, Loss: 0.22282329201698303
# Epoch 6/30, Loss: 0.07331836223602295
# Epoch 6/30, Loss: 0.05243565887212753
# Epoch 6/30, Loss: 0.11778245121240616
# Epoch 6/30, Loss: 0.07033104449510574
# Epoch 6/30, Loss: 0.08034814149141312
# Epoch 6/30, Loss: 0.12673762440681458
# Epoch 6/30, Loss: 0.1093398779630661
# Epoch 6/30, Loss: 0.12267386168241501
# Epoch 6/30, Loss: 0.06932362914085388
# Epoch 6/30, Loss: 0.08154867589473724
# Epoch 6/30, Loss: 0.25510019063949585
# Epoch 6/30, Loss: 0.31679630279541016
# Epoch 6/30, Loss: 0.13217979669570923
# Epoch 6/30, Loss: 0.12112999707460403
# Epoch 6/30, Loss: 0.10948844999074936
# Epoch 6/30, Loss: 0.12285131961107254
# Epoch 6/30, Loss: 0.08551651239395142
# Epoch 6/30, Loss: 0.09689617156982422
# Epoch 6/30, Loss: 0.20819169282913208
# Epoch 6/30, Loss: 0.0637897253036499
# Epoch 6/30, Loss: 0.08909893780946732
# Epoch 6/30, Loss: 0.07866005599498749
# Epoch 6/30, Loss: 0.12212713062763214
# Epoch 6/30, Loss: 0.12989258766174316
# Epoch 6/30, Loss: 0.11561641097068787
# Epoch 6/30, Loss: 0.13943400979042053
# Epoch 6/30, Loss: 0.07850473374128342
# Epoch 6/30, Loss: 0.0987156331539154
# Epoch 6/30, Loss: 0.06881992518901825
# Epoch 6/30, Loss: 0.09261415898799896
# Epoch 6/30, Loss: 0.06410057842731476
# Epoch 6/30, Loss: 0.19010719656944275
# Epoch 6/30, Loss: 0.15311111509799957
# Epoch 6/30, Loss: 0.07761674374341965
# Epoch 6/30, Loss: 0.12417672574520111
# Epoch 6/30, Loss: 0.061027977615594864
# Epoch 6/30, Loss: 0.0950673520565033
# ...
# Epoch 13/30, Loss: 0.033182643353939056
# Epoch 13/30, Loss: 0.02374163269996643
# Epoch 13/30, Loss: 0.03392317518591881
# Epoch 13/30, Loss: 0.033693041652441025
# Epoch 13/30, Loss: 0.04499184340238571
# Epoch 13/30, Loss: 0.013059794902801514
# Epoch 13/30, Loss: 0.0189377348870039
# Epoch 13/30, Loss: 0.018396761268377304
# Epoch 13/30, Loss: 0.03554346412420273
# Epoch 13/30, Loss: 0.08713515102863312
# Epoch 13/30, Loss: 0.03143388032913208
# Epoch 13/30, Loss: 0.03714296594262123
# Epoch 13/30, Loss: 0.038711607456207275
# Epoch 13/30, Loss: 0.025450676679611206
# Epoch 13/30, Loss: 0.014353673905134201
# Epoch 13/30, Loss: 0.030985739082098007
# Epoch 13/30, Loss: 0.034381743520498276
# Epoch 13/30, Loss: 0.0331677608191967
# Epoch 13/30, Loss: 0.04630417004227638
# Epoch 13/30, Loss: 0.023326551541686058
# Epoch 13/30, Loss: 0.02868126705288887
# Epoch 13/30, Loss: 0.02616698294878006
# Epoch 13/30, Loss: 0.0453806035220623
# Epoch 13/30, Loss: 0.049690309911966324
# Epoch 13/30, Loss: 0.02336743101477623
# Epoch 13/30, Loss: 0.010046725161373615
# Epoch 13/30, Loss: 0.03154463320970535
# Epoch 13/30, Loss: 0.028345957398414612
# Epoch 13/30, Loss: 0.021761054173111916
# Epoch 13/30, Loss: 0.037307966500520706
# Epoch 13/30, Loss: 0.020349621772766113
# Epoch 13/30, Loss: 0.013129128143191338
# Epoch 13/30, Loss: 0.04528267681598663
# Epoch 13/30, Loss: 0.029607895761728287
# Epoch 13/30, Loss: 0.012865593656897545
# Epoch 13/30, Loss: 0.020631421357393265
# Epoch 13/30, Loss: 0.025227367877960205
# Epoch 13/30, Loss: 0.011764074675738811
# Epoch 13/30, Loss: 0.01935158297419548
# Epoch 13/30, Loss: 0.03417608141899109
# Epoch 13/30, Loss: 0.015921518206596375
# Epoch 13/30, Loss: 0.024804051965475082
# Epoch 13/30, Loss: 0.021313020959496498
# Epoch 13/30, Loss: 0.00979725643992424
# Epoch 13/30, Loss: 0.04202207922935486
# Epoch 13/30, Loss: 0.27051466703414917
# Epoch 13/30, Loss: 0.02241745963692665
# Epoch 13/30, Loss: 0.042445238679647446
# Epoch 13/30, Loss: 0.09997189044952393
# Epoch 13/30, Loss: 0.04762731492519379
# Epoch 13/30, Loss: 0.031668372452259064
# Epoch 13/30, Loss: 0.07089158892631531
# Epoch 13/30, Loss: 0.02318083867430687
# Epoch 13/30, Loss: 0.031456686556339264
# Epoch 13/30, Loss: 0.029008032754063606
# Epoch 13/30, Loss: 0.018263861536979675
# Epoch 13/30, Loss: 0.039910897612571716
# Epoch 13/30, Loss: 0.017166629433631897
# Epoch 13/30, Loss: 0.041714757680892944
# Epoch 13/30, Loss: 0.028086528182029724
# Epoch 13/30, Loss: 0.021270573139190674
# Epoch 13/30, Loss: 0.020065169781446457
# Epoch 13/30, Loss: 0.07859813421964645
# Epoch 13/30, Loss: 0.021589625626802444
# Epoch 13/30, Loss: 0.0359044186770916
# Epoch 13/30, Loss: 0.035770878195762634
# Epoch 13/30, Loss: 0.04284925013780594
# Epoch 13/30, Loss: 0.04970095679163933
# Epoch 13/30, Loss: 0.049991801381111145
# Epoch 13/30, Loss: 0.02191198244690895
# Epoch 13/30, Loss: 0.03575429320335388
# Epoch 13/30, Loss: 0.027880530804395676
# Epoch 13/30, Loss: 0.0381251722574234
# Epoch 13/30, Loss: 0.037360116839408875
# Epoch 13/30, Loss: 0.02405901439487934
# Epoch 13/30, Loss: 0.03535887971520424
# Epoch 13/30, Loss: 0.019532250240445137
# Epoch 13/30, Loss: 0.027558475732803345
# Epoch 13/30, Loss: 0.04243485629558563
# Epoch 13/30, Loss: 0.17358258366584778
# Epoch 13/30, Loss: 0.013732954859733582
# Epoch 13/30, Loss: 0.018378468230366707
# Epoch 13/30, Loss: 0.04046715050935745
# Epoch 13/30, Loss: 0.026578856632113457
# Epoch 13/30, Loss: 0.03694543242454529
# Epoch 13/30, Loss: 0.021511320024728775
# Epoch 13/30, Loss: 0.028140608221292496
# Epoch 13/30, Loss: 0.033822424709796906
# Epoch 13/30, Loss: 0.024733224883675575
# Epoch 13/30, Loss: 0.013179137371480465
# Epoch 13/30, Loss: 0.02994270622730255
# Epoch 13/30, Loss: 0.022842008620500565
# Epoch 13/30, Loss: 0.04932088032364845
# Epoch 13/30, Loss: 0.048740774393081665
# Epoch 13/30, Loss: 0.026720769703388214
# Epoch 13/30, Loss: 0.024337194859981537
# Epoch 13/30, Loss: 0.03799951821565628
# Epoch 13/30, Loss: 0.04759737476706505
# Epoch 13/30, Loss: 0.04021668806672096
# Epoch 13/30, Loss: 0.014811733737587929
# Epoch 13/30, Loss: 0.02710995450615883
# Epoch 13/30, Loss: 0.017087144777178764
# Epoch 13/30, Loss: 0.022766750305891037
# Epoch 13/30, Loss: 0.021141573786735535
# Epoch 13/30, Loss: 0.03936180844902992
# Epoch 13/30, Loss: 0.010672391392290592
# Epoch 13/30, Loss: 0.020408909767866135
# Epoch 13/30, Loss: 0.030937541276216507
# Epoch 13/30, Loss: 0.170729398727417
# Epoch 13/30, Loss: 0.043427012860774994
# Epoch 13/30, Loss: 0.040377505123615265
# Epoch 13/30, Loss: 0.03567727655172348
# Epoch 13/30, Loss: 0.021719124168157578
# Epoch 13/30, Loss: 0.031305380165576935
# Epoch 13/30, Loss: 0.02822265774011612
# Epoch 13/30, Loss: 0.02443826012313366
# Epoch 13/30, Loss: 0.022902637720108032
# Epoch 13/30, Loss: 0.016298241913318634
# Epoch 13/30, Loss: 0.015684911981225014
# Epoch 13/30, Loss: 0.02907628007233143
# Epoch 13/30, Loss: 0.08414220064878464
# Epoch 13/30, Loss: 0.026603257283568382
# Epoch 13/30, Loss: 0.03419370576739311
# Epoch 13/30, Loss: 0.05964604392647743
# Epoch 13/30, Loss: 0.01792990230023861
# Epoch 13/30, Loss: 0.041115351021289825
# Epoch 13/30, Loss: 0.02491426095366478
# Epoch 13/30, Loss: 0.03829153627157211
# Epoch 13/30, Loss: 0.028447682037949562
# Epoch 13/30, Loss: 0.03236819803714752
# Epoch 13/30, Loss: 0.029225515201687813
# Epoch 13/30, Loss: 0.030606813728809357
# Epoch 13/30, Loss: 0.025126034393906593
# Epoch 13/30, Loss: 0.0258052796125412
# Epoch 13/30, Loss: 0.03610241785645485
# Epoch 13/30, Loss: 0.025060798972845078
# Epoch 13/30, Loss: 0.022400442510843277
# Epoch 13/30, Loss: 0.036733731627464294
# Epoch 13/30, Loss: 0.0348660983145237
# Epoch 13/30, Loss: 0.01973710209131241
# Epoch 13/30, Loss: 0.028430575504899025
# Epoch 13/30, Loss: 0.026773281395435333
# Epoch 13/30, Loss: 0.02474014088511467
# Epoch 13/30, Loss: 0.01986555941402912
# Epoch 13/30, Loss: 0.021513644605875015
# Epoch 13/30, Loss: 0.05835331231355667
# Epoch 13/30, Loss: 0.02860044315457344
# Epoch 13/30, Loss: 0.03317655622959137
# Epoch 13/30, Loss: 0.08676936477422714
# Epoch 13/30, Loss: 0.028937138617038727
# Epoch 13/30, Loss: 0.07388745248317719
# Epoch 13/30, Loss: 0.06913334876298904
# Epoch 13/30, Loss: 0.02572815492749214
# Epoch 13/30, Loss: 0.02845737151801586
# Epoch 13/30, Loss: 0.03133779391646385
# Epoch 13/30, Loss: 0.02692801132798195
# Epoch 13/30, Loss: 0.028710413724184036
# Epoch 13/30, Loss: 0.026607923209667206
# Epoch 13/30, Loss: 0.05303259193897247
# Epoch 13/30, Loss: 0.022568322718143463
# Epoch 13/30, Loss: 0.039609380066394806
# Epoch 13/30, Loss: 0.048114705830812454
# Epoch 13/30, Loss: 0.027245352044701576
# Epoch 13/30, Loss: 0.023741723969578743
# Epoch 13/30, Loss: 0.030830543488264084
# Epoch 13/30, Loss: 0.028744898736476898
# Epoch 13/30, Loss: 0.014995606616139412
# Epoch 13/30, Loss: 0.04080086946487427
# Epoch 13/30, Loss: 0.026066947728395462
# Epoch 13/30, Loss: 0.023176124319434166
# Epoch 13/30, Loss: 0.020528778433799744
# Epoch 13/30, Loss: 0.014694172888994217
# Epoch 13/30, Loss: 0.01208430528640747
# Epoch 13/30, Loss: 0.013456142507493496
# Epoch 13/30, Loss: 0.02349851280450821
# Epoch 13/30, Loss: 0.044765397906303406
# Epoch 13/30, Loss: 0.023663979023694992
# Epoch 13/30, Loss: 0.019497767090797424
# Epoch 13/30, Loss: 0.04953896999359131
# Epoch 13/30, Loss: 0.02799856662750244
# Epoch 13/30, Loss: 0.016504067927598953
# Epoch 13/30, Loss: 0.026449665427207947
# Epoch 13/30, Loss: 0.05867208540439606
# Epoch 13/30, Loss: 0.03004264272749424
# Epoch 13/30, Loss: 0.03264227136969566
# Epoch 13/30, Loss: 0.016446735709905624
# Epoch 13/30, Eval Loss: 3.2226623763831763
# Epoch 14/30, Loss: 0.02621636539697647
# Epoch 14/30, Loss: 0.02696225792169571
# Epoch 14/30, Loss: 0.016986817121505737
# Epoch 14/30, Loss: 0.02394057624042034
# Epoch 14/30, Loss: 0.03512145206332207
# Epoch 14/30, Loss: 0.0691564530134201
# Epoch 14/30, Loss: 0.041050948202610016
# Epoch 14/30, Loss: 0.020845677703619003
# Epoch 14/30, Loss: 0.021421484649181366
# Epoch 14/30, Loss: 0.03558178246021271
# Epoch 14/30, Loss: 0.03407838195562363
# Epoch 14/30, Loss: 0.014832009561359882
# Epoch 14/30, Loss: 0.03449387103319168
# Epoch 14/30, Loss: 0.02992558479309082
# Epoch 14/30, Loss: 0.01828344538807869
# Epoch 14/30, Loss: 0.02496819570660591
# Epoch 14/30, Loss: 0.01819513738155365
# Epoch 14/30, Loss: 0.02538139745593071
# Epoch 14/30, Loss: 0.015914302319288254
# Epoch 14/30, Loss: 0.014555785804986954
# Epoch 14/30, Loss: 0.018945593386888504
# Epoch 14/30, Loss: 0.009737785905599594
# Epoch 14/30, Loss: 0.018726982176303864
# Epoch 14/30, Loss: 0.02187657169997692
# Epoch 14/30, Loss: 0.015940207988023758
# Epoch 14/30, Loss: 0.03301794081926346
# Epoch 14/30, Loss: 0.07951149344444275
# Epoch 14/30, Loss: 0.011213315650820732
# Epoch 14/30, Loss: 0.0474710538983345
# Epoch 14/30, Loss: 0.02799275703728199
# Epoch 14/30, Loss: 0.013591442257165909
# Epoch 14/30, Loss: 0.016260603442788124
# Epoch 14/30, Loss: 0.014031379483640194
# Epoch 14/30, Loss: 0.03075396828353405
# Epoch 14/30, Loss: 0.035554055124521255
# Epoch 14/30, Loss: 0.04015940800309181
# Epoch 14/30, Loss: 0.015605496242642403
# Epoch 14/30, Loss: 0.11863522231578827
# Epoch 14/30, Loss: 0.012577049434185028
# Epoch 14/30, Loss: 0.01081218384206295
# Epoch 14/30, Loss: 0.023769838735461235
# Epoch 14/30, Loss: 0.03108225390315056
# Epoch 14/30, Loss: 0.03597988560795784
# Epoch 14/30, Loss: 0.09847366809844971
# Epoch 14/30, Loss: 0.01777571067214012
# Epoch 14/30, Loss: 0.024668671190738678
# Epoch 14/30, Loss: 0.022453157231211662
# Epoch 14/30, Loss: 0.028231892734766006
# Epoch 14/30, Loss: 0.04364900290966034
# Epoch 14/30, Loss: 0.015066834166646004
# Epoch 14/30, Loss: 0.025660209357738495
# Epoch 14/30, Loss: 0.03823048621416092
# Epoch 14/30, Loss: 0.01609344407916069
# Epoch 14/30, Loss: 0.016943298280239105
# Epoch 14/30, Loss: 0.022243859246373177
# Epoch 14/30, Loss: 0.022317346185445786
# Epoch 14/30, Loss: 0.05748852342367172
# Epoch 14/30, Loss: 0.023752566426992416
# Epoch 14/30, Loss: 0.026437561959028244
# Epoch 14/30, Loss: 0.01752435229718685
# Epoch 14/30, Loss: 0.029105037450790405
# Epoch 14/30, Loss: 0.02637924626469612
# Epoch 14/30, Loss: 0.025495795533061028
# Epoch 14/30, Loss: 0.016328169032931328
# Epoch 14/30, Loss: 0.019278107210993767
# Epoch 14/30, Loss: 0.023433256894350052
# Epoch 14/30, Loss: 0.03564349561929703
# Epoch 14/30, Loss: 0.013696162030100822
# Epoch 14/30, Loss: 0.02886742167174816
# Epoch 14/30, Loss: 0.02057921327650547
# Epoch 14/30, Loss: 0.02153126895427704
# Epoch 14/30, Loss: 0.01471913605928421
# Epoch 14/30, Loss: 0.0343252569437027
# Epoch 14/30, Loss: 0.04732847958803177
# Epoch 14/30, Loss: 0.06255073100328445
# Epoch 14/30, Loss: 0.020927855744957924
# Epoch 14/30, Loss: 0.02171034924685955
# Epoch 14/30, Loss: 0.019767221063375473
# Epoch 14/30, Loss: 0.036293964833021164
# Epoch 14/30, Loss: 0.017190953716635704
# Epoch 14/30, Loss: 0.03286319971084595
# Epoch 14/30, Loss: 0.019869286566972733
# Epoch 14/30, Loss: 0.029976435005664825
# Epoch 14/30, Loss: 0.04053836315870285
# Epoch 14/30, Loss: 0.03951029106974602
# Epoch 14/30, Loss: 0.020154442638158798
# Epoch 14/30, Loss: 0.11095356941223145
# Epoch 14/30, Loss: 0.022510776296257973
# Epoch 14/30, Loss: 0.024070139974355698
# Epoch 14/30, Loss: 0.05643777921795845
# Epoch 14/30, Loss: 0.024416498839855194
# Epoch 14/30, Loss: 0.03212627023458481
# Epoch 14/30, Loss: 0.025407228618860245
# Epoch 14/30, Loss: 0.021612104028463364
# Epoch 14/30, Loss: 0.031125323846936226
# Epoch 14/30, Loss: 0.07320617139339447
# Epoch 14/30, Loss: 0.09708185493946075
# Epoch 14/30, Loss: 0.017397867515683174
# Epoch 14/30, Loss: 0.02392943948507309
# Epoch 14/30, Loss: 0.040869347751140594
# Epoch 14/30, Loss: 0.033595841377973557
# Epoch 14/30, Loss: 0.05482650548219681
# Epoch 14/30, Loss: 0.04771549254655838
# Epoch 14/30, Loss: 0.03307798132300377
# Epoch 14/30, Loss: 0.0484001561999321
# Epoch 14/30, Loss: 0.027081992477178574
# Epoch 14/30, Loss: 0.02341776341199875
# Epoch 14/30, Loss: 0.03658953309059143
# Epoch 14/30, Loss: 0.041891634464263916
# Epoch 14/30, Loss: 0.020812563598155975
# Epoch 14/30, Loss: 0.04860817641019821
# Epoch 14/30, Loss: 0.03117493912577629
# Epoch 14/30, Loss: 0.02374323457479477
# Epoch 14/30, Loss: 0.030545318499207497
# Epoch 14/30, Loss: 0.015397503972053528
# Epoch 14/30, Loss: 0.012084327638149261
# Epoch 14/30, Loss: 0.029347658157348633
# Epoch 14/30, Loss: 0.03310321643948555
# Epoch 14/30, Loss: 0.06481382995843887
# Epoch 14/30, Loss: 0.021152805536985397
# Epoch 14/30, Loss: 0.031248413026332855
# Epoch 14/30, Loss: 0.01413060910999775
# Epoch 14/30, Loss: 0.025370437651872635
# Epoch 14/30, Loss: 0.02753952331840992
# Epoch 14/30, Loss: 0.02570979669690132
# Epoch 14/30, Loss: 0.019546637311577797
# Epoch 14/30, Loss: 0.012741654179990292
# Epoch 14/30, Loss: 0.033557385206222534
# Epoch 14/30, Loss: 0.008077127858996391
# Epoch 14/30, Loss: 0.025097748264670372
# Epoch 14/30, Loss: 0.008802423253655434
# Epoch 14/30, Loss: 0.054966624826192856
# Epoch 14/30, Loss: 0.02992788515985012
# Epoch 14/30, Loss: 0.021081533282995224
# Epoch 14/30, Loss: 0.017338378354907036
# Epoch 14/30, Loss: 0.03424913063645363
# Epoch 14/30, Loss: 0.02511874958872795
# Epoch 14/30, Loss: 0.01458604633808136
# Epoch 14/30, Loss: 0.023108098655939102
# Epoch 14/30, Loss: 0.05528581142425537
# Epoch 14/30, Loss: 0.027574805542826653
# Epoch 14/30, Loss: 0.013492275960743427
# Epoch 14/30, Loss: 0.05076073855161667
# Epoch 14/30, Loss: 0.017316661775112152
# Epoch 14/30, Loss: 0.04216999560594559
# Epoch 14/30, Loss: 0.020989667624235153
# Epoch 14/30, Loss: 0.014657864347100258
# Epoch 14/30, Loss: 0.015282373875379562
# Epoch 14/30, Loss: 0.028492126613855362
# Epoch 14/30, Loss: 0.014001094736158848
# Epoch 14/30, Loss: 0.017224859446287155
# Epoch 14/30, Loss: 0.020169641822576523
# Epoch 14/30, Loss: 0.03089846670627594
# Epoch 14/30, Loss: 0.029315445572137833
# Epoch 14/30, Loss: 0.03396429121494293
# Epoch 14/30, Loss: 0.026312435045838356
# Epoch 14/30, Loss: 0.02918710745871067
# Epoch 14/30, Loss: 0.022312307730317116
# Epoch 14/30, Loss: 0.02258649654686451
# Epoch 14/30, Loss: 0.05022064596414566
# Epoch 14/30, Loss: 0.036084383726119995
# Epoch 14/30, Loss: 0.06356658041477203
# Epoch 14/30, Loss: 0.032615650445222855
# Epoch 14/30, Loss: 0.07243555784225464
# Epoch 14/30, Loss: 0.04278707876801491
# Epoch 14/30, Loss: 0.03990674763917923
# Epoch 14/30, Loss: 0.014724323526024818
# Epoch 14/30, Loss: 0.09153122454881668
# Epoch 14/30, Loss: 0.014387033879756927
# Epoch 14/30, Loss: 0.027613380923867226
# Epoch 14/30, Loss: 0.012937074527144432
# Epoch 14/30, Loss: 0.028842244297266006
# Epoch 14/30, Loss: 0.019888710230588913
# Epoch 14/30, Loss: 0.026741918176412582
# Epoch 14/30, Loss: 0.027455780655145645
# Epoch 14/30, Loss: 0.03263292461633682
# Epoch 14/30, Loss: 0.059657253324985504
# Epoch 14/30, Loss: 0.01780453696846962
# Epoch 14/30, Loss: 0.023854650557041168
# Epoch 14/30, Loss: 0.038690872490406036
# Epoch 14/30, Loss: 0.020450256764888763
# Epoch 14/30, Loss: 0.021925361827015877
# Epoch 14/30, Loss: 0.03354421630501747
# Epoch 14/30, Loss: 0.03497584909200668
# Epoch 14/30, Loss: 0.029822606593370438
# Epoch 14/30, Loss: 0.02010585553944111
# Epoch 14/30, Loss: 0.03344652056694031
# Epoch 14/30, Loss: 0.017577242106199265
# Epoch 14/30, Loss: 0.02322026528418064
# Epoch 14/30, Loss: 0.023096807301044464
# Epoch 14/30, Loss: 0.02211422473192215
# Epoch 14/30, Loss: 0.022326603531837463
# Epoch 14/30, Loss: 0.012578741647303104
# Epoch 14/30, Loss: 0.023865535855293274
# Epoch 14/30, Loss: 0.0382060706615448
# Epoch 14/30, Loss: 0.04651612043380737
# Epoch 14/30, Loss: 0.018407680094242096
# Epoch 14/30, Loss: 0.03423558175563812
# Epoch 14/30, Loss: 0.0356086865067482
# Epoch 14/30, Loss: 0.017036978155374527
# Epoch 14/30, Loss: 0.05947582796216011
# Epoch 14/30, Loss: 0.017615657299757004
# Epoch 14/30, Loss: 0.05795138329267502
# Epoch 14/30, Loss: 0.026331299915909767
# Epoch 14/30, Loss: 0.04567457363009453
# Epoch 14/30, Loss: 0.030539467930793762
# Epoch 14/30, Loss: 0.020258553326129913
# Epoch 14/30, Loss: 0.03243473917245865
# Epoch 14/30, Loss: 0.043009668588638306
# Epoch 14/30, Loss: 0.025783177465200424
# Epoch 14/30, Loss: 0.10813575237989426
# Epoch 14/30, Loss: 0.02119809202849865
# Epoch 14/30, Loss: 0.025344623252749443
# Epoch 14/30, Loss: 0.020195256918668747
# Epoch 14/30, Loss: 0.01627468317747116
# Epoch 14/30, Loss: 0.027374576777219772
# Epoch 14/30, Eval Loss: 3.2121023220511584
# Early stopping triggered

# %%
model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/modelos/Visual/ghot_model.pth'))
# Out:
# <All keys matched successfully>

# %%
trainer = Trainer(model.to(device), train_dataset, trainloader, devloader, testloader, 30, 0.001, device, True, earlystopping)

# %%
trainer.test()
# Out:
# MAE: 0.4237
# R²:  0.1352
# <ipython-input-19-eea53120342c>:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = torch.cat([torch.tensor(p) for p in preds]).to('cpu').numpy().flatten()
# <ipython-input-19-eea53120342c>:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true = torch.cat([torch.tensor(t) for t in targets]).to('cpu').numpy().flatten()
# (0.42374205589294434, 0.13522017002105713)
