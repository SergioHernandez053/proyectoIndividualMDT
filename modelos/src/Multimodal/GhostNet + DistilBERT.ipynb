# %%
# !pip install lmdb

import argparse
import os
import numpy as np
import math
import itertools
import signal
import pandas as pd
import random
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from sklearn.metrics import mean_absolute_error, r2_score
import lmdb
import pickle
from io import BytesIO
from sklearn.preprocessing import StandardScaler
import torchvision.transforms as transforms
from torchvision.utils import save_image
from transformers import AutoTokenizer, AutoModel
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torch.autograd import Variable
from torchvision import models

import gc

import zipfile
from io import BytesIO

import torch.nn as nn
import torch.nn.functional as F
import torch

import matplotlib.pyplot as plt
from PIL import Image

from torch.amp import GradScaler, autocast
from torch.utils.data import random_split

import glob
# Out:
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (1.6.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/data/datos_coches_procesados.csv')

# %%
import zipfile
import os

ruta_zip = "/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/data/imagenes_comprimidas.zip"
carpeta_destino = "dataset_extraido"

os.makedirs(carpeta_destino, exist_ok=True)

with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
    zip_ref.extractall(carpeta_destino)

print("Descompresión completada.")
# Out:
# Descompresión completada.

# %%
# Ruta a imágenes y CSV
root_dir = "dataset_extraido/imagenes_comprimidas"
csv_path = "/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/data/datos_coches_procesados.csv"
lmdb_path = "dataset.lmdb"

# Leer CSV
df = pd.read_csv(csv_path)
df = df.set_index('url')


# Crear base de datos LMDB
env = lmdb.open(lmdb_path, map_async=True, map_size=20*1024**3, meminit=False, writemap=True, lock=False)

with env.begin(write=True) as txn:
    for url in os.listdir(root_dir):
        folder_path = os.path.join(root_dir, url)
        if not os.path.isdir(folder_path) or url not in df.index:
            continue

        images = []

         # Cargar todas las imágenes de la subcarpeta
        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            with open(img_path, 'rb') as f:
                img_bytes = f.read()
                images.append((img_name, img_bytes))  # Guardamos el nombre y el contenido

        if not images:
            continue

        key = url.encode('utf-8')  # Solo el nombre de la carpeta como clave
        metadata = df.loc[url].to_dict()
        value = pickle.dumps({
            "images": images,    # Lista de (nombre, bytes)
            "metadata": metadata,
        })

        txn.put(key, value)

# %% [markdown]
# # Funciones para partir el dataset

# %%
random.seed(42)
def split_keys(path, train, dev):
  env = lmdb.open(path, readonly=True, lock=False)
  keys = []

  with env.begin() as txn:
      cursor = txn.cursor()
      for key, _ in cursor:
          keys.append(key)

  random.shuffle(keys)

  train_split = train
  dev_split = dev

  n = len(keys)
  train_keys = keys[:int(train_split * n)]
  dev_keys = keys[int(train_split * n):int((train_split + dev_split) * n)]
  test_keys = keys[int((train_split + dev_split) * n):]
  return train_keys, dev_keys, test_keys

# %%
def set_scaler(y_train):
  y_train_int = []
  for y in y_train:
    y = y.split(",")[0]
    y = y.replace('.', '')
    y = int(y)
    y_train_int.append(y)
  targets = np.array(y_train_int).reshape(-1, 1)
  scaler = StandardScaler()
  scaler.fit(targets)
  return scaler

# %%
def get_labels_train(df, train_keys):
  keys_str = [key.decode('utf-8') for key in train_keys]
  filtered_df = df.loc[df.index.intersection(keys_str)]
  y_train = filtered_df['precio'].tolist()
  return y_train

# %%
class LMDBDataset(Dataset):
    def __init__(self, lmdb_path ,keys, scaler, transform=None):
        self.env = lmdb.open(lmdb_path, readonly=True, lock=False)
        self.keys = keys
        self.transform = transform or transforms.ToTensor()
        self.normalizar = False
        self.scaler = scaler
    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        with self.env.begin() as txn:
            data = pickle.loads(txn.get(key))

        images = data["images"]
        metadata = data["metadata"]
        try:
          año = int(float(metadata['año']))
        except:
          año = None
        try:
          km = int(float(metadata['km']))
        except:
          km = None
        try:
          precio = metadata['precio'].split(",")[0]
          precio = precio.replace('.', '')
          precio = int(precio)
        except:
          precio = -1

        # Texto que se le pasará al modelo textual
        text = "Modelo: " + str(metadata['marca']) +" "+str(metadata['modelo']) +" " + "año: " + str(año)+ " "+"Kilómetros: " + str(km) + " " + str(metadata['desc'])


        precio = self.normalizar_precio(precio)

        image_list = []
        for img_name, img_bytes in images:
            img = Image.open(BytesIO(img_bytes)).convert("RGB")
            img = self.transform(img)
            image_list.append(img)

        return image_list, text, len(images), precio
    def normalizar_precio(self, precio):
        y = self.scaler.transform([[precio]])[0][0]
        return y

# %%
def custom_collate_fn(batch):
    all_images = []
    all_metadata = []
    num_images_per_group = []
    precios = []
    for images, metadata, num_images, precio in batch:
        all_images.extend(images)  # añadir todas las imágenes
        all_metadata.append(metadata)
        num_images_per_group.append(num_images)
        precios.append(precio)

    all_images = torch.stack(all_images, dim=0)  # [total_imágenes, 3, 256, 256]

    return all_images, all_metadata, num_images_per_group, precios

# %%
train_keys, dev_keys, test_keys = split_keys(lmdb_path, 0.85, 0.05)

# %%
train_precios = get_labels_train(df, train_keys)
scaler = set_scaler(train_precios)

# %%
train_dataset = LMDBDataset(lmdb_path, train_keys, scaler)
dev_dataset = LMDBDataset(lmdb_path, dev_keys, scaler)
test_dataset = LMDBDataset(lmdb_path, test_keys, scaler)

# %%
dataloader = DataLoader(dev_dataset, batch_size = 32, collate_fn=custom_collate_fn)

# %%
print(len(train_dataset))
print(len(dev_dataset))
print(len(test_dataset))
# Out:
# 6907
# 406
# 813

# %% [markdown]
# # Modelos

# %%
class MultiImageFlexibleVGG(nn.Module):
    def __init__(self, model, feature_dim=4096):
        super().__init__()
        self.model = model

    def forward(self, images):
        device = next(self.parameters()).device
        all_imgs = images.to(device)

        with torch.no_grad():
            feats = self.model(all_imgs)
        return feats

# %%
class FeatLSTM(nn.Module):
  def __init__(self, input_size, hidden_size):
    super(FeatLSTM, self).__init__()
    self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, batch_first=True, bidirectional=True)

  def forward(self, x, lengths):
    cut_indices = torch.cumsum(lengths, dim=0)[:-1]
    split = torch.tensor_split(x, cut_indices.tolist(), dim=0)
    out = torch.tensor([]).to(device)
    for seq in split:
      _, (h, c) = self.lstm(seq)
      h = h.flatten()
      out = torch.cat((out, torch.unsqueeze(h, 0)), dim=0)


    return out

# %%
# Para el MODELO DE LENGUAJE
# https://huggingface.co/Recognai/distilbert-base-es-multilingual-cased

# %%
class TextModel(nn.Module):
  def __init__(self, tokenizer, model, device):
    super(TextModel, self).__init__()
    self.tokenizer = tokenizer
    self.model = model
    self.device = device
  def forward(self, x):
    tokens = self.tokenizer(x, padding=True, truncation=True, return_tensors='pt')
    tokens = tokens.to(self.device)
    output = self.model(**tokens)
    return output.last_hidden_state[:, 0, :]

# %%
class MultimodalModel(nn.Module):
  def __init__(self, multiVGG, featLSTM, textModel, device, image_latent_dim=1024, text_latent_dim=768):
    super(MultimodalModel, self).__init__()
    self.device = device
    self.multiVGG = multiVGG.to(self.device)
    self.featLSTM = featLSTM.to(self.device)
    self.textModel = textModel.to(self.device)
    self.text_latent_dim = text_latent_dim
    self.image_latent_dim = image_latent_dim
    self.latent_dim = text_latent_dim + image_latent_dim

    self.regresion = nn.Sequential(
        nn.Linear(self.latent_dim, 1024),
        nn.ReLU(),
        nn.Linear(1024, 512),
        nn.ReLU(),
        nn.Linear(512, 1)
    )
  def forward(self, images, text, lengths):
    image_latent = self.multiVGG(images)
    text_latent = self.textModel(text)
    image_latent = self.featLSTM(image_latent, lengths)
    latent = torch.cat((image_latent, text_latent), dim=1)
    output = self.regresion(latent)
    return output

# %% [markdown]
# # Trainer

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0
        self.should_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True

# %%
class Trainer():
  def __init__(self, model, dataset, dataloader, devloader, testloader, num_epochs, learning_rate, device, save, earlystopping):
    self.model = model
    self.dataset = dataset
    self.dataloader = dataloader
    self.num_epochs = num_epochs
    self.learning_rate = learning_rate
    self.device = device
    self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)
    self.criterion = nn.MSELoss()
    self.save = save
    self.earlystopping = earlystopping
    self.devloader = devloader
    self.testloader = testloader
    self.save_path ='/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/multimodal_model.pth'

  def train(self):
    for epoch in range(self.num_epochs):
      self.model.train()
      for images, text, num_images, y in self.dataloader:
        y = torch.tensor(y, dtype=torch.float32).to(device)
        lengths = torch.tensor(num_images).to(self.device)
        images = images.to(self.device)

        self.optimizer.zero_grad()

        output = self.model(images, text, lengths)
        loss = self.criterion(output.flatten(), y.flatten())
        loss.backward()
        self.optimizer.step()
        print(f"Epoch {epoch+1}/{self.num_epochs}, Loss: {loss.item()}")

      eval_loss = self.eval()

      if self.save and self.earlystopping.best_loss > eval_loss:
        torch.save(self.model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/multimodal_model-2.pth')

      print(f"Epoch {epoch+1}/{self.num_epochs}, Eval Loss: {eval_loss}")
      if epoch == 8:
        self.descongelar_capas()
      self.earlystopping(eval_loss)
      if self.earlystopping.should_stop:
        print("Early stopping triggered")
        break

  def eval(self):
    self.model.eval()
    losses = []
    with torch.no_grad():
      for images, text, num_images, y in self.devloader:
        lengths = torch.tensor(num_images).to(self.device)
        y = torch.tensor(y, dtype=torch.float32).to(device)
        images = images.to(self.device)
        output = self.model(images, text, lengths)
        loss = self.criterion(output.flatten(), y.flatten())
        losses.append(loss.item())
    return sum(losses)/len(losses)
  def test(self):
    self.model.eval()
    targets = []
    preds = []
    with torch.no_grad():
      for images, text, num_images, y in self.testloader:
        lengths = torch.tensor(num_images).to(self.device)
        y = torch.tensor(y, dtype=torch.float32).to(device)
        images = images.to(self.device)
        output = self.model(images, text, lengths)
        preds.append(output)
        targets.append(y)

    y_pred = torch.cat([torch.tensor(p) for p in preds]).to('cpu').numpy().flatten()
    y_true = torch.cat([torch.tensor(t) for t in targets]).to('cpu').numpy().flatten()

    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    print(f"MAE: {mae:.4f}")
    print(f"R²:  {r2:.4f}")

    return mae, r2

  def save(self, path=None):
    if path is None:
      torch.save(self.model.state_dict(), self.save_path)
    else:
      torch.save(self.model.state_dict(), path)
  def descongelar_capas(self):
    print("Descongelando capas...")
    for name, param in self.model.multiVGG.named_parameters():
      if '8.3.ghost2' in name:
        param.requires_grad = True
    for name, param in self.model.textModel.named_parameters():
      if '5.' in name:
        param.requires_grad = True

# %% [markdown]
# # Inicialización de los modelos, entrenamiento y testeo

# %%
import timm
v_model = timm.create_model('ghostnet_100', pretrained=True)
v_model.classifier = nn.Identity()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
for name, param in v_model.blocks.named_parameters():
    if '9' in name:  # suponiendo que el último bloque tiene '16' en el nombre
        param.requires_grad = True
    else:
        param.requires_grad = False


# Descongela la capa conv_head
for name, param in v_model.named_parameters():
    if 'conv_head' in name:
        param.requires_grad = True

# %%
for name, param in v_model.named_parameters():
    estado = "entrenable" if param.requires_grad else "congelada"
    print(f"{name:50} → {estado}")
# Out:
# conv_stem.weight                                   → entrenable
# bn1.weight                                         → entrenable
# bn1.bias                                           → entrenable
# blocks.0.0.ghost1.primary_conv.0.weight            → congelada
# blocks.0.0.ghost1.primary_conv.1.weight            → congelada
# blocks.0.0.ghost1.primary_conv.1.bias              → congelada
# blocks.0.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.0.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.0.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.0.0.ghost2.primary_conv.0.weight            → congelada
# blocks.0.0.ghost2.primary_conv.1.weight            → congelada
# blocks.0.0.ghost2.primary_conv.1.bias              → congelada
# blocks.0.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.0.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.0.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.1.0.ghost1.primary_conv.0.weight            → congelada
# blocks.1.0.ghost1.primary_conv.1.weight            → congelada
# blocks.1.0.ghost1.primary_conv.1.bias              → congelada
# blocks.1.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.1.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.1.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.1.0.conv_dw.weight                          → congelada
# blocks.1.0.bn_dw.weight                            → congelada
# blocks.1.0.bn_dw.bias                              → congelada
# blocks.1.0.ghost2.primary_conv.0.weight            → congelada
# blocks.1.0.ghost2.primary_conv.1.weight            → congelada
# blocks.1.0.ghost2.primary_conv.1.bias              → congelada
# blocks.1.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.1.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.1.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.1.0.shortcut.0.weight                       → congelada
# blocks.1.0.shortcut.1.weight                       → congelada
# blocks.1.0.shortcut.1.bias                         → congelada
# blocks.1.0.shortcut.2.weight                       → congelada
# blocks.1.0.shortcut.3.weight                       → congelada
# blocks.1.0.shortcut.3.bias                         → congelada
# blocks.2.0.ghost1.primary_conv.0.weight            → congelada
# blocks.2.0.ghost1.primary_conv.1.weight            → congelada
# blocks.2.0.ghost1.primary_conv.1.bias              → congelada
# blocks.2.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.2.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.2.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.2.0.ghost2.primary_conv.0.weight            → congelada
# blocks.2.0.ghost2.primary_conv.1.weight            → congelada
# blocks.2.0.ghost2.primary_conv.1.bias              → congelada
# blocks.2.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.2.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.2.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.3.0.ghost1.primary_conv.0.weight            → congelada
# blocks.3.0.ghost1.primary_conv.1.weight            → congelada
# blocks.3.0.ghost1.primary_conv.1.bias              → congelada
# blocks.3.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.3.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.3.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.3.0.conv_dw.weight                          → congelada
# blocks.3.0.bn_dw.weight                            → congelada
# blocks.3.0.bn_dw.bias                              → congelada
# blocks.3.0.se.conv_reduce.weight                   → congelada
# blocks.3.0.se.conv_reduce.bias                     → congelada
# blocks.3.0.se.conv_expand.weight                   → congelada
# blocks.3.0.se.conv_expand.bias                     → congelada
# blocks.3.0.ghost2.primary_conv.0.weight            → congelada
# blocks.3.0.ghost2.primary_conv.1.weight            → congelada
# blocks.3.0.ghost2.primary_conv.1.bias              → congelada
# blocks.3.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.3.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.3.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.3.0.shortcut.0.weight                       → congelada
# blocks.3.0.shortcut.1.weight                       → congelada
# blocks.3.0.shortcut.1.bias                         → congelada
# blocks.3.0.shortcut.2.weight                       → congelada
# blocks.3.0.shortcut.3.weight                       → congelada
# blocks.3.0.shortcut.3.bias                         → congelada
# blocks.4.0.ghost1.primary_conv.0.weight            → congelada
# blocks.4.0.ghost1.primary_conv.1.weight            → congelada
# blocks.4.0.ghost1.primary_conv.1.bias              → congelada
# blocks.4.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.4.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.4.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.4.0.se.conv_reduce.weight                   → congelada
# blocks.4.0.se.conv_reduce.bias                     → congelada
# blocks.4.0.se.conv_expand.weight                   → congelada
# blocks.4.0.se.conv_expand.bias                     → congelada
# blocks.4.0.ghost2.primary_conv.0.weight            → congelada
# blocks.4.0.ghost2.primary_conv.1.weight            → congelada
# blocks.4.0.ghost2.primary_conv.1.bias              → congelada
# blocks.4.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.4.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.4.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.5.0.ghost1.primary_conv.0.weight            → congelada
# blocks.5.0.ghost1.primary_conv.1.weight            → congelada
# blocks.5.0.ghost1.primary_conv.1.bias              → congelada
# blocks.5.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.5.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.5.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.5.0.conv_dw.weight                          → congelada
# blocks.5.0.bn_dw.weight                            → congelada
# blocks.5.0.bn_dw.bias                              → congelada
# blocks.5.0.ghost2.primary_conv.0.weight            → congelada
# blocks.5.0.ghost2.primary_conv.1.weight            → congelada
# blocks.5.0.ghost2.primary_conv.1.bias              → congelada
# blocks.5.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.5.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.5.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.5.0.shortcut.0.weight                       → congelada
# blocks.5.0.shortcut.1.weight                       → congelada
# blocks.5.0.shortcut.1.bias                         → congelada
# blocks.5.0.shortcut.2.weight                       → congelada
# blocks.5.0.shortcut.3.weight                       → congelada
# blocks.5.0.shortcut.3.bias                         → congelada
# blocks.6.0.ghost1.primary_conv.0.weight            → congelada
# blocks.6.0.ghost1.primary_conv.1.weight            → congelada
# blocks.6.0.ghost1.primary_conv.1.bias              → congelada
# blocks.6.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.6.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.6.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.6.0.ghost2.primary_conv.0.weight            → congelada
# blocks.6.0.ghost2.primary_conv.1.weight            → congelada
# blocks.6.0.ghost2.primary_conv.1.bias              → congelada
# blocks.6.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.6.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.6.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.6.1.ghost1.primary_conv.0.weight            → congelada
# blocks.6.1.ghost1.primary_conv.1.weight            → congelada
# blocks.6.1.ghost1.primary_conv.1.bias              → congelada
# blocks.6.1.ghost1.cheap_operation.0.weight         → congelada
# blocks.6.1.ghost1.cheap_operation.1.weight         → congelada
# blocks.6.1.ghost1.cheap_operation.1.bias           → congelada
# blocks.6.1.ghost2.primary_conv.0.weight            → congelada
# blocks.6.1.ghost2.primary_conv.1.weight            → congelada
# blocks.6.1.ghost2.primary_conv.1.bias              → congelada
# blocks.6.1.ghost2.cheap_operation.0.weight         → congelada
# blocks.6.1.ghost2.cheap_operation.1.weight         → congelada
# blocks.6.1.ghost2.cheap_operation.1.bias           → congelada
# blocks.6.2.ghost1.primary_conv.0.weight            → congelada
# blocks.6.2.ghost1.primary_conv.1.weight            → congelada
# blocks.6.2.ghost1.primary_conv.1.bias              → congelada
# blocks.6.2.ghost1.cheap_operation.0.weight         → congelada
# blocks.6.2.ghost1.cheap_operation.1.weight         → congelada
# blocks.6.2.ghost1.cheap_operation.1.bias           → congelada
# blocks.6.2.ghost2.primary_conv.0.weight            → congelada
# blocks.6.2.ghost2.primary_conv.1.weight            → congelada
# blocks.6.2.ghost2.primary_conv.1.bias              → congelada
# blocks.6.2.ghost2.cheap_operation.0.weight         → congelada
# blocks.6.2.ghost2.cheap_operation.1.weight         → congelada
# blocks.6.2.ghost2.cheap_operation.1.bias           → congelada
# blocks.6.3.ghost1.primary_conv.0.weight            → congelada
# blocks.6.3.ghost1.primary_conv.1.weight            → congelada
# blocks.6.3.ghost1.primary_conv.1.bias              → congelada
# blocks.6.3.ghost1.cheap_operation.0.weight         → congelada
# blocks.6.3.ghost1.cheap_operation.1.weight         → congelada
# blocks.6.3.ghost1.cheap_operation.1.bias           → congelada
# blocks.6.3.se.conv_reduce.weight                   → congelada
# blocks.6.3.se.conv_reduce.bias                     → congelada
# blocks.6.3.se.conv_expand.weight                   → congelada
# blocks.6.3.se.conv_expand.bias                     → congelada
# blocks.6.3.ghost2.primary_conv.0.weight            → congelada
# blocks.6.3.ghost2.primary_conv.1.weight            → congelada
# blocks.6.3.ghost2.primary_conv.1.bias              → congelada
# blocks.6.3.ghost2.cheap_operation.0.weight         → congelada
# blocks.6.3.ghost2.cheap_operation.1.weight         → congelada
# blocks.6.3.ghost2.cheap_operation.1.bias           → congelada
# blocks.6.3.shortcut.0.weight                       → congelada
# blocks.6.3.shortcut.1.weight                       → congelada
# blocks.6.3.shortcut.1.bias                         → congelada
# blocks.6.3.shortcut.2.weight                       → congelada
# blocks.6.3.shortcut.3.weight                       → congelada
# blocks.6.3.shortcut.3.bias                         → congelada
# blocks.6.4.ghost1.primary_conv.0.weight            → congelada
# blocks.6.4.ghost1.primary_conv.1.weight            → congelada
# blocks.6.4.ghost1.primary_conv.1.bias              → congelada
# blocks.6.4.ghost1.cheap_operation.0.weight         → congelada
# blocks.6.4.ghost1.cheap_operation.1.weight         → congelada
# blocks.6.4.ghost1.cheap_operation.1.bias           → congelada
# blocks.6.4.se.conv_reduce.weight                   → congelada
# blocks.6.4.se.conv_reduce.bias                     → congelada
# blocks.6.4.se.conv_expand.weight                   → congelada
# blocks.6.4.se.conv_expand.bias                     → congelada
# blocks.6.4.ghost2.primary_conv.0.weight            → congelada
# blocks.6.4.ghost2.primary_conv.1.weight            → congelada
# blocks.6.4.ghost2.primary_conv.1.bias              → congelada
# blocks.6.4.ghost2.cheap_operation.0.weight         → congelada
# blocks.6.4.ghost2.cheap_operation.1.weight         → congelada
# blocks.6.4.ghost2.cheap_operation.1.bias           → congelada
# blocks.7.0.ghost1.primary_conv.0.weight            → congelada
# blocks.7.0.ghost1.primary_conv.1.weight            → congelada
# blocks.7.0.ghost1.primary_conv.1.bias              → congelada
# blocks.7.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.7.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.7.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.7.0.conv_dw.weight                          → congelada
# blocks.7.0.bn_dw.weight                            → congelada
# blocks.7.0.bn_dw.bias                              → congelada
# blocks.7.0.se.conv_reduce.weight                   → congelada
# blocks.7.0.se.conv_reduce.bias                     → congelada
# blocks.7.0.se.conv_expand.weight                   → congelada
# blocks.7.0.se.conv_expand.bias                     → congelada
# blocks.7.0.ghost2.primary_conv.0.weight            → congelada
# blocks.7.0.ghost2.primary_conv.1.weight            → congelada
# blocks.7.0.ghost2.primary_conv.1.bias              → congelada
# blocks.7.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.7.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.7.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.7.0.shortcut.0.weight                       → congelada
# blocks.7.0.shortcut.1.weight                       → congelada
# blocks.7.0.shortcut.1.bias                         → congelada
# blocks.7.0.shortcut.2.weight                       → congelada
# blocks.7.0.shortcut.3.weight                       → congelada
# blocks.7.0.shortcut.3.bias                         → congelada
# blocks.8.0.ghost1.primary_conv.0.weight            → congelada
# blocks.8.0.ghost1.primary_conv.1.weight            → congelada
# blocks.8.0.ghost1.primary_conv.1.bias              → congelada
# blocks.8.0.ghost1.cheap_operation.0.weight         → congelada
# blocks.8.0.ghost1.cheap_operation.1.weight         → congelada
# blocks.8.0.ghost1.cheap_operation.1.bias           → congelada
# blocks.8.0.ghost2.primary_conv.0.weight            → congelada
# blocks.8.0.ghost2.primary_conv.1.weight            → congelada
# blocks.8.0.ghost2.primary_conv.1.bias              → congelada
# blocks.8.0.ghost2.cheap_operation.0.weight         → congelada
# blocks.8.0.ghost2.cheap_operation.1.weight         → congelada
# blocks.8.0.ghost2.cheap_operation.1.bias           → congelada
# blocks.8.1.ghost1.primary_conv.0.weight            → congelada
# blocks.8.1.ghost1.primary_conv.1.weight            → congelada
# blocks.8.1.ghost1.primary_conv.1.bias              → congelada
# blocks.8.1.ghost1.cheap_operation.0.weight         → congelada
# blocks.8.1.ghost1.cheap_operation.1.weight         → congelada
# blocks.8.1.ghost1.cheap_operation.1.bias           → congelada
# blocks.8.1.se.conv_reduce.weight                   → congelada
# blocks.8.1.se.conv_reduce.bias                     → congelada
# blocks.8.1.se.conv_expand.weight                   → congelada
# blocks.8.1.se.conv_expand.bias                     → congelada
# blocks.8.1.ghost2.primary_conv.0.weight            → congelada
# blocks.8.1.ghost2.primary_conv.1.weight            → congelada
# blocks.8.1.ghost2.primary_conv.1.bias              → congelada
# blocks.8.1.ghost2.cheap_operation.0.weight         → congelada
# blocks.8.1.ghost2.cheap_operation.1.weight         → congelada
# blocks.8.1.ghost2.cheap_operation.1.bias           → congelada
# blocks.8.2.ghost1.primary_conv.0.weight            → congelada
# blocks.8.2.ghost1.primary_conv.1.weight            → congelada
# blocks.8.2.ghost1.primary_conv.1.bias              → congelada
# blocks.8.2.ghost1.cheap_operation.0.weight         → congelada
# blocks.8.2.ghost1.cheap_operation.1.weight         → congelada
# blocks.8.2.ghost1.cheap_operation.1.bias           → congelada
# blocks.8.2.ghost2.primary_conv.0.weight            → congelada
# blocks.8.2.ghost2.primary_conv.1.weight            → congelada
# blocks.8.2.ghost2.primary_conv.1.bias              → congelada
# blocks.8.2.ghost2.cheap_operation.0.weight         → congelada
# blocks.8.2.ghost2.cheap_operation.1.weight         → congelada
# blocks.8.2.ghost2.cheap_operation.1.bias           → congelada
# blocks.8.3.ghost1.primary_conv.0.weight            → congelada
# blocks.8.3.ghost1.primary_conv.1.weight            → congelada
# blocks.8.3.ghost1.primary_conv.1.bias              → congelada
# blocks.8.3.ghost1.cheap_operation.0.weight         → congelada
# blocks.8.3.ghost1.cheap_operation.1.weight         → congelada
# blocks.8.3.ghost1.cheap_operation.1.bias           → congelada
# blocks.8.3.se.conv_reduce.weight                   → congelada
# blocks.8.3.se.conv_reduce.bias                     → congelada
# blocks.8.3.se.conv_expand.weight                   → congelada
# blocks.8.3.se.conv_expand.bias                     → congelada
# blocks.8.3.ghost2.primary_conv.0.weight            → congelada
# blocks.8.3.ghost2.primary_conv.1.weight            → congelada
# blocks.8.3.ghost2.primary_conv.1.bias              → congelada
# blocks.8.3.ghost2.cheap_operation.0.weight         → congelada
# blocks.8.3.ghost2.cheap_operation.1.weight         → congelada
# blocks.8.3.ghost2.cheap_operation.1.bias           → congelada
# blocks.9.0.conv.weight                             → entrenable
# blocks.9.0.bn1.weight                              → entrenable
# blocks.9.0.bn1.bias                                → entrenable
# conv_head.weight                                   → entrenable
# conv_head.bias                                     → entrenable

# %%
multiVGG = MultiImageFlexibleVGG(v_model).to(device)
featLSTM = FeatLSTM(1280, 512).to(device)

# %%
tokenizer = AutoTokenizer.from_pretrained("Recognai/distilbert-base-es-multilingual-cased")
model = AutoModel.from_pretrained("Recognai/distilbert-base-es-multilingual-cased")

# %%
for param in model.parameters():
    param.requires_grad = False

for name, param in model.named_parameters():
    if '5.output_layer_norm' in name or '5.ffn' in name:
        param.requires_grad = True

# %%
for name, param in model.named_parameters():
    estado = "entrenable" if param.requires_grad else "congelada"
    print(f"{name:50} → {estado}")
# Out:
# embeddings.word_embeddings.weight                  → congelada
# embeddings.position_embeddings.weight              → congelada
# embeddings.LayerNorm.weight                        → congelada
# embeddings.LayerNorm.bias                          → congelada
# transformer.layer.0.attention.q_lin.weight         → congelada
# transformer.layer.0.attention.q_lin.bias           → congelada
# transformer.layer.0.attention.k_lin.weight         → congelada
# transformer.layer.0.attention.k_lin.bias           → congelada
# transformer.layer.0.attention.v_lin.weight         → congelada
# transformer.layer.0.attention.v_lin.bias           → congelada
# transformer.layer.0.attention.out_lin.weight       → congelada
# transformer.layer.0.attention.out_lin.bias         → congelada
# transformer.layer.0.sa_layer_norm.weight           → congelada
# transformer.layer.0.sa_layer_norm.bias             → congelada
# transformer.layer.0.ffn.lin1.weight                → congelada
# transformer.layer.0.ffn.lin1.bias                  → congelada
# transformer.layer.0.ffn.lin2.weight                → congelada
# transformer.layer.0.ffn.lin2.bias                  → congelada
# transformer.layer.0.output_layer_norm.weight       → congelada
# transformer.layer.0.output_layer_norm.bias         → congelada
# transformer.layer.1.attention.q_lin.weight         → congelada
# transformer.layer.1.attention.q_lin.bias           → congelada
# transformer.layer.1.attention.k_lin.weight         → congelada
# transformer.layer.1.attention.k_lin.bias           → congelada
# transformer.layer.1.attention.v_lin.weight         → congelada
# transformer.layer.1.attention.v_lin.bias           → congelada
# transformer.layer.1.attention.out_lin.weight       → congelada
# transformer.layer.1.attention.out_lin.bias         → congelada
# transformer.layer.1.sa_layer_norm.weight           → congelada
# transformer.layer.1.sa_layer_norm.bias             → congelada
# transformer.layer.1.ffn.lin1.weight                → congelada
# transformer.layer.1.ffn.lin1.bias                  → congelada
# transformer.layer.1.ffn.lin2.weight                → congelada
# transformer.layer.1.ffn.lin2.bias                  → congelada
# transformer.layer.1.output_layer_norm.weight       → congelada
# transformer.layer.1.output_layer_norm.bias         → congelada
# transformer.layer.2.attention.q_lin.weight         → congelada
# transformer.layer.2.attention.q_lin.bias           → congelada
# transformer.layer.2.attention.k_lin.weight         → congelada
# transformer.layer.2.attention.k_lin.bias           → congelada
# transformer.layer.2.attention.v_lin.weight         → congelada
# transformer.layer.2.attention.v_lin.bias           → congelada
# transformer.layer.2.attention.out_lin.weight       → congelada
# transformer.layer.2.attention.out_lin.bias         → congelada
# transformer.layer.2.sa_layer_norm.weight           → congelada
# transformer.layer.2.sa_layer_norm.bias             → congelada
# transformer.layer.2.ffn.lin1.weight                → congelada
# transformer.layer.2.ffn.lin1.bias                  → congelada
# transformer.layer.2.ffn.lin2.weight                → congelada
# transformer.layer.2.ffn.lin2.bias                  → congelada
# transformer.layer.2.output_layer_norm.weight       → congelada
# transformer.layer.2.output_layer_norm.bias         → congelada
# transformer.layer.3.attention.q_lin.weight         → congelada
# transformer.layer.3.attention.q_lin.bias           → congelada
# transformer.layer.3.attention.k_lin.weight         → congelada
# transformer.layer.3.attention.k_lin.bias           → congelada
# transformer.layer.3.attention.v_lin.weight         → congelada
# transformer.layer.3.attention.v_lin.bias           → congelada
# transformer.layer.3.attention.out_lin.weight       → congelada
# transformer.layer.3.attention.out_lin.bias         → congelada
# transformer.layer.3.sa_layer_norm.weight           → congelada
# transformer.layer.3.sa_layer_norm.bias             → congelada
# transformer.layer.3.ffn.lin1.weight                → congelada
# transformer.layer.3.ffn.lin1.bias                  → congelada
# transformer.layer.3.ffn.lin2.weight                → congelada
# transformer.layer.3.ffn.lin2.bias                  → congelada
# transformer.layer.3.output_layer_norm.weight       → congelada
# transformer.layer.3.output_layer_norm.bias         → congelada
# transformer.layer.4.attention.q_lin.weight         → congelada
# transformer.layer.4.attention.q_lin.bias           → congelada
# transformer.layer.4.attention.k_lin.weight         → congelada
# transformer.layer.4.attention.k_lin.bias           → congelada
# transformer.layer.4.attention.v_lin.weight         → congelada
# transformer.layer.4.attention.v_lin.bias           → congelada
# transformer.layer.4.attention.out_lin.weight       → congelada
# transformer.layer.4.attention.out_lin.bias         → congelada
# transformer.layer.4.sa_layer_norm.weight           → congelada
# transformer.layer.4.sa_layer_norm.bias             → congelada
# transformer.layer.4.ffn.lin1.weight                → congelada
# transformer.layer.4.ffn.lin1.bias                  → congelada
# transformer.layer.4.ffn.lin2.weight                → congelada
# transformer.layer.4.ffn.lin2.bias                  → congelada
# transformer.layer.4.output_layer_norm.weight       → congelada
# transformer.layer.4.output_layer_norm.bias         → congelada
# transformer.layer.5.attention.q_lin.weight         → congelada
# transformer.layer.5.attention.q_lin.bias           → congelada
# transformer.layer.5.attention.k_lin.weight         → congelada
# transformer.layer.5.attention.k_lin.bias           → congelada
# transformer.layer.5.attention.v_lin.weight         → congelada
# transformer.layer.5.attention.v_lin.bias           → congelada
# transformer.layer.5.attention.out_lin.weight       → congelada
# transformer.layer.5.attention.out_lin.bias         → congelada
# transformer.layer.5.sa_layer_norm.weight           → congelada
# transformer.layer.5.sa_layer_norm.bias             → congelada
# transformer.layer.5.ffn.lin1.weight                → entrenable
# transformer.layer.5.ffn.lin1.bias                  → entrenable
# transformer.layer.5.ffn.lin2.weight                → entrenable
# transformer.layer.5.ffn.lin2.bias                  → entrenable
# transformer.layer.5.output_layer_norm.weight       → entrenable
# transformer.layer.5.output_layer_norm.bias         → entrenable

# %%
textmodel = TextModel(tokenizer, model, device).to(device)

# %%
multimodal_model = MultimodalModel(multiVGG, featLSTM, textmodel, device)

# %%
trainloader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)
devloader = DataLoader(dev_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)
testloader = DataLoader(test_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)

# %%
earlystopping = EarlyStopping(patience = 12, min_delta=0.01)

# %%
trainer = Trainer(multimodal_model.to(device), train_dataset, trainloader, devloader, testloader, 30, 0.001, device, True, earlystopping)

# %%
trainer.train()
# Out:
# Epoch 1/30, Loss: 0.1713414490222931
# Epoch 1/30, Loss: 0.6342011094093323
# Epoch 1/30, Loss: 1.241392731666565
# Epoch 1/30, Loss: 0.4843325912952423
# Epoch 1/30, Loss: 0.2563340663909912
# Epoch 1/30, Loss: 2.6854259967803955
# Epoch 1/30, Loss: 0.1396353542804718
# Epoch 1/30, Loss: 0.26212918758392334
# Epoch 1/30, Loss: 0.3765050172805786
# Epoch 1/30, Loss: 0.273301899433136
# Epoch 1/30, Loss: 0.2794382572174072
# Epoch 1/30, Loss: 0.4893430471420288
# Epoch 1/30, Loss: 0.13794009387493134
# Epoch 1/30, Loss: 0.20097225904464722
# Epoch 1/30, Loss: 0.11067746579647064
# Epoch 1/30, Loss: 35.74848937988281
# Epoch 1/30, Loss: 0.7789672613143921
# Epoch 1/30, Loss: 0.14330121874809265
# Epoch 1/30, Loss: 1.0006150007247925
# Epoch 1/30, Loss: 0.21298864483833313
# Epoch 1/30, Loss: 0.22624196112155914
# Epoch 1/30, Loss: 2.789778709411621
# Epoch 1/30, Loss: 0.2403961718082428
# Epoch 1/30, Loss: 0.15360543131828308
# Epoch 1/30, Loss: 0.17403990030288696
# Epoch 1/30, Loss: 0.24317757785320282
# Epoch 1/30, Loss: 0.14719124138355255
# Epoch 1/30, Loss: 0.28750553727149963
# Epoch 1/30, Loss: 0.1710537075996399
# Epoch 1/30, Loss: 0.2914219796657562
# Epoch 1/30, Loss: 0.21407422423362732
# Epoch 1/30, Loss: 0.39532893896102905
# Epoch 1/30, Loss: 0.1866312474012375
# Epoch 1/30, Loss: 0.5639607906341553
# Epoch 1/30, Loss: 0.74859619140625
# Epoch 1/30, Loss: 0.5588749051094055
# Epoch 1/30, Loss: 0.24035429954528809
# Epoch 1/30, Loss: 0.7048656940460205
# Epoch 1/30, Loss: 0.1193198561668396
# Epoch 1/30, Loss: 0.509827733039856
# Epoch 1/30, Loss: 0.17420127987861633
# Epoch 1/30, Loss: 0.2859151363372803
# Epoch 1/30, Loss: 0.44680076837539673
# Epoch 1/30, Loss: 0.3323514759540558
# Epoch 1/30, Loss: 0.305177241563797
# Epoch 1/30, Loss: 0.13925224542617798
# Epoch 1/30, Loss: 0.3499596118927002
# Epoch 1/30, Loss: 0.6171940565109253
# Epoch 1/30, Loss: 0.7587131857872009
# Epoch 1/30, Loss: 0.28381431102752686
# Epoch 1/30, Loss: 0.15008622407913208
# Epoch 1/30, Loss: 0.13952653110027313
# Epoch 1/30, Loss: 0.19997179508209229
# Epoch 1/30, Loss: 0.2437492311000824
# Epoch 1/30, Loss: 0.12422983348369598
# Epoch 1/30, Loss: 4.662233352661133
# Epoch 1/30, Loss: 0.10936228930950165
# Epoch 1/30, Loss: 0.41143500804901123
# Epoch 1/30, Loss: 6.339938163757324
# Epoch 1/30, Loss: 0.15365993976593018
# Epoch 1/30, Loss: 0.1961715668439865
# Epoch 1/30, Loss: 0.4432990550994873
# Epoch 1/30, Loss: 0.3219718039035797
# Epoch 1/30, Loss: 0.49904850125312805
# Epoch 1/30, Loss: 0.3709196448326111
# Epoch 1/30, Loss: 0.6957613229751587
# Epoch 1/30, Loss: 0.8697831630706787
# Epoch 1/30, Loss: 0.10119645297527313
# Epoch 1/30, Loss: 0.12215197831392288
# Epoch 1/30, Loss: 0.5555099844932556
# Epoch 1/30, Loss: 2.931614875793457
# Epoch 1/30, Loss: 1.492286205291748
# Epoch 1/30, Loss: 0.3759765625
# Epoch 1/30, Loss: 0.31174084544181824
# Epoch 1/30, Loss: 0.5203856825828552
# Epoch 1/30, Loss: 0.2528066337108612
# Epoch 1/30, Loss: 1.6208670139312744
# Epoch 1/30, Loss: 6.126413822174072
# Epoch 1/30, Loss: 0.34433338046073914
# Epoch 1/30, Loss: 0.2987140715122223
# Epoch 1/30, Loss: 0.24916552007198334
# Epoch 1/30, Loss: 0.2426484078168869
# Epoch 1/30, Loss: 0.21442720293998718
# Epoch 1/30, Loss: 0.5459520220756531
# Epoch 1/30, Loss: 0.1839224100112915
# Epoch 1/30, Loss: 0.24996469914913177
# Epoch 1/30, Loss: 0.5401101112365723
# Epoch 1/30, Loss: 0.8803382515907288
# Epoch 1/30, Loss: 0.21240761876106262
# Epoch 1/30, Loss: 0.22557400166988373
# Epoch 1/30, Loss: 0.08037680387496948
# Epoch 1/30, Loss: 0.11855494976043701
# Epoch 1/30, Loss: 0.1419418603181839
# Epoch 1/30, Loss: 2.917309045791626
# Epoch 1/30, Loss: 0.20549027621746063
# Epoch 1/30, Loss: 0.3308379352092743
# Epoch 1/30, Loss: 0.1366707682609558
# Epoch 1/30, Loss: 0.12153379619121552
# Epoch 1/30, Loss: 0.9922671318054199
# Epoch 1/30, Loss: 0.14357352256774902
# Epoch 1/30, Loss: 0.11900237947702408
# Epoch 1/30, Loss: 7.446885585784912
# Epoch 1/30, Loss: 0.14974240958690643
# Epoch 1/30, Loss: 0.12801288068294525
# Epoch 1/30, Loss: 0.19578678905963898
# Epoch 1/30, Loss: 0.25439706444740295
# Epoch 1/30, Loss: 0.5113774538040161
# Epoch 1/30, Loss: 0.3731660544872284
# Epoch 1/30, Loss: 8.086248397827148
# Epoch 1/30, Loss: 0.4104022979736328
# Epoch 1/30, Loss: 0.3675660192966461
# Epoch 1/30, Loss: 0.1302715241909027
# Epoch 1/30, Loss: 0.06288336217403412
# Epoch 1/30, Loss: 0.14246517419815063
# Epoch 1/30, Loss: 0.2630886435508728
# Epoch 1/30, Loss: 0.36351123452186584
# Epoch 1/30, Loss: 0.31350767612457275
# Epoch 1/30, Loss: 0.10334840416908264
# Epoch 1/30, Loss: 0.20658302307128906
# Epoch 1/30, Loss: 0.15206211805343628
# Epoch 1/30, Loss: 0.2365422248840332
# Epoch 1/30, Loss: 0.6466221809387207
# Epoch 1/30, Loss: 7.097517967224121
# Epoch 1/30, Loss: 2.8010919094085693
# Epoch 1/30, Loss: 0.23557768762111664
# Epoch 1/30, Loss: 0.42291033267974854
# Epoch 1/30, Loss: 0.17500925064086914
# Epoch 1/30, Loss: 0.1564672738313675
# Epoch 1/30, Loss: 0.14190368354320526
# Epoch 1/30, Loss: 0.3251999020576477
# Epoch 1/30, Loss: 0.36548489332199097
# Epoch 1/30, Loss: 0.21623560786247253
# Epoch 1/30, Loss: 0.8398215770721436
# Epoch 1/30, Loss: 0.09462408721446991
# Epoch 1/30, Loss: 0.11656970530748367
# Epoch 1/30, Loss: 4.0615129470825195
# Epoch 1/30, Loss: 0.13648270070552826
# Epoch 1/30, Loss: 0.09194455295801163
# Epoch 1/30, Loss: 0.33319902420043945
# Epoch 1/30, Loss: 7.1816182136535645
# Epoch 1/30, Loss: 0.32988041639328003
# Epoch 1/30, Loss: 0.6318075656890869
# Epoch 1/30, Loss: 0.1591821163892746
# Epoch 1/30, Loss: 0.3288118839263916
# Epoch 1/30, Loss: 0.3830157220363617
# Epoch 1/30, Loss: 0.09030773490667343
# Epoch 1/30, Loss: 0.13630004227161407
# Epoch 1/30, Loss: 0.5048351883888245
# Epoch 1/30, Loss: 2.068575859069824
# Epoch 1/30, Loss: 0.25358688831329346
# Epoch 1/30, Loss: 0.16131684184074402
# Epoch 1/30, Loss: 0.19215741753578186
# Epoch 1/30, Loss: 0.19062666594982147
# Epoch 1/30, Loss: 0.3571321368217468
# Epoch 1/30, Loss: 0.27996134757995605
# Epoch 1/30, Loss: 0.07502555847167969
# Epoch 1/30, Loss: 0.4797706604003906
# Epoch 1/30, Loss: 0.2634424865245819
# Epoch 1/30, Loss: 0.11200641095638275
# Epoch 1/30, Loss: 0.07045776396989822
# Epoch 1/30, Loss: 0.1484145224094391
# Epoch 1/30, Loss: 0.09991161525249481
# Epoch 1/30, Loss: 0.0904376357793808
# Epoch 1/30, Loss: 0.10910726338624954
# Epoch 1/30, Loss: 0.4994580149650574
# Epoch 1/30, Loss: 0.05341125279664993
# Epoch 1/30, Loss: 0.06369063258171082
# Epoch 1/30, Loss: 0.3070506453514099
# Epoch 1/30, Loss: 0.15484429895877838
# Epoch 1/30, Loss: 0.09177008271217346
# Epoch 1/30, Loss: 0.10113571584224701
# Epoch 1/30, Loss: 0.14803114533424377
# Epoch 1/30, Loss: 0.15862272679805756
# Epoch 1/30, Loss: 0.07338526844978333
# Epoch 1/30, Loss: 0.15451779961585999
# Epoch 1/30, Loss: 0.9035967588424683
# Epoch 1/30, Loss: 0.36639484763145447
# Epoch 1/30, Loss: 0.15372952818870544
# Epoch 1/30, Loss: 0.1135977953672409
# Epoch 1/30, Loss: 1.734079360961914
# Epoch 1/30, Loss: 0.12469559162855148
# Epoch 1/30, Loss: 0.21826283633708954
# Epoch 1/30, Loss: 0.09252628684043884
# Epoch 1/30, Loss: 0.49467718601226807
# Epoch 1/30, Loss: 0.08846449851989746
# Epoch 1/30, Loss: 0.10717999935150146
# Epoch 1/30, Loss: 0.6647154092788696
# Epoch 1/30, Loss: 0.24142587184906006
# Epoch 1/30, Loss: 0.1429515779018402
# Epoch 1/30, Loss: 0.3728275001049042
# Epoch 1/30, Loss: 0.13745945692062378
# Epoch 1/30, Loss: 17.900033950805664
# Epoch 1/30, Loss: 0.32521292567253113
# Epoch 1/30, Loss: 0.4266607463359833
# Epoch 1/30, Loss: 0.3080825209617615
# Epoch 1/30, Loss: 0.09362079203128815
# Epoch 1/30, Loss: 0.13622450828552246
# Epoch 1/30, Loss: 1.8808400630950928
# Epoch 1/30, Loss: 0.18426869809627533
# Epoch 1/30, Loss: 0.26267188787460327
# Epoch 1/30, Loss: 0.6743748188018799
# Epoch 1/30, Loss: 0.5812022089958191
# Epoch 1/30, Loss: 14.140728950500488
# Epoch 1/30, Loss: 0.19787496328353882
# Epoch 1/30, Loss: 0.05568986013531685
# Epoch 1/30, Loss: 0.1106935515999794
# Epoch 1/30, Loss: 0.2970302999019623
# Epoch 1/30, Loss: 0.12476697564125061
# Epoch 1/30, Loss: 0.07582508772611618
# Epoch 1/30, Loss: 0.20911532640457153
# Epoch 1/30, Loss: 0.24542297422885895
# Epoch 1/30, Loss: 0.3180570900440216
# Epoch 1/30, Loss: 0.12519675493240356
# Epoch 1/30, Loss: 3.063214063644409
# Epoch 1/30, Loss: 0.22110025584697723
# Epoch 1/30, Loss: 0.122381791472435
# Epoch 1/30, Eval Loss: 3.195198355959012
# Epoch 2/30, Loss: 0.23459768295288086
# Epoch 2/30, Loss: 0.6037119626998901
# Epoch 2/30, Loss: 0.20014485716819763
# Epoch 2/30, Loss: 0.36427971720695496
# Epoch 2/30, Loss: 1.1445165872573853
# Epoch 2/30, Loss: 0.13748468458652496
# Epoch 2/30, Loss: 0.1637035310268402
# Epoch 2/30, Loss: 0.07986301183700562
# Epoch 2/30, Loss: 0.6879767775535583
# Epoch 2/30, Loss: 0.18900799751281738
# Epoch 2/30, Loss: 0.14868277311325073
# Epoch 2/30, Loss: 0.16952408850193024
# Epoch 2/30, Loss: 0.1627376675605774
# Epoch 2/30, Loss: 0.06225873529911041
# Epoch 2/30, Loss: 0.0766267329454422
# Epoch 2/30, Loss: 5.038172721862793
# Epoch 2/30, Loss: 0.19610381126403809
# Epoch 2/30, Loss: 0.3403606414794922
# Epoch 2/30, Loss: 0.31145748496055603
# Epoch 2/30, Loss: 0.25298795104026794
# Epoch 2/30, Loss: 0.34989133477211
# Epoch 2/30, Loss: 0.19379670917987823
# Epoch 2/30, Loss: 0.1230010837316513
# Epoch 2/30, Loss: 0.14669466018676758
# Epoch 2/30, Loss: 0.8982781767845154
# Epoch 2/30, Loss: 0.1281118243932724
# Epoch 2/30, Loss: 0.1299026757478714
# Epoch 2/30, Loss: 0.5980060696601868
# Epoch 2/30, Loss: 0.08515267074108124
# Epoch 2/30, Loss: 0.1039271131157875
# Epoch 2/30, Loss: 0.08697706460952759
# Epoch 2/30, Loss: 0.21703024208545685
# Epoch 2/30, Loss: 1.9993468523025513
# Epoch 2/30, Loss: 0.1918306201696396
# Epoch 2/30, Loss: 0.16652178764343262
# Epoch 2/30, Loss: 0.2563377320766449
# Epoch 2/30, Loss: 0.1805914044380188
# Epoch 2/30, Loss: 0.20788082480430603
# Epoch 2/30, Loss: 0.07165723294019699
# Epoch 2/30, Loss: 0.14935718476772308
# Epoch 2/30, Loss: 0.21336553990840912
# Epoch 2/30, Loss: 0.09901155531406403
# Epoch 2/30, Loss: 0.48542535305023193
# Epoch 2/30, Loss: 0.18693843483924866
# Epoch 2/30, Loss: 0.10905483365058899
# Epoch 2/30, Loss: 0.1009453684091568
# Epoch 2/30, Loss: 0.06998279690742493
# Epoch 2/30, Loss: 0.23495343327522278
# Epoch 2/30, Loss: 0.2632536292076111
# Epoch 2/30, Loss: 0.10847063362598419
# Epoch 2/30, Loss: 0.10448284447193146
# Epoch 2/30, Loss: 0.11629890650510788
# Epoch 2/30, Loss: 0.20167818665504456
# Epoch 2/30, Loss: 0.13112199306488037
# Epoch 2/30, Loss: 0.08172078430652618
# Epoch 2/30, Loss: 0.16325600445270538
# Epoch 2/30, Loss: 0.1796119511127472
# Epoch 2/30, Loss: 12.758939743041992
# Epoch 2/30, Loss: 0.09970244020223618
# Epoch 2/30, Loss: 0.14284448325634003
# Epoch 2/30, Loss: 0.11681661754846573
# Epoch 2/30, Loss: 0.14392483234405518
# Epoch 2/30, Loss: 0.40965399146080017
# Epoch 2/30, Loss: 0.7442817091941833
# Epoch 2/30, Loss: 0.5035964250564575
# Epoch 2/30, Loss: 0.25776243209838867
# Epoch 2/30, Loss: 0.6855783462524414
# Epoch 2/30, Loss: 0.5450817346572876
# Epoch 2/30, Loss: 0.20301467180252075
# Epoch 2/30, Loss: 0.1521046757698059
# Epoch 2/30, Loss: 0.2932862341403961
# Epoch 2/30, Loss: 0.43039196729660034
# Epoch 2/30, Loss: 0.8971855640411377
# Epoch 2/30, Loss: 0.6787381172180176
# Epoch 2/30, Loss: 0.13965776562690735
# Epoch 2/30, Loss: 0.09761419892311096
# Epoch 2/30, Loss: 0.47150927782058716
# Epoch 2/30, Loss: 0.07113010436296463
# Epoch 2/30, Loss: 0.27724719047546387
# Epoch 2/30, Loss: 0.1404493898153305
# Epoch 2/30, Loss: 3.008944511413574
# Epoch 2/30, Loss: 0.707711935043335
# Epoch 2/30, Loss: 0.15526479482650757
# Epoch 2/30, Loss: 0.4366823732852936
# Epoch 2/30, Loss: 0.4597129225730896
# Epoch 2/30, Loss: 0.16911381483078003
# Epoch 2/30, Loss: 0.48230859637260437
# Epoch 2/30, Loss: 0.5218279361724854
# Epoch 2/30, Loss: 0.23175689578056335
# Epoch 2/30, Loss: 0.5475260019302368
# Epoch 2/30, Loss: 0.21226826310157776
# Epoch 2/30, Loss: 6.65855598449707
# Epoch 2/30, Loss: 0.1563788652420044
# Epoch 2/30, Loss: 0.1981765627861023
# Epoch 2/30, Loss: 13.924599647521973
# Epoch 2/30, Loss: 0.7263576984405518
# Epoch 2/30, Loss: 0.8578982353210449
# Epoch 2/30, Loss: 0.22365185618400574
# Epoch 2/30, Loss: 0.1739993393421173
# Epoch 2/30, Loss: 0.14981773495674133
# Epoch 2/30, Loss: 6.466891765594482
# Epoch 2/30, Loss: 0.3123740553855896
# Epoch 2/30, Loss: 0.26574522256851196
# Epoch 2/30, Loss: 2.9475302696228027
# Epoch 2/30, Loss: 0.7148309350013733
# Epoch 2/30, Loss: 0.2489287406206131
# Epoch 2/30, Loss: 0.19296517968177795
# Epoch 2/30, Loss: 0.35885298252105713
# Epoch 2/30, Loss: 5.689797401428223
# Epoch 2/30, Loss: 1.9154939651489258
# Epoch 2/30, Loss: 0.12833258509635925
# Epoch 2/30, Loss: 0.1728600114583969
# Epoch 2/30, Loss: 0.18337494134902954
# Epoch 2/30, Loss: 0.9720356464385986
# Epoch 2/30, Loss: 0.15266737341880798
# Epoch 2/30, Loss: 0.12900042533874512
# Epoch 2/30, Loss: 0.13226516544818878
# Epoch 2/30, Loss: 0.13893455266952515
# Epoch 2/30, Loss: 0.23036804795265198
# Epoch 2/30, Loss: 0.1699058711528778
# Epoch 2/30, Loss: 1.7292383909225464
# Epoch 2/30, Loss: 0.40935420989990234
# Epoch 2/30, Loss: 2.066079616546631
# Epoch 2/30, Loss: 0.46422526240348816
# Epoch 2/30, Loss: 0.2603883743286133
# Epoch 2/30, Loss: 0.49608176946640015
# Epoch 2/30, Loss: 0.9474440813064575
# Epoch 2/30, Loss: 0.20456275343894958
# Epoch 2/30, Loss: 3.928377389907837
# Epoch 2/30, Loss: 2.6484880447387695
# Epoch 2/30, Loss: 0.9112149477005005
# Epoch 2/30, Loss: 0.06944634020328522
# Epoch 2/30, Loss: 0.07215607911348343
# Epoch 2/30, Loss: 0.2852795124053955
# Epoch 2/30, Loss: 0.15612399578094482
# Epoch 2/30, Loss: 0.1261037141084671
# Epoch 2/30, Loss: 0.5420388579368591
# Epoch 2/30, Loss: 0.3009861707687378
# Epoch 2/30, Loss: 0.1793917417526245
# Epoch 2/30, Loss: 0.3061195909976959
# Epoch 2/30, Loss: 0.25229158997535706
# Epoch 2/30, Loss: 0.24051973223686218
# Epoch 2/30, Loss: 1.0742703676223755
# Epoch 2/30, Loss: 0.08066289126873016
# Epoch 2/30, Loss: 0.9994032382965088
# Epoch 2/30, Loss: 0.6875289678573608
# Epoch 2/30, Loss: 0.2028181254863739
# Epoch 2/30, Loss: 0.17060236632823944
# Epoch 2/30, Loss: 0.25254493951797485
# Epoch 2/30, Loss: 0.1679690182209015
# Epoch 2/30, Loss: 0.2053217589855194
# Epoch 2/30, Loss: 0.0479184091091156
# Epoch 2/30, Loss: 2.3709819316864014
# Epoch 2/30, Loss: 0.3481271266937256
# Epoch 2/30, Loss: 0.17789104580879211
# Epoch 2/30, Loss: 0.23710578680038452
# Epoch 2/30, Loss: 8.112690925598145
# Epoch 2/30, Loss: 35.05889892578125
# Epoch 2/30, Loss: 0.31304535269737244
# Epoch 2/30, Loss: 0.2962873578071594
# Epoch 2/30, Loss: 0.394287645816803
# Epoch 2/30, Loss: 0.12964150309562683
# Epoch 2/30, Loss: 0.5597804188728333
# Epoch 2/30, Loss: 0.38036954402923584
# Epoch 2/30, Loss: 0.11932874470949173
# Epoch 2/30, Loss: 0.2792016267776489
# Epoch 2/30, Loss: 0.8463808298110962
# Epoch 2/30, Loss: 0.18034306168556213
# Epoch 2/30, Loss: 0.17011423408985138
# Epoch 2/30, Loss: 0.24368910491466522
# Epoch 2/30, Loss: 0.23213672637939453
# Epoch 2/30, Loss: 0.27785223722457886
# Epoch 2/30, Loss: 0.340948224067688
# Epoch 2/30, Loss: 0.22397220134735107
# Epoch 2/30, Loss: 1.1098805665969849
# Epoch 2/30, Loss: 0.1679486185312271
# Epoch 2/30, Loss: 0.615752100944519
# Epoch 2/30, Loss: 0.4823791980743408
# Epoch 2/30, Loss: 0.44505658745765686
# Epoch 2/30, Loss: 0.0794190838932991
# Epoch 2/30, Loss: 0.13505014777183533
# Epoch 2/30, Loss: 0.1389697641134262
# Epoch 2/30, Loss: 0.0645703598856926
# Epoch 2/30, Loss: 0.13665032386779785
# Epoch 2/30, Loss: 0.5420543551445007
# Epoch 2/30, Loss: 0.12742990255355835
# Epoch 2/30, Loss: 0.7085046768188477
# Epoch 2/30, Loss: 0.12394832074642181
# Epoch 2/30, Loss: 1.6343790292739868
# Epoch 2/30, Loss: 0.35379788279533386
# Epoch 2/30, Loss: 0.1736915409564972
# Epoch 2/30, Loss: 0.14008432626724243
# Epoch 2/30, Loss: 2.3158955574035645
# Epoch 2/30, Loss: 0.13826440274715424
# Epoch 2/30, Loss: 0.11997377127408981
# Epoch 2/30, Loss: 0.38620859384536743
# Epoch 2/30, Loss: 0.15142448246479034
# Epoch 2/30, Loss: 0.30833086371421814
# Epoch 2/30, Loss: 0.12939614057540894
# Epoch 2/30, Loss: 0.17461739480495453
# Epoch 2/30, Loss: 0.11032901704311371
# Epoch 2/30, Loss: 0.1534380316734314
# Epoch 2/30, Loss: 0.1907532960176468
# Epoch 2/30, Loss: 0.11193438619375229
# Epoch 2/30, Loss: 0.0786229819059372
# Epoch 2/30, Loss: 2.217733144760132
# Epoch 2/30, Loss: 0.5658568143844604
# Epoch 2/30, Loss: 0.1044338047504425
# Epoch 2/30, Loss: 0.16389241814613342
# Epoch 2/30, Loss: 0.27837908267974854
# Epoch 2/30, Loss: 0.10995550453662872
# Epoch 2/30, Loss: 0.23735183477401733
# Epoch 2/30, Loss: 6.762384414672852
# Epoch 2/30, Loss: 0.38278907537460327
# Epoch 2/30, Loss: 0.3644530177116394
# Epoch 2/30, Loss: 0.16497068107128143
# Epoch 2/30, Eval Loss: 3.140256108286289
# Epoch 3/30, Loss: 0.10849516838788986
# Epoch 3/30, Loss: 22.099075317382812
# Epoch 3/30, Loss: 1.9939699172973633
# Epoch 3/30, Loss: 0.561241626739502
# Epoch 3/30, Loss: 0.41640546917915344
# Epoch 3/30, Loss: 0.2914963364601135
# Epoch 3/30, Loss: 0.22209589183330536
# Epoch 3/30, Loss: 0.7103099226951599
# Epoch 3/30, Loss: 0.1220393106341362
# Epoch 3/30, Loss: 0.21711690723896027
# Epoch 3/30, Loss: 0.09471069276332855
# Epoch 3/30, Loss: 0.1832738220691681
# Epoch 3/30, Loss: 0.22838212549686432
# Epoch 3/30, Loss: 5.541060924530029
# Epoch 3/30, Loss: 1.0363376140594482
# Epoch 3/30, Loss: 0.4262668192386627
# Epoch 3/30, Loss: 0.7164186239242554
# Epoch 3/30, Loss: 0.3232177793979645
# Epoch 3/30, Loss: 4.539017677307129
# Epoch 3/30, Loss: 0.26309409737586975
# Epoch 3/30, Loss: 0.27086687088012695
# Epoch 3/30, Loss: 0.37734246253967285
# Epoch 3/30, Loss: 0.18990333378314972
# Epoch 3/30, Loss: 0.2745078206062317
# Epoch 3/30, Loss: 0.5713636875152588
# Epoch 3/30, Loss: 0.5370343327522278
# Epoch 3/30, Loss: 0.5151711702346802
# Epoch 3/30, Loss: 0.3003414571285248
# Epoch 3/30, Loss: 0.26102352142333984
# Epoch 3/30, Loss: 0.13404768705368042
# Epoch 3/30, Loss: 0.16121995449066162
# Epoch 3/30, Loss: 0.2164650857448578
# Epoch 3/30, Loss: 0.210921049118042
# Epoch 3/30, Loss: 0.19780641794204712
# Epoch 3/30, Loss: 0.17764517664909363
# Epoch 3/30, Loss: 0.3300468921661377
# Epoch 3/30, Loss: 0.15476222336292267
# Epoch 3/30, Loss: 0.31220585107803345
# Epoch 3/30, Loss: 0.22399529814720154
# Epoch 3/30, Loss: 0.858969509601593
# Epoch 3/30, Loss: 0.13410669565200806
# Epoch 3/30, Loss: 0.22885341942310333
# Epoch 3/30, Loss: 0.28945213556289673
# Epoch 3/30, Loss: 34.57490921020508
# Epoch 3/30, Loss: 0.16041558980941772
# Epoch 3/30, Loss: 0.19283053278923035
# Epoch 3/30, Loss: 0.15922877192497253
# Epoch 3/30, Loss: 0.319510817527771
# Epoch 3/30, Loss: 0.2525806128978729
# Epoch 3/30, Loss: 0.19657810032367706
# Epoch 3/30, Loss: 0.43690595030784607
# Epoch 3/30, Loss: 0.15237858891487122
# Epoch 3/30, Loss: 0.2104014903306961
# Epoch 3/30, Loss: 0.22601085901260376
# Epoch 3/30, Loss: 0.10167580842971802
# Epoch 3/30, Loss: 1.985519289970398
# Epoch 3/30, Loss: 0.11467839777469635
# Epoch 3/30, Loss: 0.07589932531118393
# Epoch 3/30, Loss: 0.43102654814720154
# Epoch 3/30, Loss: 0.16559866070747375
# Epoch 3/30, Loss: 0.10225778818130493
# Epoch 3/30, Loss: 0.41192692518234253
# Epoch 3/30, Loss: 0.2585628628730774
# Epoch 3/30, Loss: 0.2737848460674286
# Epoch 3/30, Loss: 2.9387757778167725
# Epoch 3/30, Loss: 0.15014630556106567
# Epoch 3/30, Loss: 0.1542375385761261
# Epoch 3/30, Loss: 0.11517457664012909
# Epoch 3/30, Loss: 0.4745684862136841
# Epoch 3/30, Loss: 0.08305118978023529
# Epoch 3/30, Loss: 0.13902819156646729
# Epoch 3/30, Loss: 0.0695292055606842
# Epoch 3/30, Loss: 0.364621102809906
# Epoch 3/30, Loss: 0.25406911969184875
# Epoch 3/30, Loss: 0.8039661645889282
# Epoch 3/30, Loss: 0.4104544520378113
# Epoch 3/30, Loss: 0.10854292660951614
# Epoch 3/30, Loss: 0.2822526693344116
# Epoch 3/30, Loss: 0.6546841859817505
# Epoch 3/30, Loss: 0.22994089126586914
# Epoch 3/30, Loss: 0.15642771124839783
# Epoch 3/30, Loss: 0.6940637826919556
# Epoch 3/30, Loss: 0.6799035668373108
# Epoch 3/30, Loss: 0.18634214997291565
# Epoch 3/30, Loss: 3.1093225479125977
# Epoch 3/30, Loss: 0.21405810117721558
# Epoch 3/30, Loss: 0.3165193200111389
# Epoch 3/30, Loss: 0.25511837005615234
# Epoch 3/30, Loss: 0.20114333927631378
# Epoch 3/30, Loss: 0.16804902255535126
# Epoch 3/30, Loss: 0.17522728443145752
# Epoch 3/30, Loss: 0.10484820604324341
# Epoch 3/30, Loss: 2.8840620517730713
# Epoch 3/30, Loss: 0.7939686179161072
# Epoch 3/30, Loss: 0.25614580512046814
# Epoch 3/30, Loss: 0.3873492479324341
# Epoch 3/30, Loss: 0.39650195837020874
# Epoch 3/30, Loss: 0.1714823991060257
# Epoch 3/30, Loss: 0.08710421621799469
# Epoch 3/30, Loss: 0.4183284044265747
# Epoch 3/30, Loss: 0.49106353521347046
# Epoch 3/30, Loss: 0.2983008027076721
# Epoch 3/30, Loss: 11.900018692016602
# Epoch 3/30, Loss: 0.08588685095310211
# Epoch 3/30, Loss: 0.2058888077735901
# Epoch 3/30, Loss: 0.07994520664215088
# Epoch 3/30, Loss: 0.1302875131368637
# Epoch 3/30, Loss: 1.2358535528182983
# Epoch 3/30, Loss: 0.16813908517360687
# Epoch 3/30, Loss: 0.17845770716667175
# Epoch 3/30, Loss: 0.09241366386413574
# Epoch 3/30, Loss: 0.18324202299118042
# Epoch 3/30, Loss: 0.08548405021429062
# Epoch 3/30, Loss: 0.07294073700904846
# Epoch 3/30, Loss: 0.11128738522529602
# Epoch 3/30, Loss: 0.20183472335338593
# Epoch 3/30, Loss: 0.2631346583366394
# Epoch 3/30, Loss: 0.17153888940811157
# Epoch 3/30, Loss: 0.1613624095916748
# Epoch 3/30, Loss: 0.08951406180858612
# Epoch 3/30, Loss: 0.21329081058502197
# Epoch 3/30, Loss: 0.10761891305446625
# Epoch 3/30, Loss: 0.304505318403244
# Epoch 3/30, Loss: 0.2622898817062378
# Epoch 3/30, Loss: 0.6935163736343384
# Epoch 3/30, Loss: 0.6719793081283569
# Epoch 3/30, Loss: 0.4028683304786682
# Epoch 3/30, Loss: 0.14998799562454224
# Epoch 3/30, Loss: 0.5092660784721375
# Epoch 3/30, Loss: 0.5994731783866882
# Epoch 3/30, Loss: 0.3988932967185974
# Epoch 3/30, Loss: 0.1258273869752884
# Epoch 3/30, Loss: 0.13697996735572815
# Epoch 3/30, Loss: 0.07824648171663284
# Epoch 3/30, Loss: 0.18105295300483704
# Epoch 3/30, Loss: 0.10282015800476074
# Epoch 3/30, Loss: 0.0822887271642685
# Epoch 3/30, Loss: 0.306613028049469
# Epoch 3/30, Loss: 0.20443417131900787
# Epoch 3/30, Loss: 0.21233734488487244
# Epoch 3/30, Loss: 0.172345831990242
# Epoch 3/30, Loss: 0.172855943441391
# Epoch 3/30, Loss: 0.5912379026412964
# Epoch 3/30, Loss: 0.2889467477798462
# Epoch 3/30, Loss: 0.08692659437656403
# Epoch 3/30, Loss: 0.1192740797996521
# Epoch 3/30, Loss: 0.18772277235984802
# Epoch 3/30, Loss: 0.08010080456733704
# Epoch 3/30, Loss: 0.12436564266681671
# Epoch 3/30, Loss: 1.7481517791748047
# Epoch 3/30, Loss: 0.29973411560058594
# Epoch 3/30, Loss: 0.30958807468414307
# Epoch 3/30, Loss: 0.4540935754776001
# Epoch 3/30, Loss: 0.27873745560646057
# Epoch 3/30, Loss: 0.10327194631099701
# Epoch 3/30, Loss: 0.11184333264827728
# Epoch 3/30, Loss: 0.08456438779830933
# Epoch 3/30, Loss: 0.0951995998620987
# Epoch 3/30, Loss: 0.12014999985694885
# Epoch 3/30, Loss: 0.45364493131637573
# Epoch 3/30, Loss: 0.11238904297351837
# Epoch 3/30, Loss: 0.4204883277416229
# Epoch 3/30, Loss: 0.5176990032196045
# Epoch 3/30, Loss: 1.9254631996154785
# Epoch 3/30, Loss: 0.09322337806224823
# Epoch 3/30, Loss: 0.07829126715660095
# Epoch 3/30, Loss: 0.43890801072120667
# Epoch 3/30, Loss: 0.2022918164730072
# Epoch 3/30, Loss: 2.2752208709716797
# Epoch 3/30, Loss: 0.5436708927154541
# Epoch 3/30, Loss: 0.10729394108057022
# Epoch 3/30, Loss: 0.2636427879333496
# Epoch 3/30, Loss: 0.28398582339286804
# Epoch 3/30, Loss: 0.42585575580596924
# Epoch 3/30, Loss: 0.2028842270374298
# Epoch 3/30, Loss: 0.21715444326400757
# Epoch 3/30, Loss: 0.28774797916412354
# Epoch 3/30, Loss: 0.4751964509487152
# Epoch 3/30, Loss: 0.1682652086019516
# Epoch 3/30, Loss: 2.0396478176116943
# Epoch 3/30, Loss: 0.18290185928344727
# Epoch 3/30, Loss: 0.1341751664876938
# Epoch 3/30, Loss: 6.607478141784668
# Epoch 3/30, Loss: 0.5076776146888733
# Epoch 3/30, Loss: 0.4283883571624756
# Epoch 3/30, Loss: 0.4378891587257385
# Epoch 3/30, Loss: 0.443225622177124
# Epoch 3/30, Loss: 0.18343709409236908
# Epoch 3/30, Loss: 0.06849704682826996
# Epoch 3/30, Loss: 0.21572545170783997
# Epoch 3/30, Loss: 0.31534838676452637
# Epoch 3/30, Loss: 0.14609260857105255
# Epoch 3/30, Loss: 0.3449106812477112
# Epoch 3/30, Loss: 0.21019160747528076
# Epoch 3/30, Loss: 0.15969735383987427
# Epoch 3/30, Loss: 0.1253427118062973
# Epoch 3/30, Loss: 0.1964448094367981
# Epoch 3/30, Loss: 0.07237651199102402
# Epoch 3/30, Loss: 0.29174259305000305
# Epoch 3/30, Loss: 0.1274259090423584
# Epoch 3/30, Loss: 0.6388798952102661
# Epoch 3/30, Loss: 0.11222759634256363
# Epoch 3/30, Loss: 0.3718135952949524
# Epoch 3/30, Loss: 1.3564808368682861
# Epoch 3/30, Loss: 0.09513095021247864
# Epoch 3/30, Loss: 0.4533427655696869
# Epoch 3/30, Loss: 0.1133614033460617
# Epoch 3/30, Loss: 0.35302725434303284
# Epoch 3/30, Loss: 0.14347094297409058
# Epoch 3/30, Loss: 0.45108962059020996
# Epoch 3/30, Loss: 0.11149337142705917
# Epoch 3/30, Loss: 0.4121445119380951
# Epoch 3/30, Loss: 0.22031733393669128
# Epoch 3/30, Loss: 0.17863312363624573
# Epoch 3/30, Loss: 0.3121703267097473
# Epoch 3/30, Loss: 0.4258198142051697
# Epoch 3/30, Eval Loss: 2.4602817726823
# Epoch 4/30, Loss: 0.19509649276733398
# Epoch 4/30, Loss: 0.1884947419166565
# Epoch 4/30, Loss: 1.6930367946624756
# Epoch 4/30, Loss: 0.670224130153656
# Epoch 4/30, Loss: 0.16684573888778687
# Epoch 4/30, Loss: 0.1803966611623764
# Epoch 4/30, Loss: 0.14878520369529724
# Epoch 4/30, Loss: 0.09668880701065063
# Epoch 4/30, Loss: 0.06099966913461685
# Epoch 4/30, Loss: 0.622532844543457
# Epoch 4/30, Loss: 0.857494592666626
# Epoch 4/30, Loss: 0.2369171380996704
# Epoch 4/30, Loss: 1.927424430847168
# Epoch 4/30, Loss: 0.24981342256069183
# Epoch 4/30, Loss: 0.3159545660018921
# Epoch 4/30, Loss: 0.07718197256326675
# Epoch 4/30, Loss: 0.1708713322877884
# Epoch 4/30, Loss: 0.21440793573856354
# Epoch 4/30, Loss: 0.07174372673034668
# Epoch 4/30, Loss: 0.16389773786067963
# Epoch 4/30, Loss: 0.12014074623584747
# Epoch 4/30, Loss: 0.2733873724937439
# Epoch 4/30, Loss: 0.23179258406162262
# Epoch 4/30, Loss: 0.11540821194648743
# Epoch 4/30, Loss: 0.06693044304847717
# Epoch 4/30, Loss: 0.05960176885128021
# Epoch 4/30, Loss: 0.20076988637447357
# Epoch 4/30, Loss: 0.08762606233358383
# Epoch 4/30, Loss: 0.15409639477729797
# Epoch 4/30, Loss: 0.9194005131721497
# Epoch 4/30, Loss: 0.09742981940507889
# Epoch 4/30, Loss: 0.343302845954895
# Epoch 4/30, Loss: 0.44651299715042114
# Epoch 4/30, Loss: 0.11890141665935516
# Epoch 4/30, Loss: 0.6833518147468567
# Epoch 4/30, Loss: 0.6903518438339233
# Epoch 4/30, Loss: 0.1155238002538681
# Epoch 4/30, Loss: 24.483564376831055
# Epoch 4/30, Loss: 3.365542411804199
# Epoch 4/30, Loss: 0.28608566522598267
# Epoch 4/30, Loss: 0.26151445508003235
# Epoch 4/30, Loss: 2.883899688720703
# Epoch 4/30, Loss: 0.4670133590698242
# Epoch 4/30, Loss: 1.1154441833496094
# Epoch 4/30, Loss: 3.3290202617645264
# Epoch 4/30, Loss: 0.04427076503634453
# Epoch 4/30, Loss: 0.24052563309669495
# Epoch 4/30, Loss: 0.9156804084777832
# Epoch 4/30, Loss: 0.1589757204055786
# Epoch 4/30, Loss: 0.26973050832748413
# Epoch 4/30, Loss: 0.2207404375076294
# Epoch 4/30, Loss: 0.4789600372314453
# Epoch 4/30, Loss: 1.0763514041900635
# Epoch 4/30, Loss: 0.2552092969417572
# Epoch 4/30, Loss: 0.20819413661956787
# Epoch 4/30, Loss: 0.9889006614685059
# Epoch 4/30, Loss: 0.22880695760250092
# Epoch 4/30, Loss: 0.25061124563217163
# Epoch 4/30, Loss: 0.2305234670639038
# Epoch 4/30, Loss: 0.8895941376686096
# Epoch 4/30, Loss: 0.472929984331131
# Epoch 4/30, Loss: 0.5218055248260498
# Epoch 4/30, Loss: 2.491105794906616
# Epoch 4/30, Loss: 0.3524385690689087
# Epoch 4/30, Loss: 0.20764636993408203
# Epoch 4/30, Loss: 0.5451826453208923
# Epoch 4/30, Loss: 0.2962913513183594
# Epoch 4/30, Loss: 0.15702064335346222
# Epoch 4/30, Loss: 0.2788538932800293
# Epoch 4/30, Loss: 0.1629658341407776
# Epoch 4/30, Loss: 0.2317107617855072
# Epoch 4/30, Loss: 0.06607046723365784
# Epoch 4/30, Loss: 0.25677987933158875
# Epoch 4/30, Loss: 0.11341138184070587
# Epoch 4/30, Loss: 0.17096152901649475
# Epoch 4/30, Loss: 0.28245723247528076
# Epoch 4/30, Loss: 0.7193835973739624
# Epoch 4/30, Loss: 0.22591175138950348
# Epoch 4/30, Loss: 0.45701077580451965
# Epoch 4/30, Loss: 0.05563998594880104
# Epoch 4/30, Loss: 0.2622769773006439
# Epoch 4/30, Loss: 0.14188289642333984
# Epoch 4/30, Loss: 0.13160493969917297
# Epoch 4/30, Loss: 0.32210394740104675
# Epoch 4/30, Loss: 0.18051500618457794
# Epoch 4/30, Loss: 0.18924517929553986
# Epoch 4/30, Loss: 0.13823455572128296
# Epoch 4/30, Loss: 0.404066801071167
# Epoch 4/30, Loss: 0.22471663355827332
# Epoch 4/30, Loss: 0.3876786530017853
# Epoch 4/30, Loss: 0.239104226231575
# Epoch 4/30, Loss: 0.1578146070241928
# Epoch 4/30, Loss: 0.1512807458639145
# Epoch 4/30, Loss: 0.10790522396564484
# Epoch 4/30, Loss: 0.12801584601402283
# Epoch 4/30, Loss: 0.2562565207481384
# Epoch 4/30, Loss: 0.39435797929763794
# Epoch 4/30, Loss: 0.11872144043445587
# Epoch 4/30, Loss: 0.20448598265647888
# Epoch 4/30, Loss: 0.12741634249687195
# Epoch 4/30, Loss: 1.2795089483261108
# Epoch 4/30, Loss: 0.15511512756347656
# Epoch 4/30, Loss: 0.3208213448524475
# Epoch 4/30, Loss: 0.2374962568283081
# Epoch 4/30, Loss: 0.0811687558889389
# Epoch 4/30, Loss: 0.23211397230625153
# Epoch 4/30, Loss: 0.0957823321223259
# Epoch 4/30, Loss: 0.14788466691970825
# Epoch 4/30, Loss: 0.1464543342590332
# Epoch 4/30, Loss: 0.11353780329227448
# Epoch 4/30, Loss: 0.33379507064819336
# Epoch 4/30, Loss: 0.5954389572143555
# Epoch 4/30, Loss: 1.6732393503189087
# Epoch 4/30, Loss: 0.10904117673635483
# Epoch 4/30, Loss: 0.091966912150383
# Epoch 4/30, Loss: 0.2865157723426819
# Epoch 4/30, Loss: 0.1240634173154831
# Epoch 4/30, Loss: 0.2366158664226532
# Epoch 4/30, Loss: 0.23502209782600403
# Epoch 4/30, Loss: 0.1570143699645996
# Epoch 4/30, Loss: 0.18910300731658936
# Epoch 4/30, Loss: 0.25503402948379517
# Epoch 4/30, Loss: 2.6095995903015137
# Epoch 4/30, Loss: 0.24904367327690125
# Epoch 4/30, Loss: 0.23778025805950165
# Epoch 4/30, Loss: 0.22331959009170532
# Epoch 4/30, Loss: 0.3693442940711975
# Epoch 4/30, Loss: 0.17964623868465424
# Epoch 4/30, Loss: 2.9556057453155518
# Epoch 4/30, Loss: 0.05645226687192917
# Epoch 4/30, Loss: 0.12962031364440918
# Epoch 4/30, Loss: 0.42777836322784424
# Epoch 4/30, Loss: 0.3029356598854065
# Epoch 4/30, Loss: 0.13116618990898132
# Epoch 4/30, Loss: 0.24607162177562714
# Epoch 4/30, Loss: 0.16549289226531982
# Epoch 4/30, Loss: 0.269271582365036
# Epoch 4/30, Loss: 0.16204506158828735
# Epoch 4/30, Loss: 0.3638313412666321
# Epoch 4/30, Loss: 6.766838550567627
# Epoch 4/30, Loss: 2.9746673107147217
# Epoch 4/30, Loss: 0.3804265260696411
# Epoch 4/30, Loss: 0.2638767957687378
# Epoch 4/30, Loss: 0.6136457920074463
# Epoch 4/30, Loss: 0.3969841003417969
# Epoch 4/30, Loss: 0.24611765146255493
# Epoch 4/30, Loss: 0.2169463187456131
# Epoch 4/30, Loss: 0.17314413189888
# Epoch 4/30, Loss: 0.2710902988910675
# Epoch 4/30, Loss: 0.42724981904029846
# Epoch 4/30, Loss: 0.13363854587078094
# Epoch 4/30, Loss: 0.45081159472465515
# Epoch 4/30, Loss: 0.33939510583877563
# Epoch 4/30, Loss: 0.2319125086069107
# Epoch 4/30, Loss: 0.1523534059524536
# Epoch 4/30, Loss: 0.2094273716211319
# Epoch 4/30, Loss: 0.2662821412086487
# Epoch 4/30, Loss: 0.13290376961231232
# Epoch 4/30, Loss: 0.3386871814727783
# Epoch 4/30, Loss: 2.794905424118042
# Epoch 4/30, Loss: 0.2914849519729614
# Epoch 4/30, Loss: 0.21392998099327087
# Epoch 4/30, Loss: 0.6484031081199646
# Epoch 4/30, Loss: 0.7114424705505371
# Epoch 4/30, Loss: 0.24595427513122559
# Epoch 4/30, Loss: 0.8406019806861877
# Epoch 4/30, Loss: 0.5125806927680969
# Epoch 4/30, Loss: 0.8655111789703369
# Epoch 4/30, Loss: 0.21123653650283813
# Epoch 4/30, Loss: 0.25591611862182617
# Epoch 4/30, Loss: 0.2858382761478424
# Epoch 4/30, Loss: 0.09228597581386566
# Epoch 4/30, Loss: 0.1150989681482315
# Epoch 4/30, Loss: 0.11940474808216095
# Epoch 4/30, Loss: 1.2069895267486572
# Epoch 4/30, Loss: 0.3911055028438568
# Epoch 4/30, Loss: 0.3909316658973694
# Epoch 4/30, Loss: 1.996167540550232
# Epoch 4/30, Loss: 0.7357511520385742
# Epoch 4/30, Loss: 0.20079316198825836
# Epoch 4/30, Loss: 0.26796954870224
# Epoch 4/30, Loss: 0.41474080085754395
# Epoch 4/30, Loss: 0.07987567037343979
# Epoch 4/30, Loss: 0.0993843674659729
# Epoch 4/30, Loss: 0.37846672534942627
# Epoch 4/30, Loss: 0.05734794959425926
# Epoch 4/30, Loss: 1.5883747339248657
# Epoch 4/30, Loss: 0.05710799992084503
# Epoch 4/30, Loss: 0.05589292570948601
# Epoch 4/30, Loss: 0.19558750092983246
# Epoch 4/30, Loss: 0.27848345041275024
# Epoch 4/30, Loss: 0.17885899543762207
# Epoch 4/30, Loss: 0.2407584935426712
# Epoch 4/30, Loss: 0.09966260194778442
# Epoch 4/30, Loss: 0.21029174327850342
# Epoch 4/30, Loss: 0.07753445208072662
# Epoch 4/30, Loss: 0.6638594269752502
# Epoch 4/30, Loss: 0.08674424141645432
# Epoch 4/30, Loss: 0.23043595254421234
# Epoch 4/30, Loss: 1.698656439781189
# Epoch 4/30, Loss: 0.150773823261261
# Epoch 4/30, Loss: 0.09245593100786209
# Epoch 4/30, Loss: 0.16671888530254364
# Epoch 4/30, Loss: 0.2511441111564636
# Epoch 4/30, Loss: 0.26190441846847534
# Epoch 4/30, Loss: 0.2157631516456604
# Epoch 4/30, Loss: 0.198369100689888
# Epoch 4/30, Loss: 0.13857653737068176
# Epoch 4/30, Loss: 0.2185034453868866
# Epoch 4/30, Loss: 0.13399416208267212
# Epoch 4/30, Loss: 0.16629961133003235
# Epoch 4/30, Loss: 0.7189356088638306
# Epoch 4/30, Loss: 0.30500397086143494
# Epoch 4/30, Loss: 13.871177673339844
# Epoch 4/30, Loss: 0.36017924547195435
# Epoch 4/30, Loss: 0.11713023483753204
# Epoch 4/30, Eval Loss: 3.1655255063222003
# Epoch 5/30, Loss: 0.2063540667295456
# Epoch 5/30, Loss: 0.7132307291030884
# Epoch 5/30, Loss: 0.12209152430295944
# Epoch 5/30, Loss: 0.2344091534614563
# Epoch 5/30, Loss: 0.20279762148857117
# Epoch 5/30, Loss: 0.1705377995967865
# Epoch 5/30, Loss: 0.10613889992237091
# Epoch 5/30, Loss: 0.250654935836792
# Epoch 5/30, Loss: 0.16891390085220337
# Epoch 5/30, Loss: 6.678398132324219
# Epoch 5/30, Loss: 2.0467066764831543
# Epoch 5/30, Loss: 0.3321940004825592
# Epoch 5/30, Loss: 0.3149745464324951
# Epoch 5/30, Loss: 0.08947822451591492
# Epoch 5/30, Loss: 4.418466091156006
# Epoch 5/30, Loss: 0.23409606516361237
# Epoch 5/30, Loss: 0.3458704352378845
# Epoch 5/30, Loss: 0.14360275864601135
# Epoch 5/30, Loss: 0.14619600772857666
# Epoch 5/30, Loss: 0.30620425939559937
# Epoch 5/30, Loss: 0.17163753509521484
# Epoch 5/30, Loss: 2.9660160541534424
# Epoch 5/30, Loss: 1.599191665649414
# Epoch 5/30, Loss: 0.49527665972709656
# Epoch 5/30, Loss: 0.7238906025886536
# Epoch 5/30, Loss: 0.31127864122390747
# Epoch 5/30, Loss: 0.4762335419654846
# Epoch 5/30, Loss: 0.34437310695648193
# Epoch 5/30, Loss: 0.34461280703544617
# Epoch 5/30, Loss: 0.15714049339294434
# Epoch 5/30, Loss: 0.2992713749408722
# Epoch 5/30, Loss: 0.4665452539920807
# Epoch 5/30, Loss: 0.918097734451294
# Epoch 5/30, Loss: 0.2914075255393982
# Epoch 5/30, Loss: 0.21264991164207458
# Epoch 5/30, Loss: 3.0629191398620605
# Epoch 5/30, Loss: 14.507051467895508
# Epoch 5/30, Loss: 0.3456264138221741
# Epoch 5/30, Loss: 0.16203224658966064
# Epoch 5/30, Loss: 0.27586084604263306
# Epoch 5/30, Loss: 0.14765840768814087
# Epoch 5/30, Loss: 0.04797034338116646
# Epoch 5/30, Loss: 0.11333887279033661
# Epoch 5/30, Loss: 0.22556324303150177
# Epoch 5/30, Loss: 0.7299321293830872
# Epoch 5/30, Loss: 0.18186265230178833
# Epoch 5/30, Loss: 0.17288857698440552
# Epoch 5/30, Loss: 0.35725557804107666
# Epoch 5/30, Loss: 0.3039608299732208
# Epoch 5/30, Loss: 0.16633009910583496
# Epoch 5/30, Loss: 0.48121803998947144
# Epoch 5/30, Loss: 0.2332668900489807
# Epoch 5/30, Loss: 0.14405469596385956
# Epoch 5/30, Loss: 0.3081522285938263
# Epoch 5/30, Loss: 0.2137865424156189
# Epoch 5/30, Loss: 1.2373636960983276
# Epoch 5/30, Loss: 0.2523919641971588
# Epoch 5/30, Loss: 0.167974054813385
# Epoch 5/30, Loss: 0.45423567295074463
# Epoch 5/30, Loss: 0.26424166560173035
# Epoch 5/30, Loss: 0.14832240343093872
# Epoch 5/30, Loss: 0.16024871170520782
# Epoch 5/30, Loss: 0.32243460416793823
# Epoch 5/30, Loss: 0.8059412240982056
# Epoch 5/30, Loss: 0.9570021033287048
# Epoch 5/30, Loss: 0.13914628326892853
# Epoch 5/30, Loss: 0.24220718443393707
# Epoch 5/30, Loss: 0.336020827293396
# Epoch 5/30, Loss: 0.387708455324173
# Epoch 5/30, Loss: 0.35658514499664307
# Epoch 5/30, Loss: 0.40320396423339844
# Epoch 5/30, Loss: 0.2099820226430893
# Epoch 5/30, Loss: 4.677757263183594
# Epoch 5/30, Loss: 0.11524587869644165
# Epoch 5/30, Loss: 0.17251858115196228
# Epoch 5/30, Loss: 0.09878283739089966
# Epoch 5/30, Loss: 0.7340971231460571
# Epoch 5/30, Loss: 0.9336723685264587
# Epoch 5/30, Loss: 0.4204382300376892
# Epoch 5/30, Loss: 0.4238557815551758
# Epoch 5/30, Loss: 0.15716668963432312
# Epoch 5/30, Loss: 0.2146282196044922
# Epoch 5/30, Loss: 0.06973853707313538
# Epoch 5/30, Loss: 0.19996041059494019
# Epoch 5/30, Loss: 0.1307731717824936
# Epoch 5/30, Loss: 0.7985098958015442
# Epoch 5/30, Loss: 0.1770978718996048
# Epoch 5/30, Loss: 0.08339916169643402
# Epoch 5/30, Loss: 0.139333575963974
# Epoch 5/30, Loss: 0.2649727463722229
# Epoch 5/30, Loss: 0.2608943283557892
# Epoch 5/30, Loss: 2.7492246627807617
# Epoch 5/30, Loss: 1.6297235488891602
# Epoch 5/30, Loss: 0.2682138681411743
# Epoch 5/30, Loss: 0.17691916227340698
# Epoch 5/30, Loss: 2.255525588989258
# Epoch 5/30, Loss: 0.34417974948883057
# Epoch 5/30, Loss: 0.14426159858703613
# Epoch 5/30, Loss: 0.07072077691555023
# Epoch 5/30, Loss: 32.492671966552734
# Epoch 5/30, Loss: 0.26626425981521606
# Epoch 5/30, Loss: 0.38447535037994385
# Epoch 5/30, Loss: 0.7424405217170715
# Epoch 5/30, Loss: 0.18277443945407867
# Epoch 5/30, Loss: 0.30052870512008667
# Epoch 5/30, Loss: 0.38335978984832764
# Epoch 5/30, Loss: 0.44997283816337585
# Epoch 5/30, Loss: 0.16570645570755005
# Epoch 5/30, Loss: 0.1489640325307846
# Epoch 5/30, Loss: 4.978497505187988
# Epoch 5/30, Loss: 0.09866963326931
# Epoch 5/30, Loss: 0.18158811330795288
# Epoch 5/30, Loss: 2.391775608062744
# Epoch 5/30, Loss: 0.13831277191638947
# Epoch 5/30, Loss: 0.2002437859773636
# Epoch 5/30, Loss: 0.22348782420158386
# Epoch 5/30, Loss: 0.15660803020000458
# Epoch 5/30, Loss: 0.1715412139892578
# Epoch 5/30, Loss: 0.24648304283618927
# Epoch 5/30, Loss: 0.1389741450548172
# Epoch 5/30, Loss: 0.6726458072662354
# Epoch 5/30, Loss: 0.3646366596221924
# Epoch 5/30, Loss: 0.2929515242576599
# Epoch 5/30, Loss: 0.39104077219963074
# Epoch 5/30, Loss: 0.13407596945762634
# Epoch 5/30, Loss: 0.15120774507522583
# Epoch 5/30, Loss: 0.16446508467197418
# Epoch 5/30, Loss: 0.06829041987657547
# Epoch 5/30, Loss: 0.14653868973255157
# Epoch 5/30, Loss: 0.08286862075328827
# Epoch 5/30, Loss: 0.13752388954162598
# Epoch 5/30, Loss: 0.10224464535713196
# Epoch 5/30, Loss: 0.11740504205226898
# Epoch 5/30, Loss: 0.21115729212760925
# Epoch 5/30, Loss: 1.7691388130187988
# Epoch 5/30, Loss: 0.1821107715368271
# Epoch 5/30, Loss: 0.2204957902431488
# Epoch 5/30, Loss: 0.15393474698066711
# Epoch 5/30, Loss: 0.11443856358528137
# Epoch 5/30, Loss: 0.30267763137817383
# Epoch 5/30, Loss: 0.17314106225967407
# Epoch 5/30, Loss: 0.15119054913520813
# Epoch 5/30, Loss: 0.11764232069253922
# Epoch 5/30, Loss: 0.21371838450431824
# Epoch 5/30, Loss: 0.3849131464958191
# Epoch 5/30, Loss: 4.9787468910217285
# Epoch 5/30, Loss: 0.10410161316394806
# Epoch 5/30, Loss: 0.11119087040424347
# Epoch 5/30, Loss: 0.24422480165958405
# Epoch 5/30, Loss: 2.2158803939819336
# Epoch 5/30, Loss: 0.19650152325630188
# Epoch 5/30, Loss: 0.4579387307167053
# Epoch 5/30, Loss: 0.1006118580698967
# Epoch 5/30, Loss: 0.2363303005695343
# Epoch 5/30, Loss: 0.04211444407701492
# Epoch 5/30, Loss: 0.27958449721336365
# Epoch 5/30, Loss: 0.12333175539970398
# Epoch 5/30, Loss: 0.15056313574314117
# Epoch 5/30, Loss: 0.13689777255058289
# Epoch 5/30, Loss: 0.21406926214694977
# Epoch 5/30, Loss: 0.2005622833967209
# Epoch 5/30, Loss: 0.2430846244096756
# Epoch 5/30, Loss: 1.037463665008545
# Epoch 5/30, Loss: 0.09640894085168839
# Epoch 5/30, Loss: 0.08606395125389099
# Epoch 5/30, Loss: 0.4774577021598816
# Epoch 5/30, Loss: 1.0575567483901978
# Epoch 5/30, Loss: 0.19026675820350647
# Epoch 5/30, Loss: 0.2600851356983185
# Epoch 5/30, Loss: 0.0691591426730156
# Epoch 5/30, Loss: 0.6482963562011719
# Epoch 5/30, Loss: 0.37365323305130005
# Epoch 5/30, Loss: 0.38791292905807495
# Epoch 5/30, Loss: 0.384107768535614
# Epoch 5/30, Loss: 0.2420947104692459
# Epoch 5/30, Loss: 0.2638978064060211
# Epoch 5/30, Loss: 0.14150455594062805
# Epoch 5/30, Loss: 0.07312455773353577
# Epoch 5/30, Loss: 0.5316522121429443
# Epoch 5/30, Loss: 0.18781249225139618
# Epoch 5/30, Loss: 0.11893773078918457
# Epoch 5/30, Loss: 0.17383059859275818
# Epoch 5/30, Loss: 0.1512993574142456
# Epoch 5/30, Loss: 0.10856766998767853
# Epoch 5/30, Loss: 0.5322979688644409
# Epoch 5/30, Loss: 0.07715563476085663
# Epoch 5/30, Loss: 0.37234702706336975
# Epoch 5/30, Loss: 0.3608057498931885
# Epoch 5/30, Loss: 0.38482290506362915
# Epoch 5/30, Loss: 0.35473302006721497
# Epoch 5/30, Loss: 0.7149347066879272
# Epoch 5/30, Loss: 0.22718089818954468
# Epoch 5/30, Loss: 0.19837620854377747
# Epoch 5/30, Loss: 0.20763221383094788
# Epoch 5/30, Loss: 0.16569867730140686
# Epoch 5/30, Loss: 0.21141475439071655
# Epoch 5/30, Loss: 0.09849525988101959
# Epoch 5/30, Loss: 0.18776819109916687
# Epoch 5/30, Loss: 0.11425269395112991
# Epoch 5/30, Loss: 0.21548987925052643
# Epoch 5/30, Loss: 0.1547698974609375
# Epoch 5/30, Loss: 0.2462865561246872
# Epoch 5/30, Loss: 0.1594230830669403
# Epoch 5/30, Loss: 0.1433483064174652
# Epoch 5/30, Loss: 0.2861599028110504
# Epoch 5/30, Loss: 0.17507043480873108
# Epoch 5/30, Loss: 0.2010485827922821
# Epoch 5/30, Loss: 0.07547705620527267
# Epoch 5/30, Loss: 0.11919692158699036
# Epoch 5/30, Loss: 0.19523708522319794
# Epoch 5/30, Loss: 0.5973286628723145
# Epoch 5/30, Loss: 0.10899583995342255
# Epoch 5/30, Loss: 0.2773198187351227
# Epoch 5/30, Loss: 0.7074415683746338
# Epoch 5/30, Loss: 0.24286732077598572
# Epoch 5/30, Loss: 0.09934951364994049
# Epoch 5/30, Eval Loss: 3.0064177816877
# Epoch 6/30, Loss: 0.18265527486801147
# Epoch 6/30, Loss: 1.5037761926651
# Epoch 6/30, Loss: 0.10141971707344055
# Epoch 6/30, Loss: 0.3358336091041565
# Epoch 6/30, Loss: 0.13736914098262787
# Epoch 6/30, Loss: 0.2098369300365448
# Epoch 6/30, Loss: 0.19029244780540466
# Epoch 6/30, Loss: 0.16755825281143188
# Epoch 6/30, Loss: 0.12064565718173981
# Epoch 6/30, Loss: 0.1026466116309166
# Epoch 6/30, Loss: 0.29358166456222534
# Epoch 6/30, Loss: 0.32100480794906616
# Epoch 6/30, Loss: 0.06284070760011673
# Epoch 6/30, Loss: 0.13982219994068146
# Epoch 6/30, Loss: 0.21877267956733704
# Epoch 6/30, Loss: 0.16657370328903198
# Epoch 6/30, Loss: 0.1908555030822754
# Epoch 6/30, Loss: 0.16563305258750916
# Epoch 6/30, Loss: 0.18605099618434906
# Epoch 6/30, Loss: 0.22282159328460693
# Epoch 6/30, Loss: 0.3142363429069519
# Epoch 6/30, Loss: 0.11499486863613129
# Epoch 6/30, Loss: 0.12891104817390442
# Epoch 6/30, Loss: 0.17217469215393066
# Epoch 6/30, Loss: 0.15536198019981384
# Epoch 6/30, Loss: 0.10998362302780151
# Epoch 6/30, Loss: 0.04289468377828598
# Epoch 6/30, Loss: 0.12466159462928772
# Epoch 6/30, Loss: 0.1201983168721199
# Epoch 6/30, Loss: 0.1619260013103485
# Epoch 6/30, Loss: 0.36856961250305176
# Epoch 6/30, Loss: 0.11924344301223755
# Epoch 6/30, Loss: 0.09599241614341736
# Epoch 6/30, Loss: 0.10590402036905289
# Epoch 6/30, Loss: 0.10728044807910919
# Epoch 6/30, Loss: 0.17014868557453156
# Epoch 6/30, Loss: 1.3779780864715576
# Epoch 6/30, Loss: 0.17460668087005615
# Epoch 6/30, Loss: 0.09780225157737732
# Epoch 6/30, Loss: 0.14431855082511902
# Epoch 6/30, Loss: 0.1585845947265625
# Epoch 6/30, Loss: 0.22896966338157654
# Epoch 6/30, Loss: 4.49868631362915
# Epoch 6/30, Loss: 0.423495888710022
# Epoch 6/30, Loss: 0.21510697901248932
# Epoch 6/30, Loss: 0.17614522576332092
# Epoch 6/30, Loss: 0.17418217658996582
# Epoch 6/30, Loss: 0.3401341438293457
# Epoch 6/30, Loss: 0.26866859197616577
# Epoch 6/30, Loss: 0.16183100640773773
# Epoch 6/30, Loss: 0.11895081400871277
# Epoch 6/30, Loss: 0.6269593238830566
# Epoch 6/30, Loss: 0.10807322710752487
# Epoch 6/30, Loss: 0.06929648667573929
# Epoch 6/30, Loss: 0.20901644229888916
# Epoch 6/30, Loss: 0.10827004909515381
# Epoch 6/30, Loss: 0.11937180906534195
# Epoch 6/30, Loss: 1.2874528169631958
# Epoch 6/30, Loss: 0.18095459043979645
# Epoch 6/30, Loss: 0.12279324233531952
# Epoch 6/30, Loss: 0.13801360130310059
# Epoch 6/30, Loss: 0.07273462414741516
# Epoch 6/30, Loss: 0.2516332268714905
# Epoch 6/30, Loss: 0.7816665768623352
# Epoch 6/30, Loss: 0.18226400017738342
# Epoch 6/30, Loss: 0.2149345427751541
# Epoch 6/30, Loss: 0.17434366047382355
# Epoch 6/30, Loss: 0.12541700899600983
# Epoch 6/30, Loss: 0.058607637882232666
# Epoch 6/30, Loss: 0.13174688816070557
# Epoch 6/30, Loss: 16.57794189453125
# Epoch 6/30, Loss: 0.12518668174743652
# Epoch 6/30, Loss: 0.3495467007160187
# Epoch 6/30, Loss: 0.27771052718162537
# Epoch 6/30, Loss: 0.10094259679317474
# Epoch 6/30, Loss: 0.3772011399269104
# Epoch 6/30, Loss: 0.33738934993743896
# Epoch 6/30, Loss: 11.626094818115234
# Epoch 6/30, Loss: 0.23211613297462463
# Epoch 6/30, Loss: 0.5411670804023743
# Epoch 6/30, Loss: 2.869110107421875
# Epoch 6/30, Loss: 0.11366217583417892
# Epoch 6/30, Loss: 0.2553183436393738
# Epoch 6/30, Loss: 0.39936894178390503
# Epoch 6/30, Loss: 0.1552381068468094
# Epoch 6/30, Loss: 24.520549774169922
# Epoch 6/30, Loss: 0.702075719833374
# Epoch 6/30, Loss: 1.3665499687194824
# Epoch 6/30, Loss: 0.17760378122329712
# Epoch 6/30, Loss: 0.3153949975967407
# Epoch 6/30, Loss: 0.7964481115341187
# Epoch 6/30, Loss: 0.23195241391658783
# Epoch 6/30, Loss: 1.0112706422805786
# Epoch 6/30, Loss: 0.19340834021568298
# Epoch 6/30, Loss: 2.707926034927368
# Epoch 6/30, Loss: 0.6012752056121826
# Epoch 6/30, Loss: 0.3771783411502838
# Epoch 6/30, Loss: 0.3084560036659241
# Epoch 6/30, Loss: 0.05032327398657799
# Epoch 6/30, Loss: 0.2538338303565979
# Epoch 6/30, Loss: 0.6157137155532837
# Epoch 6/30, Loss: 0.4264557361602783
# Epoch 6/30, Loss: 0.223079651594162
# Epoch 6/30, Loss: 0.3943820893764496
# Epoch 6/30, Loss: 0.8813011050224304
# Epoch 6/30, Loss: 0.2932799756526947
# Epoch 6/30, Loss: 0.09440857917070389
# Epoch 6/30, Loss: 0.17872339487075806
# Epoch 6/30, Loss: 0.13911975920200348
# Epoch 6/30, Loss: 0.06466665863990784
# Epoch 6/30, Loss: 0.10210861265659332
# Epoch 6/30, Loss: 0.10451861470937729
# Epoch 6/30, Loss: 1.930871605873108
# Epoch 6/30, Loss: 0.2326584756374359
# Epoch 6/30, Loss: 0.12194523960351944
# Epoch 6/30, Loss: 0.8295454978942871
# Epoch 6/30, Loss: 0.4541119933128357
# Epoch 6/30, Loss: 0.5075654983520508
# Epoch 6/30, Loss: 0.3039415776729584
# Epoch 6/30, Loss: 0.13321331143379211
# Epoch 6/30, Loss: 0.2530902922153473
# Epoch 6/30, Loss: 0.07541439682245255
# Epoch 6/30, Loss: 0.7250601649284363
# Epoch 6/30, Loss: 0.08851786702871323
# Epoch 6/30, Loss: 0.3048872649669647
# Epoch 6/30, Loss: 0.17181044816970825
# Epoch 6/30, Loss: 0.6827138066291809
# Epoch 6/30, Loss: 0.1286187767982483
# Epoch 6/30, Loss: 0.2153148055076599
# Epoch 6/30, Loss: 0.1502174437046051
# Epoch 6/30, Loss: 0.9677411317825317
# Epoch 6/30, Loss: 8.220878601074219
# Epoch 6/30, Loss: 0.20784030854701996
# Epoch 6/30, Loss: 0.24343538284301758
# Epoch 6/30, Loss: 0.2446451485157013
# Epoch 6/30, Loss: 0.14155063033103943
# Epoch 6/30, Loss: 0.15762244164943695
# Epoch 6/30, Loss: 0.2963257431983948
# Epoch 6/30, Loss: 0.10380661487579346
# Epoch 6/30, Loss: 0.11261121928691864
# Epoch 6/30, Loss: 0.07737480103969574
# Epoch 6/30, Loss: 0.17364300787448883
# Epoch 6/30, Loss: 0.12831856310367584
# Epoch 6/30, Loss: 0.4360671043395996
# Epoch 6/30, Loss: 0.17161348462104797
# Epoch 6/30, Loss: 0.2158062607049942
# Epoch 6/30, Loss: 0.6240333914756775
# Epoch 6/30, Loss: 0.20414814352989197
# Epoch 6/30, Loss: 0.11165729910135269
# Epoch 6/30, Loss: 0.4941783547401428
# Epoch 6/30, Loss: 0.10064945369958878
# Epoch 6/30, Loss: 0.13227228820323944
# Epoch 6/30, Loss: 0.07242238521575928
# Epoch 6/30, Loss: 0.28393885493278503
# Epoch 6/30, Loss: 0.25699540972709656
# Epoch 6/30, Loss: 0.097346231341362
# Epoch 6/30, Loss: 0.11473892629146576
# Epoch 6/30, Loss: 0.10950527340173721
# Epoch 6/30, Loss: 2.7361364364624023
# Epoch 6/30, Loss: 0.3153507113456726
# Epoch 6/30, Loss: 0.762932538986206
# Epoch 6/30, Loss: 0.11561036109924316
# Epoch 6/30, Loss: 0.16519451141357422
# Epoch 6/30, Loss: 0.11365075409412384
# Epoch 6/30, Loss: 1.5631492137908936
# Epoch 6/30, Loss: 0.1633032262325287
# Epoch 6/30, Loss: 0.30538463592529297
# Epoch 6/30, Loss: 0.24429067969322205
# Epoch 6/30, Loss: 0.06461042910814285
# Epoch 6/30, Loss: 0.26010221242904663
# Epoch 6/30, Loss: 0.19490183889865875
# Epoch 6/30, Loss: 0.16955992579460144
# Epoch 6/30, Loss: 0.20658186078071594
# Epoch 6/30, Loss: 0.1419430524110794
# Epoch 6/30, Loss: 0.0999513566493988
# Epoch 6/30, Loss: 1.1284077167510986
# Epoch 6/30, Loss: 0.12641935050487518
# Epoch 6/30, Loss: 0.18592220544815063
# Epoch 6/30, Loss: 0.1909664422273636
# Epoch 6/30, Loss: 0.37175869941711426
# Epoch 6/30, Loss: 0.13350804150104523
# Epoch 6/30, Loss: 0.42524802684783936
# Epoch 6/30, Loss: 0.30615606904029846
# Epoch 6/30, Loss: 0.12277095764875412
# Epoch 6/30, Loss: 0.2144630253314972
# Epoch 6/30, Loss: 0.38318243622779846
# Epoch 6/30, Loss: 0.22369453310966492
# Epoch 6/30, Loss: 0.13448867201805115
# Epoch 6/30, Loss: 0.2917352616786957
# Epoch 6/30, Loss: 0.2465396225452423
# Epoch 6/30, Loss: 0.4061373770236969
# Epoch 6/30, Loss: 0.3634814918041229
# Epoch 6/30, Loss: 0.36040565371513367
# Epoch 6/30, Loss: 0.41590455174446106
# Epoch 6/30, Loss: 0.7946330308914185
# Epoch 6/30, Loss: 0.13224005699157715
# ...
# Epoch 14/30, Loss: 0.08998417854309082
# Epoch 14/30, Loss: 0.07579999417066574
# Epoch 14/30, Loss: 0.0566026009619236
# Epoch 14/30, Loss: 0.1394965797662735
# Epoch 14/30, Loss: 0.05747256055474281
# Epoch 14/30, Loss: 0.5074194669723511
# Epoch 14/30, Loss: 0.28532758355140686
# Epoch 14/30, Loss: 0.10762805491685867
# Epoch 14/30, Loss: 0.06781680881977081
# Epoch 14/30, Loss: 0.05554841458797455
# Epoch 14/30, Loss: 0.03488248586654663
# Epoch 14/30, Loss: 0.09330487251281738
# Epoch 14/30, Loss: 0.3259860575199127
# Epoch 14/30, Loss: 0.10243676602840424
# Epoch 14/30, Loss: 0.04651995003223419
# Epoch 14/30, Loss: 0.1785227209329605
# Epoch 14/30, Loss: 0.09326045960187912
# Epoch 14/30, Loss: 0.07897340506315231
# Epoch 14/30, Loss: 0.12251359224319458
# Epoch 14/30, Loss: 0.04393216595053673
# Epoch 14/30, Loss: 0.0805446058511734
# Epoch 14/30, Loss: 0.07326485216617584
# Epoch 14/30, Loss: 0.04949786886572838
# Epoch 14/30, Loss: 0.09610937535762787
# Epoch 14/30, Loss: 0.11139468848705292
# Epoch 14/30, Loss: 0.09337411820888519
# Epoch 14/30, Loss: 0.0686246007680893
# Epoch 14/30, Loss: 0.048946402966976166
# Epoch 14/30, Loss: 0.10040927678346634
# Epoch 14/30, Loss: 0.07141086459159851
# Epoch 14/30, Loss: 0.06561357527971268
# Epoch 14/30, Loss: 0.0886683240532875
# Epoch 14/30, Loss: 0.1348859816789627
# Epoch 14/30, Loss: 0.2993062436580658
# Epoch 14/30, Loss: 0.06622868031263351
# Epoch 14/30, Loss: 0.09469979256391525
# Epoch 14/30, Loss: 0.05794588476419449
# Epoch 14/30, Loss: 0.03481569141149521
# Epoch 14/30, Loss: 0.06743672490119934
# Epoch 14/30, Loss: 0.09256236255168915
# Epoch 14/30, Loss: 0.06672557443380356
# Epoch 14/30, Loss: 0.06416601687669754
# Epoch 14/30, Loss: 0.08617714047431946
# Epoch 14/30, Loss: 0.24449779093265533
# Epoch 14/30, Loss: 0.14361116290092468
# Epoch 14/30, Loss: 0.038619838654994965
# Epoch 14/30, Loss: 0.07979481667280197
# Epoch 14/30, Loss: 0.07440531998872757
# Epoch 14/30, Loss: 0.03988861292600632
# Epoch 14/30, Loss: 0.04683458060026169
# Epoch 14/30, Loss: 0.1014450341463089
# Epoch 14/30, Loss: 0.05769087374210358
# Epoch 14/30, Loss: 0.08290091902017593
# Epoch 14/30, Loss: 0.08547794073820114
# Epoch 14/30, Loss: 0.06365865468978882
# Epoch 14/30, Loss: 0.046025678515434265
# Epoch 14/30, Loss: 0.23432248830795288
# Epoch 14/30, Loss: 0.09932319819927216
# Epoch 14/30, Loss: 0.08062663674354553
# Epoch 14/30, Loss: 0.08860796689987183
# Epoch 14/30, Loss: 0.09754674136638641
# Epoch 14/30, Loss: 0.05744022876024246
# Epoch 14/30, Loss: 0.07649123668670654
# Epoch 14/30, Loss: 0.09308324009180069
# Epoch 14/30, Loss: 0.04561394453048706
# Epoch 14/30, Loss: 0.2286394238471985
# Epoch 14/30, Loss: 0.22511614859104156
# Epoch 14/30, Loss: 0.10824176669120789
# Epoch 14/30, Loss: 0.041653022170066833
# Epoch 14/30, Loss: 0.12004559487104416
# Epoch 14/30, Loss: 0.23946911096572876
# Epoch 14/30, Loss: 0.018751272931694984
# Epoch 14/30, Loss: 0.05663648992776871
# Epoch 14/30, Loss: 0.09995913505554199
# Epoch 14/30, Loss: 0.26596853137016296
# Epoch 14/30, Loss: 0.15131868422031403
# Epoch 14/30, Loss: 0.07109515368938446
# Epoch 14/30, Loss: 0.12300778180360794
# Epoch 14/30, Loss: 0.09791304916143417
# Epoch 14/30, Loss: 0.05699171870946884
# Epoch 14/30, Loss: 0.23571228981018066
# Epoch 14/30, Loss: 0.06244879215955734
# Epoch 14/30, Loss: 0.07181446254253387
# Epoch 14/30, Loss: 0.04186321794986725
# Epoch 14/30, Loss: 0.11233551055192947
# Epoch 14/30, Loss: 0.1409623920917511
# Epoch 14/30, Loss: 0.10552562773227692
# Epoch 14/30, Loss: 0.12878523766994476
# Epoch 14/30, Loss: 0.1220112293958664
# Epoch 14/30, Loss: 0.07756204903125763
# Epoch 14/30, Loss: 0.06275960803031921
# Epoch 14/30, Loss: 0.059083759784698486
# Epoch 14/30, Loss: 0.0688166469335556
# Epoch 14/30, Loss: 0.05313246697187424
# Epoch 14/30, Loss: 0.04167145490646362
# Epoch 14/30, Loss: 0.13604551553726196
# Epoch 14/30, Loss: 0.11564765870571136
# Epoch 14/30, Loss: 0.07377971708774567
# Epoch 14/30, Loss: 0.14654147624969482
# Epoch 14/30, Loss: 0.03432510048151016
# Epoch 14/30, Loss: 0.07720746099948883
# Epoch 14/30, Loss: 0.1699676811695099
# Epoch 14/30, Loss: 0.3954402506351471
# Epoch 14/30, Loss: 0.05930923670530319
# Epoch 14/30, Loss: 0.06308034062385559
# Epoch 14/30, Loss: 0.05068149417638779
# Epoch 14/30, Loss: 0.06653952598571777
# Epoch 14/30, Loss: 0.024049870669841766
# Epoch 14/30, Loss: 0.0368758849799633
# Epoch 14/30, Loss: 0.04437723755836487
# Epoch 14/30, Loss: 0.04551240801811218
# Epoch 14/30, Loss: 0.4483399987220764
# Epoch 14/30, Loss: 0.052239030599594116
# Epoch 14/30, Loss: 0.1254372000694275
# Epoch 14/30, Loss: 0.16432175040245056
# Epoch 14/30, Loss: 0.037493180483579636
# Epoch 14/30, Loss: 0.04870230332016945
# Epoch 14/30, Loss: 0.033160775899887085
# Epoch 14/30, Loss: 0.024772800505161285
# Epoch 14/30, Loss: 0.12729805707931519
# Epoch 14/30, Loss: 0.11260710656642914
# Epoch 14/30, Loss: 0.11252452433109283
# Epoch 14/30, Loss: 0.116190105676651
# Epoch 14/30, Loss: 0.06756994128227234
# Epoch 14/30, Loss: 0.09749993681907654
# Epoch 14/30, Loss: 0.07906420528888702
# Epoch 14/30, Loss: 0.03441396728157997
# Epoch 14/30, Loss: 0.10751849412918091
# Epoch 14/30, Loss: 0.09880627691745758
# Epoch 14/30, Loss: 0.14642444252967834
# Epoch 14/30, Loss: 0.05113685876131058
# Epoch 14/30, Loss: 0.22686541080474854
# Epoch 14/30, Loss: 0.07452566921710968
# Epoch 14/30, Loss: 0.08774350583553314
# Epoch 14/30, Loss: 0.12805332243442535
# Epoch 14/30, Loss: 0.07827342301607132
# Epoch 14/30, Loss: 0.04050695151090622
# Epoch 14/30, Loss: 0.4465901851654053
# Epoch 14/30, Loss: 0.27251550555229187
# Epoch 14/30, Loss: 0.04546196013689041
# Epoch 14/30, Loss: 0.24186819791793823
# Epoch 14/30, Loss: 0.14489960670471191
# Epoch 14/30, Loss: 0.05127149820327759
# Epoch 14/30, Loss: 0.09938085079193115
# Epoch 14/30, Loss: 0.04947872832417488
# Epoch 14/30, Loss: 0.18319657444953918
# Epoch 14/30, Loss: 0.08112360537052155
# Epoch 14/30, Loss: 0.08303432166576385
# Epoch 14/30, Loss: 0.11479726433753967
# Epoch 14/30, Loss: 0.2277776598930359
# Epoch 14/30, Loss: 0.08435140550136566
# Epoch 14/30, Loss: 0.10220670700073242
# Epoch 14/30, Loss: 0.060465872287750244
# Epoch 14/30, Loss: 0.12277065962553024
# Epoch 14/30, Loss: 0.10254424810409546
# Epoch 14/30, Loss: 0.1891564428806305
# Epoch 14/30, Loss: 0.13455329835414886
# Epoch 14/30, Loss: 0.18557800352573395
# Epoch 14/30, Loss: 0.04143226146697998
# Epoch 14/30, Loss: 0.09517837315797806
# Epoch 14/30, Loss: 0.06508159637451172
# Epoch 14/30, Loss: 0.07474499940872192
# Epoch 14/30, Loss: 0.03235314041376114
# Epoch 14/30, Loss: 0.11362604796886444
# Epoch 14/30, Loss: 0.2569780647754669
# Epoch 14/30, Loss: 0.06598037481307983
# Epoch 14/30, Loss: 0.20353758335113525
# Epoch 14/30, Loss: 0.06699160486459732
# Epoch 14/30, Loss: 0.1405729204416275
# Epoch 14/30, Loss: 0.11902350187301636
# Epoch 14/30, Loss: 0.13234201073646545
# Epoch 14/30, Loss: 0.13862216472625732
# Epoch 14/30, Loss: 0.04495497792959213
# Epoch 14/30, Loss: 0.2258533239364624
# Epoch 14/30, Loss: 0.15594270825386047
# Epoch 14/30, Loss: 0.0752597227692604
# Epoch 14/30, Loss: 0.16110162436962128
# Epoch 14/30, Loss: 0.03402993828058243
# Epoch 14/30, Loss: 0.06320444494485855
# Epoch 14/30, Loss: 0.05326651409268379
# Epoch 14/30, Loss: 0.03450370579957962
# Epoch 14/30, Loss: 0.08188275992870331
# Epoch 14/30, Loss: 0.06792990863323212
# Epoch 14/30, Loss: 0.04838510975241661
# Epoch 14/30, Loss: 0.09429740905761719
# Epoch 14/30, Loss: 0.06912565976381302
# Epoch 14/30, Loss: 0.10304584354162216
# Epoch 14/30, Loss: 0.6983792781829834
# Epoch 14/30, Loss: 0.23208187520503998
# Epoch 14/30, Loss: 0.05684686079621315
# Epoch 14/30, Loss: 0.14921684563159943
# Epoch 14/30, Loss: 0.15111681818962097
# Epoch 14/30, Eval Loss: 3.1209309146954465
# Epoch 15/30, Loss: 0.11634054780006409
# Epoch 15/30, Loss: 0.06967010349035263
# Epoch 15/30, Loss: 0.16974078118801117
# Epoch 15/30, Loss: 0.11516693234443665
# Epoch 15/30, Loss: 0.04554826766252518
# Epoch 15/30, Loss: 0.09038250148296356
# Epoch 15/30, Loss: 0.12311933934688568
# Epoch 15/30, Loss: 0.17092840373516083
# Epoch 15/30, Loss: 0.13262981176376343
# Epoch 15/30, Loss: 0.37610894441604614
# Epoch 15/30, Loss: 0.1186094731092453
# Epoch 15/30, Loss: 0.08886560797691345
# Epoch 15/30, Loss: 0.06360360980033875
# Epoch 15/30, Loss: 0.08132382482290268
# Epoch 15/30, Loss: 0.06106693297624588
# Epoch 15/30, Loss: 0.1193658858537674
# Epoch 15/30, Loss: 0.12036722898483276
# Epoch 15/30, Loss: 0.07425007224082947
# Epoch 15/30, Loss: 0.09425230324268341
# Epoch 15/30, Loss: 0.03834673389792442
# Epoch 15/30, Loss: 0.05901056528091431
# Epoch 15/30, Loss: 0.06839242577552795
# Epoch 15/30, Loss: 0.04051058366894722
# Epoch 15/30, Loss: 0.05380847305059433
# Epoch 15/30, Loss: 0.2522485852241516
# Epoch 15/30, Loss: 0.07025443762540817
# Epoch 15/30, Loss: 0.11933532357215881
# Epoch 15/30, Loss: 0.07862889766693115
# Epoch 15/30, Loss: 0.07201831787824631
# Epoch 15/30, Loss: 0.09938392043113708
# Epoch 15/30, Loss: 0.08329848945140839
# Epoch 15/30, Loss: 0.1471288502216339
# Epoch 15/30, Loss: 0.10480055958032608
# Epoch 15/30, Loss: 0.10049306601285934
# Epoch 15/30, Loss: 0.045140765607357025
# Epoch 15/30, Loss: 0.03711400553584099
# Epoch 15/30, Loss: 0.04283791035413742
# Epoch 15/30, Loss: 0.07494458556175232
# Epoch 15/30, Loss: 0.2021002322435379
# Epoch 15/30, Loss: 0.07604244351387024
# Epoch 15/30, Loss: 0.049840278923511505
# Epoch 15/30, Loss: 0.5020683407783508
# Epoch 15/30, Loss: 0.07287222146987915
# Epoch 15/30, Loss: 0.09827333688735962
# Epoch 15/30, Loss: 0.1133633628487587
# Epoch 15/30, Loss: 0.0948362872004509
# Epoch 15/30, Loss: 0.08596064150333405
# Epoch 15/30, Loss: 0.0442129410803318
# Epoch 15/30, Loss: 0.10026444494724274
# Epoch 15/30, Loss: 0.2554621696472168
# Epoch 15/30, Loss: 0.0652293935418129
# Epoch 15/30, Loss: 0.10224130749702454
# Epoch 15/30, Loss: 0.031951021403074265
# Epoch 15/30, Loss: 0.05418013036251068
# Epoch 15/30, Loss: 0.057232148945331573
# Epoch 15/30, Loss: 0.1780623197555542
# Epoch 15/30, Loss: 0.08566085249185562
# Epoch 15/30, Loss: 0.059083472937345505
# Epoch 15/30, Loss: 0.06940294802188873
# Epoch 15/30, Loss: 0.14112791419029236
# Epoch 15/30, Loss: 0.07243799418210983
# Epoch 15/30, Loss: 0.17541436851024628
# Epoch 15/30, Loss: 0.07233914732933044
# Epoch 15/30, Loss: 0.02050686627626419
# Epoch 15/30, Loss: 0.18549378216266632
# Epoch 15/30, Loss: 0.06080280989408493
# Epoch 15/30, Loss: 0.040079936385154724
# Epoch 15/30, Loss: 0.07354997843503952
# Epoch 15/30, Loss: 0.101715087890625
# Epoch 15/30, Loss: 0.09986820816993713
# Epoch 15/30, Loss: 0.09458939731121063
# Epoch 15/30, Loss: 0.22365276515483856
# Epoch 15/30, Loss: 0.07344945520162582
# Epoch 15/30, Loss: 0.05833294987678528
# Epoch 15/30, Loss: 0.024009360000491142
# Epoch 15/30, Loss: 0.060716401785612106
# Epoch 15/30, Loss: 0.059016935527324677
# Epoch 15/30, Loss: 0.07622513920068741
# Epoch 15/30, Loss: 0.09994463622570038
# Epoch 15/30, Loss: 0.1285901963710785
# Epoch 15/30, Loss: 0.05678950995206833
# Epoch 15/30, Loss: 0.0864405632019043
# Epoch 15/30, Loss: 0.08646790683269501
# Epoch 15/30, Loss: 0.06321945786476135
# Epoch 15/30, Loss: 0.048565469682216644
# Epoch 15/30, Loss: 0.08232724666595459
# Epoch 15/30, Loss: 0.034530553966760635
# Epoch 15/30, Loss: 0.046574268490076065
# Epoch 15/30, Loss: 0.07773204892873764
# Epoch 15/30, Loss: 0.03885415941476822
# Epoch 15/30, Loss: 0.0554962232708931
# Epoch 15/30, Loss: 0.032735615968704224
# Epoch 15/30, Loss: 0.02630939520895481
# Epoch 15/30, Loss: 0.037191279232501984
# Epoch 15/30, Loss: 0.04980289936065674
# Epoch 15/30, Loss: 0.054810140281915665
# Epoch 15/30, Loss: 0.06010235846042633
# Epoch 15/30, Loss: 0.18099966645240784
# Epoch 15/30, Loss: 0.10772232711315155
# Epoch 15/30, Loss: 0.05017135664820671
# Epoch 15/30, Loss: 0.039585888385772705
# Epoch 15/30, Loss: 0.033342085778713226
# Epoch 15/30, Loss: 0.058849673718214035
# Epoch 15/30, Loss: 0.06067418307065964
# Epoch 15/30, Loss: 0.06885102391242981
# Epoch 15/30, Loss: 0.062004223465919495
# Epoch 15/30, Loss: 0.05729459226131439
# Epoch 15/30, Loss: 0.19526265561580658
# Epoch 15/30, Loss: 0.14604178071022034
# Epoch 15/30, Loss: 0.03625745326280594
# Epoch 15/30, Loss: 0.15081898868083954
# Epoch 15/30, Loss: 0.09885942935943604
# Epoch 15/30, Loss: 0.050086282193660736
# Epoch 15/30, Loss: 0.15385228395462036
# Epoch 15/30, Loss: 0.05598318576812744
# Epoch 15/30, Loss: 0.04494118690490723
# Epoch 15/30, Loss: 0.05821068957448006
# Epoch 15/30, Loss: 0.11216193437576294
# Epoch 15/30, Loss: 0.03824256733059883
# Epoch 15/30, Loss: 0.13004735112190247
# Epoch 15/30, Loss: 0.07159633189439774
# Epoch 15/30, Loss: 0.1142154186964035
# Epoch 15/30, Loss: 0.0479230061173439
# Epoch 15/30, Loss: 0.04240138828754425
# Epoch 15/30, Loss: 0.3439880907535553
# Epoch 15/30, Loss: 0.021877150982618332
# Epoch 15/30, Loss: 0.17406736314296722
# Epoch 15/30, Loss: 0.03450467064976692
# Epoch 15/30, Loss: 0.1099342629313469
# Epoch 15/30, Loss: 0.03926592320203781
# Epoch 15/30, Loss: 0.0854649692773819
# Epoch 15/30, Loss: 0.06705573201179504
# Epoch 15/30, Loss: 0.04869040846824646
# Epoch 15/30, Loss: 0.133438378572464
# Epoch 15/30, Loss: 0.025936802849173546
# Epoch 15/30, Loss: 0.11995916813611984
# Epoch 15/30, Loss: 0.0819929912686348
# Epoch 15/30, Loss: 0.09752410650253296
# Epoch 15/30, Loss: 0.06926862895488739
# Epoch 15/30, Loss: 0.05202517658472061
# Epoch 15/30, Loss: 0.0429399237036705
# Epoch 15/30, Loss: 0.09635329246520996
# Epoch 15/30, Loss: 0.0871545672416687
# Epoch 15/30, Loss: 0.2310173511505127
# Epoch 15/30, Loss: 0.11207379400730133
# Epoch 15/30, Loss: 0.11579298973083496
# Epoch 15/30, Loss: 0.23677107691764832
# Epoch 15/30, Loss: 0.061199549585580826
# Epoch 15/30, Loss: 0.1738239824771881
# Epoch 15/30, Loss: 0.08826403319835663
# Epoch 15/30, Loss: 0.05425524711608887
# Epoch 15/30, Loss: 0.1558116227388382
# Epoch 15/30, Loss: 0.06651926785707474
# Epoch 15/30, Loss: 0.03955797478556633
# Epoch 15/30, Loss: 0.10259085893630981
# Epoch 15/30, Loss: 0.13212057948112488
# Epoch 15/30, Loss: 0.14490756392478943
# Epoch 15/30, Loss: 0.12419860064983368
# Epoch 15/30, Loss: 0.409701943397522
# Epoch 15/30, Loss: 0.0817517638206482
# Epoch 15/30, Loss: 0.04309074953198433
# Epoch 15/30, Loss: 0.13131248950958252
# Epoch 15/30, Loss: 0.11583760380744934
# Epoch 15/30, Loss: 0.10692302882671356
# Epoch 15/30, Loss: 0.061004720628261566
# Epoch 15/30, Loss: 0.2451208233833313
# Epoch 15/30, Loss: 0.12224981933832169
# Epoch 15/30, Loss: 0.09552031010389328
# Epoch 15/30, Loss: 0.12690919637680054
# Epoch 15/30, Loss: 0.09335226565599442
# Epoch 15/30, Loss: 0.05475769564509392
# Epoch 15/30, Loss: 0.05608261376619339
# Epoch 15/30, Loss: 0.15900446474552155
# Epoch 15/30, Loss: 0.07608680427074432
# Epoch 15/30, Loss: 0.07030889391899109
# Epoch 15/30, Loss: 0.12383246421813965
# Epoch 15/30, Loss: 0.27437543869018555
# Epoch 15/30, Loss: 0.04311992973089218
# Epoch 15/30, Loss: 0.0778774842619896
# Epoch 15/30, Loss: 0.11248967051506042
# Epoch 15/30, Loss: 0.22696515917778015
# Epoch 15/30, Loss: 0.13668471574783325
# Epoch 15/30, Loss: 0.033258941024541855
# Epoch 15/30, Loss: 0.09397754818201065
# Epoch 15/30, Loss: 0.07705379277467728
# Epoch 15/30, Loss: 0.2379017472267151
# Epoch 15/30, Loss: 0.03020886331796646
# Epoch 15/30, Loss: 0.09227009117603302
# Epoch 15/30, Loss: 0.06376785039901733
# Epoch 15/30, Loss: 0.07418595999479294
# Epoch 15/30, Loss: 0.2757949233055115
# Epoch 15/30, Loss: 0.058937110006809235
# Epoch 15/30, Loss: 0.08206554502248764
# Epoch 15/30, Loss: 0.041972171515226364
# Epoch 15/30, Loss: 0.061410266906023026
# Epoch 15/30, Loss: 0.07526557147502899
# Epoch 15/30, Loss: 0.16918301582336426
# Epoch 15/30, Loss: 0.07039511948823929
# Epoch 15/30, Loss: 0.13650423288345337
# Epoch 15/30, Loss: 0.16542351245880127
# Epoch 15/30, Loss: 0.28695815801620483
# Epoch 15/30, Loss: 0.2996906042098999
# Epoch 15/30, Loss: 0.07135602086782455
# Epoch 15/30, Loss: 0.11981365084648132
# Epoch 15/30, Loss: 0.05017508566379547
# Epoch 15/30, Loss: 0.07462906092405319
# Epoch 15/30, Loss: 0.09864459931850433
# Epoch 15/30, Loss: 0.12060405313968658
# Epoch 15/30, Loss: 0.052750084549188614
# Epoch 15/30, Loss: 0.0329996682703495
# Epoch 15/30, Loss: 0.1149785965681076
# Epoch 15/30, Loss: 0.0757288709282875
# Epoch 15/30, Loss: 0.13498945534229279
# Epoch 15/30, Loss: 0.0471249558031559
# Epoch 15/30, Loss: 0.08381487429141998
# Epoch 15/30, Loss: 0.07008351385593414
# Epoch 15/30, Eval Loss: 4.328308256199727
# Early stopping triggered

# %%
multimodal_model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/multimodal_model-2.pth'))
trainer = Trainer(multimodal_model.to(device), train_dataset, trainloader, devloader, testloader, 30, 0.001, device, True, earlystopping)

# %%
trainer.test()
# Out:
# MAE: 0.4086
# R²:  0.1921
# <ipython-input-23-795c20baa097>:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = torch.cat([torch.tensor(p) for p in preds]).to('cpu').numpy().flatten()
# <ipython-input-23-795c20baa097>:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true = torch.cat([torch.tensor(t) for t in targets]).to('cpu').numpy().flatten()
# (0.408601850271225, 0.19210952520370483)
