# %%
# !pip install lmdb

import argparse
import os
import numpy as np
import math
import itertools
import signal
import pandas as pd
import random
from sklearn.metrics import mean_absolute_error, r2_score
import lmdb
import pickle
from io import BytesIO
from sklearn.preprocessing import StandardScaler
import torchvision.transforms as transforms
from torchvision.utils import save_image
from transformers import AutoTokenizer, AutoModel
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torch.autograd import Variable
from torchvision import models

import gc

import zipfile
from io import BytesIO

import torch.nn as nn
import torch.nn.functional as F
import torch

import matplotlib.pyplot as plt
from PIL import Image

from torch.amp import GradScaler, autocast
from torch.utils.data import random_split

import glob
# Out:
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (1.6.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/datos_coches_procesados.csv')

# %%
import zipfile
import os

ruta_zip = "/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/imagenes_comprimidas.zip"
carpeta_destino = "dataset_extraido"

os.makedirs(carpeta_destino, exist_ok=True)

with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
    zip_ref.extractall(carpeta_destino)

print("Descompresión completada.")
# Out:
# Descompresión completada.

# %%
# Ruta a imágenes y CSV
root_dir = "dataset_extraido/imagenes_comprimidas"
csv_path = "/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/datos_coches_procesados.csv"
lmdb_path = "dataset.lmdb"

# Leer CSV
df = pd.read_csv(csv_path)
df = df.set_index('url')


# Crear base de datos LMDB
env = lmdb.open(lmdb_path, map_async=True, map_size=20*1024**3, meminit=False, writemap=True, lock=False)

with env.begin(write=True) as txn:
    for url in os.listdir(root_dir):
        folder_path = os.path.join(root_dir, url)
        if not os.path.isdir(folder_path) or url not in df.index:
            continue

        images = []

         # Cargar todas las imágenes de la subcarpeta
        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            with open(img_path, 'rb') as f:
                img_bytes = f.read()
                images.append((img_name, img_bytes))
            break  # Guardamos el nombre y el contenido

        if not images:
            continue

        key = url.encode('utf-8')  # Solo el nombre de la carpeta como clave
        metadata = df.loc[url].to_dict()
        value = pickle.dumps({
            "image": images,    # Lista de (nombre, bytes)
            "metadata": metadata,
        })

        txn.put(key, value)

# %%
random.seed(42)
def split_keys(path, train, dev):
  env = lmdb.open(path, readonly=True, lock=False)
  keys = []

  with env.begin() as txn:
      cursor = txn.cursor()
      for key, _ in cursor:
          keys.append(key)

  random.shuffle(keys)

  train_split = train
  dev_split = dev

  n = len(keys)
  train_keys = keys[:int(train_split * n)]
  dev_keys = keys[int(train_split * n):int((train_split + dev_split) * n)]
  test_keys = keys[int((train_split + dev_split) * n):]
  return train_keys, dev_keys, test_keys

# %%
def set_scaler(y_train):
  y_train_int = []
  for y in y_train:
    y = y.split(",")[0]
    y = y.replace('.', '')
    y = int(y)
    y_train_int.append(y)
  targets = np.array(y_train_int).reshape(-1, 1)
  scaler = StandardScaler()
  scaler.fit(targets)
  return scaler

# %%
def get_labels_train(df, train_keys):
  keys_str = [key.decode('utf-8') for key in train_keys]
  filtered_df = df.loc[df.index.intersection(keys_str)]
  y_train = filtered_df['precio'].tolist()
  return y_train

# %%
class LMDBDataset(Dataset):
    def __init__(self, lmdb_path ,keys, scaler, transform=None):
        self.env = lmdb.open(lmdb_path, readonly=True, lock=False)
        self.keys = keys
        self.transform = transform or transforms.ToTensor()
        self.normalizar = False
        self.scaler = scaler
    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        with self.env.begin() as txn:
            data = pickle.loads(txn.get(key))

        metadata = data["metadata"]
        try:
          año = int(float(metadata['año']))
        except:
          año = None
        try:
          km = int(float(metadata['km']))
        except:
          km = None
        try:
          precio = metadata['precio'].split(",")[0]
          precio = precio.replace('.', '')
          precio = int(precio)
        except:
          precio = -1

        text = "Modelo: " + str(metadata['marca']) +" "+str(metadata['modelo']) +" " + "año: " + str(año)+ " "+"Kilómetros: " + str(km) + " " + str(metadata['desc'])


        precio = self.normalizar_precio(precio)

        name, img_bytes = data["image"][0]
        img = Image.open(BytesIO(img_bytes)).convert("RGB")
        img = self.transform(img)

        return img, text, precio
    def normalizar_precio(self, precio):
        y = self.scaler.transform([[precio]])[0][0]
        return y

# %%
train_keys, dev_keys, test_keys = split_keys(lmdb_path, 0.85, 0.05)
print(len(train_keys))
# Out:
# 6907

# %%
train_precios = get_labels_train(df, train_keys)
scaler = set_scaler(train_precios)

# %%
train_dataset = LMDBDataset(lmdb_path, train_keys, scaler)
dev_dataset = LMDBDataset(lmdb_path, dev_keys, scaler)
test_dataset = LMDBDataset(lmdb_path, test_keys, scaler)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
from transformers import CLIPModel, CLIPProcessor

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
for name, param in model.named_parameters():
    if 'projection' in name:  # suponiendo que el último bloque tiene '16' en el nombre
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
for name, param in model.named_parameters():
    estado = "entrenable" if param.requires_grad else "congelada"
    print(f"{name:50} → {estado}")
# Out:
# logit_scale                                        → congelada
# text_model.embeddings.token_embedding.weight       → congelada
# text_model.embeddings.position_embedding.weight    → congelada
# text_model.encoder.layers.0.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.0.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.0.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.0.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.0.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.0.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.0.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.0.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.0.layer_norm1.weight     → congelada
# text_model.encoder.layers.0.layer_norm1.bias       → congelada
# text_model.encoder.layers.0.mlp.fc1.weight         → congelada
# text_model.encoder.layers.0.mlp.fc1.bias           → congelada
# text_model.encoder.layers.0.mlp.fc2.weight         → congelada
# text_model.encoder.layers.0.mlp.fc2.bias           → congelada
# text_model.encoder.layers.0.layer_norm2.weight     → congelada
# text_model.encoder.layers.0.layer_norm2.bias       → congelada
# text_model.encoder.layers.1.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.1.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.1.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.1.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.1.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.1.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.1.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.1.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.1.layer_norm1.weight     → congelada
# text_model.encoder.layers.1.layer_norm1.bias       → congelada
# text_model.encoder.layers.1.mlp.fc1.weight         → congelada
# text_model.encoder.layers.1.mlp.fc1.bias           → congelada
# text_model.encoder.layers.1.mlp.fc2.weight         → congelada
# text_model.encoder.layers.1.mlp.fc2.bias           → congelada
# text_model.encoder.layers.1.layer_norm2.weight     → congelada
# text_model.encoder.layers.1.layer_norm2.bias       → congelada
# text_model.encoder.layers.2.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.2.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.2.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.2.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.2.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.2.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.2.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.2.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.2.layer_norm1.weight     → congelada
# text_model.encoder.layers.2.layer_norm1.bias       → congelada
# text_model.encoder.layers.2.mlp.fc1.weight         → congelada
# text_model.encoder.layers.2.mlp.fc1.bias           → congelada
# text_model.encoder.layers.2.mlp.fc2.weight         → congelada
# text_model.encoder.layers.2.mlp.fc2.bias           → congelada
# text_model.encoder.layers.2.layer_norm2.weight     → congelada
# text_model.encoder.layers.2.layer_norm2.bias       → congelada
# text_model.encoder.layers.3.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.3.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.3.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.3.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.3.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.3.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.3.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.3.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.3.layer_norm1.weight     → congelada
# text_model.encoder.layers.3.layer_norm1.bias       → congelada
# text_model.encoder.layers.3.mlp.fc1.weight         → congelada
# text_model.encoder.layers.3.mlp.fc1.bias           → congelada
# text_model.encoder.layers.3.mlp.fc2.weight         → congelada
# text_model.encoder.layers.3.mlp.fc2.bias           → congelada
# text_model.encoder.layers.3.layer_norm2.weight     → congelada
# text_model.encoder.layers.3.layer_norm2.bias       → congelada
# text_model.encoder.layers.4.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.4.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.4.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.4.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.4.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.4.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.4.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.4.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.4.layer_norm1.weight     → congelada
# text_model.encoder.layers.4.layer_norm1.bias       → congelada
# text_model.encoder.layers.4.mlp.fc1.weight         → congelada
# text_model.encoder.layers.4.mlp.fc1.bias           → congelada
# text_model.encoder.layers.4.mlp.fc2.weight         → congelada
# text_model.encoder.layers.4.mlp.fc2.bias           → congelada
# text_model.encoder.layers.4.layer_norm2.weight     → congelada
# text_model.encoder.layers.4.layer_norm2.bias       → congelada
# text_model.encoder.layers.5.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.5.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.5.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.5.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.5.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.5.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.5.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.5.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.5.layer_norm1.weight     → congelada
# text_model.encoder.layers.5.layer_norm1.bias       → congelada
# text_model.encoder.layers.5.mlp.fc1.weight         → congelada
# text_model.encoder.layers.5.mlp.fc1.bias           → congelada
# text_model.encoder.layers.5.mlp.fc2.weight         → congelada
# text_model.encoder.layers.5.mlp.fc2.bias           → congelada
# text_model.encoder.layers.5.layer_norm2.weight     → congelada
# text_model.encoder.layers.5.layer_norm2.bias       → congelada
# text_model.encoder.layers.6.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.6.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.6.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.6.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.6.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.6.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.6.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.6.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.6.layer_norm1.weight     → congelada
# text_model.encoder.layers.6.layer_norm1.bias       → congelada
# text_model.encoder.layers.6.mlp.fc1.weight         → congelada
# text_model.encoder.layers.6.mlp.fc1.bias           → congelada
# text_model.encoder.layers.6.mlp.fc2.weight         → congelada
# text_model.encoder.layers.6.mlp.fc2.bias           → congelada
# text_model.encoder.layers.6.layer_norm2.weight     → congelada
# text_model.encoder.layers.6.layer_norm2.bias       → congelada
# text_model.encoder.layers.7.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.7.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.7.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.7.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.7.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.7.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.7.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.7.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.7.layer_norm1.weight     → congelada
# text_model.encoder.layers.7.layer_norm1.bias       → congelada
# text_model.encoder.layers.7.mlp.fc1.weight         → congelada
# text_model.encoder.layers.7.mlp.fc1.bias           → congelada
# text_model.encoder.layers.7.mlp.fc2.weight         → congelada
# text_model.encoder.layers.7.mlp.fc2.bias           → congelada
# text_model.encoder.layers.7.layer_norm2.weight     → congelada
# text_model.encoder.layers.7.layer_norm2.bias       → congelada
# text_model.encoder.layers.8.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.8.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.8.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.8.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.8.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.8.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.8.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.8.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.8.layer_norm1.weight     → congelada
# text_model.encoder.layers.8.layer_norm1.bias       → congelada
# text_model.encoder.layers.8.mlp.fc1.weight         → congelada
# text_model.encoder.layers.8.mlp.fc1.bias           → congelada
# text_model.encoder.layers.8.mlp.fc2.weight         → congelada
# text_model.encoder.layers.8.mlp.fc2.bias           → congelada
# text_model.encoder.layers.8.layer_norm2.weight     → congelada
# text_model.encoder.layers.8.layer_norm2.bias       → congelada
# text_model.encoder.layers.9.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.9.self_attn.k_proj.bias  → congelada
# text_model.encoder.layers.9.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.9.self_attn.v_proj.bias  → congelada
# text_model.encoder.layers.9.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.9.self_attn.q_proj.bias  → congelada
# text_model.encoder.layers.9.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.9.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.9.layer_norm1.weight     → congelada
# text_model.encoder.layers.9.layer_norm1.bias       → congelada
# text_model.encoder.layers.9.mlp.fc1.weight         → congelada
# text_model.encoder.layers.9.mlp.fc1.bias           → congelada
# text_model.encoder.layers.9.mlp.fc2.weight         → congelada
# text_model.encoder.layers.9.mlp.fc2.bias           → congelada
# text_model.encoder.layers.9.layer_norm2.weight     → congelada
# text_model.encoder.layers.9.layer_norm2.bias       → congelada
# text_model.encoder.layers.10.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.10.self_attn.k_proj.bias → congelada
# text_model.encoder.layers.10.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.10.self_attn.v_proj.bias → congelada
# text_model.encoder.layers.10.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.10.self_attn.q_proj.bias → congelada
# text_model.encoder.layers.10.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.10.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.10.layer_norm1.weight    → congelada
# text_model.encoder.layers.10.layer_norm1.bias      → congelada
# text_model.encoder.layers.10.mlp.fc1.weight        → congelada
# text_model.encoder.layers.10.mlp.fc1.bias          → congelada
# text_model.encoder.layers.10.mlp.fc2.weight        → congelada
# text_model.encoder.layers.10.mlp.fc2.bias          → congelada
# text_model.encoder.layers.10.layer_norm2.weight    → congelada
# text_model.encoder.layers.10.layer_norm2.bias      → congelada
# text_model.encoder.layers.11.self_attn.k_proj.weight → congelada
# text_model.encoder.layers.11.self_attn.k_proj.bias → congelada
# text_model.encoder.layers.11.self_attn.v_proj.weight → congelada
# text_model.encoder.layers.11.self_attn.v_proj.bias → congelada
# text_model.encoder.layers.11.self_attn.q_proj.weight → congelada
# text_model.encoder.layers.11.self_attn.q_proj.bias → congelada
# text_model.encoder.layers.11.self_attn.out_proj.weight → congelada
# text_model.encoder.layers.11.self_attn.out_proj.bias → congelada
# text_model.encoder.layers.11.layer_norm1.weight    → congelada
# text_model.encoder.layers.11.layer_norm1.bias      → congelada
# text_model.encoder.layers.11.mlp.fc1.weight        → congelada
# text_model.encoder.layers.11.mlp.fc1.bias          → congelada
# text_model.encoder.layers.11.mlp.fc2.weight        → congelada
# text_model.encoder.layers.11.mlp.fc2.bias          → congelada
# text_model.encoder.layers.11.layer_norm2.weight    → congelada
# text_model.encoder.layers.11.layer_norm2.bias      → congelada
# text_model.final_layer_norm.weight                 → congelada
# text_model.final_layer_norm.bias                   → congelada
# vision_model.embeddings.class_embedding            → congelada
# vision_model.embeddings.patch_embedding.weight     → congelada
# vision_model.embeddings.position_embedding.weight  → congelada
# vision_model.pre_layrnorm.weight                   → congelada
# vision_model.pre_layrnorm.bias                     → congelada
# vision_model.encoder.layers.0.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.0.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.0.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.0.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.0.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.0.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.0.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.0.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.0.layer_norm1.weight   → congelada
# vision_model.encoder.layers.0.layer_norm1.bias     → congelada
# vision_model.encoder.layers.0.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.0.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.0.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.0.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.0.layer_norm2.weight   → congelada
# vision_model.encoder.layers.0.layer_norm2.bias     → congelada
# vision_model.encoder.layers.1.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.1.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.1.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.1.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.1.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.1.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.1.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.1.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.1.layer_norm1.weight   → congelada
# vision_model.encoder.layers.1.layer_norm1.bias     → congelada
# vision_model.encoder.layers.1.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.1.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.1.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.1.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.1.layer_norm2.weight   → congelada
# vision_model.encoder.layers.1.layer_norm2.bias     → congelada
# vision_model.encoder.layers.2.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.2.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.2.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.2.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.2.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.2.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.2.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.2.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.2.layer_norm1.weight   → congelada
# vision_model.encoder.layers.2.layer_norm1.bias     → congelada
# vision_model.encoder.layers.2.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.2.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.2.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.2.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.2.layer_norm2.weight   → congelada
# vision_model.encoder.layers.2.layer_norm2.bias     → congelada
# vision_model.encoder.layers.3.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.3.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.3.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.3.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.3.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.3.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.3.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.3.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.3.layer_norm1.weight   → congelada
# vision_model.encoder.layers.3.layer_norm1.bias     → congelada
# vision_model.encoder.layers.3.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.3.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.3.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.3.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.3.layer_norm2.weight   → congelada
# vision_model.encoder.layers.3.layer_norm2.bias     → congelada
# vision_model.encoder.layers.4.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.4.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.4.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.4.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.4.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.4.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.4.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.4.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.4.layer_norm1.weight   → congelada
# vision_model.encoder.layers.4.layer_norm1.bias     → congelada
# vision_model.encoder.layers.4.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.4.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.4.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.4.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.4.layer_norm2.weight   → congelada
# vision_model.encoder.layers.4.layer_norm2.bias     → congelada
# vision_model.encoder.layers.5.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.5.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.5.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.5.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.5.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.5.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.5.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.5.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.5.layer_norm1.weight   → congelada
# vision_model.encoder.layers.5.layer_norm1.bias     → congelada
# vision_model.encoder.layers.5.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.5.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.5.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.5.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.5.layer_norm2.weight   → congelada
# vision_model.encoder.layers.5.layer_norm2.bias     → congelada
# vision_model.encoder.layers.6.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.6.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.6.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.6.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.6.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.6.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.6.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.6.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.6.layer_norm1.weight   → congelada
# vision_model.encoder.layers.6.layer_norm1.bias     → congelada
# vision_model.encoder.layers.6.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.6.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.6.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.6.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.6.layer_norm2.weight   → congelada
# vision_model.encoder.layers.6.layer_norm2.bias     → congelada
# vision_model.encoder.layers.7.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.7.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.7.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.7.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.7.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.7.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.7.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.7.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.7.layer_norm1.weight   → congelada
# vision_model.encoder.layers.7.layer_norm1.bias     → congelada
# vision_model.encoder.layers.7.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.7.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.7.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.7.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.7.layer_norm2.weight   → congelada
# vision_model.encoder.layers.7.layer_norm2.bias     → congelada
# vision_model.encoder.layers.8.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.8.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.8.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.8.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.8.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.8.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.8.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.8.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.8.layer_norm1.weight   → congelada
# vision_model.encoder.layers.8.layer_norm1.bias     → congelada
# vision_model.encoder.layers.8.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.8.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.8.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.8.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.8.layer_norm2.weight   → congelada
# vision_model.encoder.layers.8.layer_norm2.bias     → congelada
# vision_model.encoder.layers.9.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.9.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.9.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.9.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.9.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.9.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.9.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.9.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.9.layer_norm1.weight   → congelada
# vision_model.encoder.layers.9.layer_norm1.bias     → congelada
# vision_model.encoder.layers.9.mlp.fc1.weight       → congelada
# vision_model.encoder.layers.9.mlp.fc1.bias         → congelada
# vision_model.encoder.layers.9.mlp.fc2.weight       → congelada
# vision_model.encoder.layers.9.mlp.fc2.bias         → congelada
# vision_model.encoder.layers.9.layer_norm2.weight   → congelada
# vision_model.encoder.layers.9.layer_norm2.bias     → congelada
# vision_model.encoder.layers.10.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.10.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.10.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.10.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.10.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.10.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.10.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.10.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.10.layer_norm1.weight  → congelada
# vision_model.encoder.layers.10.layer_norm1.bias    → congelada
# vision_model.encoder.layers.10.mlp.fc1.weight      → congelada
# vision_model.encoder.layers.10.mlp.fc1.bias        → congelada
# vision_model.encoder.layers.10.mlp.fc2.weight      → congelada
# vision_model.encoder.layers.10.mlp.fc2.bias        → congelada
# vision_model.encoder.layers.10.layer_norm2.weight  → congelada
# vision_model.encoder.layers.10.layer_norm2.bias    → congelada
# vision_model.encoder.layers.11.self_attn.k_proj.weight → congelada
# vision_model.encoder.layers.11.self_attn.k_proj.bias → congelada
# vision_model.encoder.layers.11.self_attn.v_proj.weight → congelada
# vision_model.encoder.layers.11.self_attn.v_proj.bias → congelada
# vision_model.encoder.layers.11.self_attn.q_proj.weight → congelada
# vision_model.encoder.layers.11.self_attn.q_proj.bias → congelada
# vision_model.encoder.layers.11.self_attn.out_proj.weight → congelada
# vision_model.encoder.layers.11.self_attn.out_proj.bias → congelada
# vision_model.encoder.layers.11.layer_norm1.weight  → congelada
# vision_model.encoder.layers.11.layer_norm1.bias    → congelada
# vision_model.encoder.layers.11.mlp.fc1.weight      → congelada
# vision_model.encoder.layers.11.mlp.fc1.bias        → congelada
# vision_model.encoder.layers.11.mlp.fc2.weight      → congelada
# vision_model.encoder.layers.11.mlp.fc2.bias        → congelada
# vision_model.encoder.layers.11.layer_norm2.weight  → congelada
# vision_model.encoder.layers.11.layer_norm2.bias    → congelada
# vision_model.post_layernorm.weight                 → congelada
# vision_model.post_layernorm.bias                   → congelada
# visual_projection.weight                           → entrenable
# text_projection.weight                             → entrenable

# %%
class ClipModel(nn.Module):
  def __init__(self, model, processor, device, final_layer=1024):
    super(ClipModel, self).__init__()
    self.model = model
    self.processor = processor
    self.device = device
    self.model = self.model.to(self.device)
    self.fc = nn.Linear(final_layer, 1).to(self.device)
  def forward(self, image, text):
    inputs = self.processor(text=text, images=image, return_tensors="pt", padding=True, truncation=True).to(self.device)
    image_embeds = self.model.get_image_features(pixel_values=inputs["pixel_values"])
    text_embeds = self.model.get_text_features(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"])
    out = torch.cat((image_embeds, text_embeds), dim=1)
    out = self.fc(out)

    return out

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0
        self.should_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True

# %%
class Trainer():
  def __init__(self, model, dataset, dataloader, devloader, testloader, num_epochs, learning_rate, device, save, earlystopping):
    self.model = model
    self.dataset = dataset
    self.dataloader = dataloader
    self.num_epochs = num_epochs
    self.learning_rate = learning_rate
    self.device = device
    self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)
    self.criterion = nn.MSELoss()
    self.save = save
    self.earlystopping = earlystopping
    self.devloader = devloader
    self.testloader = testloader
    self.save_path ='/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/clip_model-2.pth'
    self.upload_path = '/content/drive/MyDrive/Colab Notebooks/MDT/ProyectoIndividual/clip_model.pth'

  def train(self):
    for epoch in range(self.num_epochs):
      self.model.train()
      for images, text, y in self.dataloader:

        y = y.clone().detach().to(torch.float32).to(self.device)

        self.optimizer.zero_grad()

        output = self.model(images, text)
        loss = self.criterion(output.flatten(), y.flatten())
        loss.backward()
        self.optimizer.step()
        print(f"Epoch {epoch+1}/{self.num_epochs}, Loss: {loss.item()}")

      eval_loss = self.eval()

      if self.save and self.earlystopping.best_loss > eval_loss:
        self.save_model()

      print(f"Epoch {epoch+1}/{self.num_epochs}, Eval Loss: {eval_loss}")
      if epoch == 8:
        self.descongelar_capas()
      self.earlystopping(eval_loss)
      if self.earlystopping.should_stop:
        print("Early stopping triggered")
        break

  def eval(self):
    self.model.eval()
    losses = []
    with torch.no_grad():
      for images, text, y in self.devloader:
        y = y.clone().detach().to(torch.float32).to(self.device)
        output = self.model(images, text)
        loss = self.criterion(output.flatten(), y.flatten())
        losses.append(loss.item())
    return sum(losses)/len(losses)

  def test(self):
    self.model.eval()
    targets = []
    preds = []
    with torch.no_grad():
      for images, text, y in self.testloader:
        y = y.clone().detach().to(torch.float32).to(self.device)
        output = self.model(images, text)
        preds.append(output)
        targets.append(y)

    y_pred = torch.cat([torch.tensor(p) for p in preds]).to('cpu').numpy().flatten()
    y_true = torch.cat([torch.tensor(t) for t in targets]).to('cpu').numpy().flatten()

    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    print(f"MAE: {mae:.4f}")
    print(f"R²:  {r2:.4f}")

    return mae, r2

  def save_model(self, path=None):
    if path is None:
      torch.save(self.model.state_dict(), self.save_path)
    else:
      torch.save(self.model.state_dict(), path)
  def descongelar_capas(self):
    print("Descongelando capas...")
    for name, param in self.model.named_parameters():
      if 'post_layernorm' in name or 'final_layer_norm' in name:
        param.requires_grad = True
    for name, param in self.model.named_parameters():
      if '11.' in name:
        param.requires_grad = True
  def get_model(self, path = None):
    self.model.load_state_dict(torch.load(self.upload_path))

# %%
clipmodel = ClipModel(model, processor, device, final_layer=1024)

# %%
earlystopping = EarlyStopping(patience=7, min_delta=0.01)

# Epoch 6/30, Loss: 0.1174297034740448
# Epoch 6/30, Loss: 0.17606845498085022
# Epoch 6/30, Loss: 0.16262775659561157
# Epoch 6/30, Loss: 1.2047008275985718
# Epoch 6/30, Loss: 0.41115355491638184
# Epoch 6/30, Loss: 0.2175620198249817
# Epoch 6/30, Loss: 0.07486242055892944
# Epoch 6/30, Loss: 0.2277894914150238
# Epoch 6/30, Loss: 0.23286110162734985
# Epoch 6/30, Loss: 0.1047716736793518
# Epoch 6/30, Loss: 0.08599885553121567
# ...
# Epoch 8/30, Loss: 0.07767529785633087
# Epoch 8/30, Loss: 0.07791431248188019
# Epoch 8/30, Loss: 0.22872048616409302
# Epoch 8/30, Loss: 0.22590267658233643
# Epoch 8/30, Loss: 0.07284237444400787
# Epoch 8/30, Loss: 0.10070299357175827
# Epoch 8/30, Loss: 0.23373620212078094
# Epoch 8/30, Loss: 0.1520330160856247
# Epoch 8/30, Loss: 0.1312435418367386
# Epoch 8/30, Loss: 0.2162320911884308
# Epoch 8/30, Loss: 0.10069552063941956
# Epoch 8/30, Loss: 0.15467414259910583
# Epoch 8/30, Loss: 0.3297072649002075
# Epoch 8/30, Loss: 0.22785331308841705
# Epoch 8/30, Loss: 0.26429274678230286
# Epoch 8/30, Loss: 0.12337227165699005
# Epoch 8/30, Loss: 0.12278575450181961
# Epoch 8/30, Loss: 0.21052715182304382
# Epoch 8/30, Loss: 0.1383240669965744
# Epoch 8/30, Loss: 0.11950983107089996
# Epoch 8/30, Loss: 0.10299451649188995
# Epoch 8/30, Loss: 0.20166541635990143
# Epoch 8/30, Loss: 0.13476207852363586
# Epoch 8/30, Loss: 0.18264362215995789
# Epoch 8/30, Loss: 0.21656034886837006
# Epoch 8/30, Loss: 0.16511881351470947
# Epoch 8/30, Loss: 0.2334405481815338
# Epoch 8/30, Loss: 0.19541065394878387
# Epoch 8/30, Loss: 0.11725100129842758
# Epoch 8/30, Loss: 0.0813220664858818
# Epoch 8/30, Loss: 0.10018382966518402
# Epoch 8/30, Loss: 0.7510024309158325
# Epoch 8/30, Loss: 0.11255801469087601
# Epoch 8/30, Loss: 0.04911006987094879
# Epoch 8/30, Loss: 0.21905532479286194
# Epoch 8/30, Loss: 0.12065480649471283
# Epoch 8/30, Loss: 0.09757144004106522
# Epoch 8/30, Loss: 0.08427198231220245
# Epoch 8/30, Loss: 0.25439807772636414
# Epoch 8/30, Loss: 0.11800972372293472
# Epoch 8/30, Loss: 0.0815424770116806
# Epoch 8/30, Loss: 0.09315669536590576
# Epoch 8/30, Loss: 0.04015379026532173
# Epoch 8/30, Loss: 0.1307520866394043
# Epoch 8/30, Loss: 0.1583975851535797
# Epoch 8/30, Loss: 0.11929836124181747
# Epoch 8/30, Loss: 0.09573112428188324
# Epoch 8/30, Loss: 0.14021453261375427
# Epoch 8/30, Loss: 0.187327578663826
# Epoch 8/30, Loss: 0.061277784407138824
# Epoch 8/30, Loss: 0.0920240581035614
# Epoch 8/30, Loss: 0.1269994080066681
# Epoch 8/30, Loss: 0.3551439642906189
# Epoch 8/30, Loss: 0.17287111282348633
# Epoch 8/30, Loss: 0.19838328659534454
# Epoch 8/30, Loss: 0.18241342902183533
# Epoch 8/30, Loss: 0.12634745240211487
# Epoch 8/30, Loss: 0.1732175648212433
# Epoch 8/30, Loss: 0.1119861751794815
# Epoch 8/30, Loss: 0.1956329345703125
# Epoch 8/30, Loss: 0.38201969861984253
# Epoch 8/30, Loss: 2.2184431552886963
# Epoch 8/30, Loss: 1.7628114223480225
# Epoch 8/30, Loss: 0.33907678723335266
# Epoch 8/30, Loss: 0.12563933432102203
# Epoch 8/30, Loss: 0.1337931603193283
# Epoch 8/30, Loss: 0.45167410373687744
# Epoch 8/30, Loss: 0.3776153326034546
# Epoch 8/30, Loss: 0.08092564344406128
# Epoch 8/30, Loss: 0.47163793444633484
# Epoch 8/30, Loss: 0.1772775799036026
# Epoch 8/30, Loss: 0.30990612506866455
# Epoch 8/30, Loss: 0.24043549597263336
# Epoch 8/30, Loss: 0.21334461867809296
# Epoch 8/30, Loss: 0.09965600818395615
# Epoch 8/30, Loss: 0.0961310863494873
# Epoch 8/30, Loss: 3.586775541305542
# Epoch 8/30, Loss: 0.13198548555374146
# Epoch 8/30, Loss: 0.5174306035041809
# Epoch 8/30, Loss: 0.2759522795677185
# Epoch 8/30, Loss: 0.09642071276903152
# Epoch 8/30, Loss: 0.10339413583278656
# Epoch 8/30, Loss: 0.6699321866035461
# Epoch 8/30, Loss: 3.0939602851867676
# Epoch 8/30, Loss: 0.3538843095302582
# Epoch 8/30, Loss: 0.34838998317718506
# Epoch 8/30, Loss: 0.17557920515537262
# Epoch 8/30, Loss: 0.0747709646821022
# Epoch 8/30, Loss: 0.3591012954711914
# Epoch 8/30, Loss: 0.11074284464120865
# Epoch 8/30, Loss: 0.12429171055555344
# Epoch 8/30, Loss: 0.11985979229211807
# Epoch 8/30, Loss: 0.13676543533802032
# Epoch 8/30, Loss: 0.09208568930625916
# Epoch 8/30, Loss: 0.6082617044448853
# Epoch 8/30, Loss: 0.25036877393722534
# Epoch 8/30, Loss: 2.189199447631836
# Epoch 8/30, Loss: 0.15250393748283386
# Epoch 8/30, Loss: 0.5256811380386353
# Epoch 8/30, Loss: 0.5017572641372681
# Epoch 8/30, Loss: 0.3185070753097534
# Epoch 8/30, Loss: 0.22158217430114746
# Epoch 8/30, Loss: 0.08078151196241379
# Epoch 8/30, Loss: 6.801966667175293
# Epoch 8/30, Loss: 2.267007350921631
# Epoch 8/30, Loss: 0.34334874153137207
# Epoch 8/30, Loss: 0.4195026755332947
# Epoch 8/30, Loss: 1.5282392501831055
# Epoch 8/30, Loss: 0.09216947853565216
# Epoch 8/30, Loss: 0.1592966616153717
# Epoch 8/30, Loss: 1.2391806840896606
# Epoch 8/30, Loss: 0.10560715198516846
# Epoch 8/30, Loss: 0.6219947338104248
# Epoch 8/30, Loss: 0.18086457252502441
# Epoch 8/30, Loss: 0.23776254057884216
# Epoch 8/30, Loss: 0.12477166950702667
# Epoch 8/30, Loss: 0.22578957676887512
# Epoch 8/30, Loss: 0.07761100679636002
# Epoch 8/30, Loss: 0.14625196158885956
# Epoch 8/30, Loss: 1.0103565454483032
# Epoch 8/30, Loss: 0.1344960480928421
# Epoch 8/30, Loss: 0.2914591133594513
# Epoch 8/30, Loss: 0.14092999696731567
# Epoch 8/30, Loss: 0.34782493114471436
# Epoch 8/30, Loss: 0.1552528589963913
# Epoch 8/30, Loss: 0.1045420840382576
# Epoch 8/30, Loss: 0.14047658443450928
# Epoch 8/30, Loss: 0.1048862487077713
# Epoch 8/30, Loss: 0.10863253474235535
# Epoch 8/30, Loss: 0.7605537176132202
# Epoch 8/30, Loss: 0.09961941838264465
# Epoch 8/30, Loss: 2.7025365829467773
# Epoch 8/30, Loss: 0.2897878587245941
# Epoch 8/30, Loss: 0.4751741886138916
# Epoch 8/30, Loss: 0.13374808430671692
# Epoch 8/30, Loss: 0.24871155619621277
# Epoch 8/30, Loss: 0.29163774847984314
# Epoch 8/30, Loss: 0.2859044671058655
# Epoch 8/30, Loss: 0.21812361478805542
# Epoch 8/30, Loss: 0.1861763894557953
# Epoch 8/30, Loss: 0.13614463806152344
# Epoch 8/30, Loss: 0.15102514624595642
# Epoch 8/30, Loss: 0.15304061770439148
# Epoch 8/30, Loss: 0.32160934805870056
# Epoch 8/30, Loss: 0.1878625750541687
# Epoch 8/30, Loss: 0.7774635553359985
# Epoch 8/30, Loss: 0.14972907304763794
# Epoch 8/30, Loss: 0.08417029678821564
# Epoch 8/30, Loss: 0.1267773061990738
# Epoch 8/30, Loss: 0.10432259738445282
# Epoch 8/30, Loss: 0.2669886648654938
# Epoch 8/30, Loss: 0.10126833617687225
# Epoch 8/30, Loss: 0.5487844944000244
# Epoch 8/30, Loss: 0.22923485934734344
# Epoch 8/30, Loss: 0.13777583837509155
# Epoch 8/30, Loss: 0.5132253170013428
# Epoch 8/30, Loss: 0.09423583000898361
# Epoch 8/30, Loss: 0.2725437879562378
# Epoch 8/30, Loss: 0.12822900712490082
# Epoch 8/30, Loss: 0.08980300277471542
# Epoch 8/30, Loss: 0.13997118175029755
# Epoch 8/30, Loss: 0.281211793422699
# Epoch 8/30, Loss: 0.13535165786743164
# Epoch 8/30, Loss: 0.28638043999671936
# Epoch 8/30, Loss: 0.3663378655910492
# Epoch 8/30, Loss: 0.11491693556308746
# Epoch 8/30, Loss: 0.12540876865386963
# Epoch 8/30, Loss: 0.054759152233600616
# Epoch 8/30, Loss: 2.099203109741211
# Epoch 8/30, Loss: 0.4649600386619568
# Epoch 8/30, Loss: 0.15309032797813416
# Epoch 8/30, Loss: 0.22647200524806976
# Epoch 8/30, Loss: 0.21114975214004517
# Epoch 8/30, Loss: 0.09182559698820114
# Epoch 8/30, Loss: 0.17650249600410461
# Epoch 8/30, Loss: 0.05989953875541687
# Epoch 8/30, Loss: 0.40028902888298035
# Epoch 8/30, Loss: 0.09524403512477875
# Epoch 8/30, Loss: 0.29305651783943176
# Epoch 9/30, Loss: 0.14524510502815247
# Epoch 9/30, Loss: 0.1228785589337349
# Epoch 9/30, Loss: 1.0207319259643555
# Epoch 9/30, Loss: 0.11212368309497833
# Epoch 9/30, Loss: 0.09293994307518005
# Epoch 9/30, Loss: 0.05919838696718216
# Epoch 9/30, Loss: 0.405653715133667
# Epoch 9/30, Loss: 1.1077873706817627
# Epoch 9/30, Loss: 0.21662791073322296
# Epoch 9/30, Loss: 0.1401275396347046
# Epoch 9/30, Loss: 0.4216293692588806
# Epoch 9/30, Loss: 0.14137613773345947
# Epoch 9/30, Loss: 0.15622888505458832
# Epoch 9/30, Loss: 0.052920859307050705
# Epoch 9/30, Loss: 0.17632919549942017
# Epoch 9/30, Loss: 0.3077391982078552
# Epoch 9/30, Loss: 0.18118388950824738
# Epoch 9/30, Loss: 1.9439479112625122
# Epoch 9/30, Loss: 0.0844556987285614
# Epoch 9/30, Loss: 0.1851760447025299
# Epoch 9/30, Loss: 0.20304299890995026
# Epoch 9/30, Loss: 0.10263814777135849
# Epoch 9/30, Loss: 0.182327538728714
# Epoch 9/30, Loss: 0.13550840318202972
# Epoch 9/30, Loss: 0.08871495723724365
# Epoch 9/30, Loss: 0.2117767035961151
# Epoch 9/30, Loss: 0.1596686989068985
# Epoch 9/30, Loss: 0.12139930576086044
# Epoch 9/30, Loss: 0.036011952906847
# Epoch 9/30, Loss: 0.47455504536628723
# Epoch 9/30, Loss: 0.12539653480052948
# Epoch 9/30, Loss: 0.46690934896469116
# Epoch 9/30, Loss: 0.37027159333229065
# Epoch 9/30, Loss: 0.16517817974090576
# Epoch 9/30, Loss: 0.06588278710842133
# Epoch 9/30, Loss: 0.15316876769065857
# Epoch 9/30, Loss: 0.15424895286560059
# Epoch 9/30, Loss: 0.3688613176345825
# Epoch 9/30, Loss: 0.1405438482761383
# Epoch 9/30, Loss: 0.23420467972755432
# Epoch 9/30, Loss: 0.10504470765590668
# Epoch 9/30, Loss: 0.14298725128173828
# Epoch 9/30, Loss: 0.08065943419933319
# Epoch 9/30, Loss: 0.17232990264892578
# Epoch 9/30, Loss: 2.44136643409729
# Epoch 9/30, Loss: 0.3965311050415039
# Epoch 9/30, Loss: 0.19606077671051025
# Epoch 9/30, Loss: 1.7721946239471436
# Epoch 9/30, Loss: 0.40266311168670654
# Epoch 9/30, Loss: 0.32457685470581055
# Epoch 9/30, Loss: 0.30804091691970825
# Epoch 9/30, Loss: 0.18262097239494324
# Epoch 9/30, Loss: 0.34004268050193787
# Epoch 9/30, Eval Loss: 2.1550470751065474
# Descongelando capas...
# Early stopping triggered

# %%
trainer.get_model()
trainer.test()
# Out:
# MAE: 0.3461
# R²:  0.6626
# <ipython-input-68-4c7c4f2a511f>:68: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = torch.cat([torch.tensor(p) for p in preds]).to('cpu').numpy().flatten()
# <ipython-input-68-4c7c4f2a511f>:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true = torch.cat([torch.tensor(t) for t in targets]).to('cpu').numpy().flatten()
# (0.34607234597206116, 0.662649393081665)
